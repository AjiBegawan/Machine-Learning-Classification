# %% [markdown]
# # 1. Import Libraries

# %%
import tensorflow as tf
gpu = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpu[0], True)

# %%
import math
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
sns.set_style("whitegrid")
plt.style.use("fivethirtyeight")

from collections import Counter
from tqdm.notebook import tqdm
tqdm.pandas()

from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE

from tensorflow import keras
from keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD, Adam,  RMSprop, Nadam
from tensorflow.python.keras import models, layers, optimizers
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Dense, Flatten, Conv1D, MaxPooling1D, LSTM, GRU, Embedding,\
    BatchNormalization, LeakyReLU, Dropout, ReLU, Bidirectional, GlobalMaxPooling1D

from sklearn.model_selection import train_test_split
from   sklearn.model_selection import cross_val_score

from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PowerTransformer, MinMaxScaler, LabelEncoder
from sklearn.feature_selection import chi2, RFE, SelectFromModel, SelectKBest
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score, RocCurveDisplay, classification_report 

from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import PassiveAggressiveClassifier, LogisticRegression

from sklearn.ensemble import (
    BaggingClassifier,
    StackingClassifier,
    AdaBoostClassifier, 
    ExtraTreesClassifier,
    RandomForestClassifier,
    RandomForestClassifier,
    GradientBoostingClassifier, 
    HistGradientBoostingClassifier
)
from xgboost import XGBClassifier

from pycaret.classification import ClassificationExperiment

# %% [markdown]
# # 2. Load Data

# %%
data = pd.read_csv('../Dataset/heart.csv').drop_duplicates().dropna()
data.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# # 3. Initial Analysis

# %% [markdown]
# ### 3.1. Metadata

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 302 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       302 non-null    int64
#  1   sex       302 non-null    int64
#  2   cp        302 non-null    int64
#  3   trestbps  302 non-null    int64
#  4   chol      302 non-null    int64
#  5   fbs       302 non-null    int64
#  6   restecg   302 non-null    int64
#  7   thalach   302 non-null    int64
#  8   exang     302 non-null    int64
#  9   oldpeak   302 non-null    float64
#  10  slope     302 non-null    int64
#  11  ca        302 non-null    int64
#  12  thal      302 non-null    int64
#  13  target    302 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 35.4 KB

# %%
data.describe().transpose()
# Out:
#           count        mean        std    min     25%    50%     75%    max
# age       302.0   54.420530   9.047970   29.0   48.00   55.5   61.00   77.0
# sex       302.0    0.682119   0.466426    0.0    0.00    1.0    1.00    1.0
# cp        302.0    0.963576   1.032044    0.0    0.00    1.0    2.00    3.0
# trestbps  302.0  131.602649  17.563394   94.0  120.00  130.0  140.00  200.0
# chol      302.0  246.500000  51.753489  126.0  211.00  240.5  274.75  564.0
# fbs       302.0    0.149007   0.356686    0.0    0.00    0.0    0.00    1.0
# restecg   302.0    0.526490   0.526027    0.0    0.00    1.0    1.00    2.0
# thalach   302.0  149.569536  22.903527   71.0  133.25  152.5  166.00  202.0
# exang     302.0    0.327815   0.470196    0.0    0.00    0.0    1.00    1.0
# oldpeak   302.0    1.043046   1.161452    0.0    0.00    0.8    1.60    6.2
# slope     302.0    1.397351   0.616274    0.0    1.00    1.0    2.00    2.0
# ca        302.0    0.718543   1.006748    0.0    0.00    0.0    1.00    4.0
# thal      302.0    2.314570   0.613026    0.0    2.00    2.0    3.00    3.0
# target    302.0    0.543046   0.498970    0.0    0.00    1.0    1.00    1.0

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
print(f'Number of duplicates data : {data.duplicated().sum()}')
# Out:
# Number of duplicates data : 0

# %%
data.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trestbps     49
# chol        152
# fbs           2
# restecg       3
# thalach      91
# exang         2
# oldpeak      40
# slope         3
# ca            5
# thal          4
# target        2
# dtype: int64

# %%
plt.subplots(figsize=(20,5))
ax = sns.countplot(data, x=data['target'])
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '138'), Text(0, 0, '164')]

# %% [markdown]
# ### 3.2. Get columns dtypes

# %%
numerical_columns = [column_name for column_name in data.columns if data[column_name].dtype != 'object']
categorical_columns = [column_name for column_name in data.columns if data[column_name].dtype == 'object']
print(f'Numerical Columns   : {numerical_columns}')
print(f'Categorical Columns : {categorical_columns}')
# Out:
# Numerical Columns   : ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target']
# Categorical Columns : []

# %%
# def change_columns_to_numerical(data):
#     LE = LabelEncoder()

#     for column in categorical_columns:
#         data[column] = LE.fit_transform(data[column])
#         print(f'{column} : {LE.classes_}') 
#     return data

# data = change_columns_to_numerical(data)

# %% [markdown]
# ### 3.3. EDA

# %%
num_cols = 3
num_rows = math.ceil(len(numerical_columns) / num_cols)

fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 10))

for i, column in enumerate(numerical_columns):
    row = i // num_cols
    col = i % num_cols
    sns.kdeplot(data = data, x = column, ax=axes[row, col]) \
        .set_title("Distribusi nilai kolom " + column)
    

for i in range(len(numerical_columns), num_rows * num_cols):
    row = i // num_cols
    col = i % num_cols
    axes[row, col].axis('off')

plt.tight_layout()
plt.show()

# %%
num_cols = 3
num_rows = math.ceil(len(numerical_columns) / num_cols)

fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 10))

for i, column in enumerate(numerical_columns):
    row = i // num_cols
    col = i % num_cols
    sns.kdeplot(data=data, x=column, hue="target", 
                fill=True, alpha=.2, palette="YlOrRd", 
                common_norm=False, ax=axes[row, col],
                warn_singular=False)\
        .set_title(column)

for i in range(len(numerical_columns), num_rows * num_cols):
    row = i // num_cols
    col = i % num_cols
    axes[row, col].axis('off')

fig.suptitle('Distribution of Column Numeric Values based on Price Range', y=1.0, fontsize=16, fontweight='bold')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20, 10))

plt.scatter(data.age[data.target==1],
            data.thalach[data.target==1],
            c="salmon")

plt.scatter(data.age[data.target==0],
            data.thalach[data.target==0],
            c="lightblue")

plt.title("Heart Disease in function of Age and Max Heart Rate")
plt.xlabel("Age")
plt.ylabel("Max Heart Rate")
plt.legend(["Disease", "No Disease"])

# %%
sns.pairplot(data)

# %%
plt.subplots(figsize = (20,4))
ax = sns.countplot(data = data, x = 'target', palette='YlOrBr')
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '138'), Text(0, 0, '164')]

# %%
num_cols = 3
num_rows = math.ceil(len(numerical_columns) / num_cols)

fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 15))
for i, column in enumerate(numerical_columns):
    row = i // num_cols
    col = i % num_cols
    sns.boxplot(x=data[column], ax=axes[row, col], palette="Oranges").set_title(column)
    
for i in range(len(numerical_columns), num_rows * num_cols):
    row = i // num_cols
    col = i % num_cols
    axes[row, col].axis('off')

plt.tight_layout()
plt.show()

# %%
# Q1 = data['text_len'].quantile(0.25)
# Q3 = data['text_len'].quantile(1.)

# print(Q1)
# print(Q3)

# data = data[(data['text_len'] > Q1) & (data['text_len'] < Q3)]

# fig, axes = plt.subplots(figsize=(25, 2))
# sns.boxplot(x = data['text_len'], palette="Oranges")

# sns.stripplot(x=data['text_len'], data=data,
#               size=4, color=".3", linewidth=0, palette="crest", hue=data['text_len'])

# %% [markdown]
# ### 3.4. Data Correlation

# %%
corr_data = data[numerical_columns].corr().round(2)

mask = np.zeros_like(corr_data)
mask[np.triu_indices_from(mask)] = True

plt.figure(figsize=(25, 10))
# sns.heatmap(corr_data, annot=True, mask=mask, cmap='RdBu')
sns.heatmap(corr_data, annot=True, cmap='RdBu')
plt.title("Correlation Matrix", size=20)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# # 4. Data Preprocessing

# %% [markdown]
# ### 4.1. Features Selections

# %%
### Pearson Correlation
def cor_selector(X, y,num_feats):
    cor_list = []
    feature_name = X.columns.tolist()
    # calculate the correlation with y for each feature
    for i in X.columns.tolist():
        cor = np.corrcoef(X[i], y)[0, 1]
        cor_list.append(cor)
    # replace NaN with 0
    cor_list = [0 if np.isnan(i) else i for i in cor_list]
    # feature name
    cor_feature = X.iloc[:,np.argsort(np.abs(cor_list))[-num_feats:]].columns.tolist()
    # feature selection? 0 for not select, 1 for select
    cor_support = [True if i in cor_feature else False for i in feature_name]
    print(str(len(cor_feature)), 'selected features')
    print(cor_feature)
    return cor_feature

### Chi-Squared
def chi_squared_elimination(X, Y,num_feats):
    X_norm = MinMaxScaler().fit_transform(X)
    chi_selector = SelectKBest(chi2, k=num_feats)
    chi_selector.fit(X_norm, Y)
    chi_support = chi_selector.get_support()
    chi_feature = X.loc[:,chi_support].columns.tolist()
    print(str(len(chi_feature)), 'selected features')
    print(chi_feature)
    return chi_feature

### Recursive Feature Elimination
def recursive_elimination(X, Y,num_feats):
    X_norm = MinMaxScaler().fit_transform(X)
    rfe_selector = RFE(estimator=LogisticRegression(), n_features_to_select=num_feats, step=10, verbose=5)
    rfe_selector.fit(X_norm, Y)
    rfe_support = rfe_selector.get_support()
    rfe_feature = X.loc[:,rfe_support].columns.tolist()
    print(str(len(rfe_feature)), 'selected features')
    print(rfe_feature)
    return rfe_feature

### Lasso: SelectFromModel
def lasso_elimination(X, Y, num_feats):
    X_norm = MinMaxScaler().fit_transform(X)
    embeded_lr_selector = SelectFromModel(LogisticRegression(penalty="l2"), max_features=num_feats)
    embeded_lr_selector.fit(X_norm, Y)
    embeded_lr_support = embeded_lr_selector.get_support()
    embeded_lr_feature = X.loc[:,embeded_lr_support].columns.tolist()
    print(str(len(embeded_lr_feature)), 'selected features')
    print(embeded_lr_feature)
    return embeded_lr_feature

### LightGBM: SelectFromModel
def LGBMC_elimination(X, Y, num_feats):
    lgbc=LGBMClassifier(n_estimators=500, learning_rate=0.05, num_leaves=32, colsample_bytree=0.2,
                reg_alpha=3, reg_lambda=1, min_split_gain=0.01, min_child_weight=40)

    embeded_lgb_selector = SelectFromModel(lgbc, max_features=num_feats)
    embeded_lgb_selector.fit(X, Y)
    embeded_lgb_support = embeded_lgb_selector.get_support()
    embeded_lgb_feature = X.loc[:,embeded_lgb_support].columns.tolist()
    print(str(len(embeded_lgb_feature)), 'selected features')
    print(embeded_lgb_feature)
    return embeded_lgb_feature

### Tree-based: SelectFromModel
def RFC_elimination (X, Y, num_feats):
    embeded_rf_selector = SelectFromModel(RandomForestClassifier(n_estimators=100), max_features=num_feats)
    embeded_rf_selector.fit(X, Y)

    embeded_rf_support = embeded_rf_selector.get_support()
    embeded_rf_feature = X.loc[:,embeded_rf_support].columns.tolist()
    print(str(len(embeded_rf_feature)), 'selected features')
    print(embeded_rf_feature)
    return embeded_rf_feature

# %%
X = data.drop(columns=['Potability'])
Y = data['Potability']

num_feats = 10

selected_feature = cor_selector(X, Y,num_feats)
# selected_feature = chi_squared_elimination(X, Y,num_feats)
# selected_feature = recursive_elimination(X, Y,num_feats)
# selected_feature = lasso_elimination(X, Y, num_feats)
# selected_feature = LGBMC_elimination(X, Y, num_feats)
# selected_feature = RFC_elimination(X, Y, num_feats)

X = data[selected_feature]
Y = data['Credit_Score']


print(Counter(Y))
undersample = RandomUnderSampler()
X, Y = undersample.fit_resample(X, Y)
print(Counter(Y))

Y = to_categorical(Y)

scaler = MinMaxScaler(feature_range=(0,1))
X = scaler.fit_transform(X)

X_train, X_val, y_train, y_val = train_test_split(X, Y, train_size=0.9, random_state = 42)
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, train_size=0.78, random_state = 42)

print(X_train.shape)
print(X_test.shape)
print(X_val.shape)
# Out:
# 10 selected features
# ['Monthly_Balance', 'Num_Bank_Accounts', 'Credit_History_Age', 'Num_Credit_Card', 'Num_of_Loan', 'Delay_from_due_date', 'Outstanding_Debt', 'Interest_Rate', 'Num_Credit_Inquiries', 'Credit_Mix']
# Counter({0: 53174, 2: 28998, 1: 17828})
# Counter({0: 17828, 1: 17828, 2: 17828})
# (37545, 10)
# (10590, 10)
# (5349, 10)

# %% [markdown]
# # 5 Neural Network Algoritms

# %%
X = data.drop(columns=['target']).values
Y = data['target']

# print(Counter(Y))
# sampling = RandomUnderSampler()
# # sampling = SMOTE()
# X, Y = sampling.fit_resample(X, Y)
# print(Counter(Y))

Y = pd.get_dummies(Y).values

# scaler = MinMaxScaler(feature_range=(0,1))
scaler = PowerTransformer(method='yeo-johnson', standardize=True)
X = scaler.fit_transform(X)

X_train, X_val, y_train, y_val = train_test_split(X, Y, train_size=0.9, random_state = 42)
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, train_size=0.78, random_state = 42)

print(X_train.shape)
print(X_test.shape)
print(X_val.shape)

label = y_train.shape[1]
# Out:
# (211, 13)
# (60, 13)
# (31, 13)

# %%
def DNN_Model():
    model = Sequential()
    model.add(Dense(1024, activation='relu', kernel_regularizer=keras.regularizers.l2(l=0.001), input_shape=(X_train.shape[1],)))
    model.add(Dense(256, activation='relu', kernel_regularizer=keras.regularizers.l2(l=0.001)))
    model.add(Dense(64, activation='relu', kernel_regularizer=keras.regularizers.l2(l=0.001)))
    model.add(Dense(label, activation='softmax'))
    
    return model

def CNN_Model():
    model = Sequential()

    model.add(Conv1D(128, 3, kernel_regularizer=keras.regularizers.l2(l=0.001), input_shape=(X_train.shape[1], 1)))
    model.add(BatchNormalization())
    # model.add(LeakyReLU(0.2))
    model.add(ReLU())
    # model.add(Dropout(0.8))
    model.add(MaxPooling1D())

    # model.add(Conv1D(64, 3, kernel_regularizer=keras.regularizers.l2(l=0.001)))
    # model.add(BatchNormalization())
    # # model.add(LeakyReLU(0.2))
    # model.add(ReLU())
    # model.add(Dropout(0.5))
    # model.add(MaxPooling1D())

    model.add(Conv1D(64, 3, kernel_regularizer=keras.regularizers.l2(l=0.001)))
    model.add(BatchNormalization())
    # model.add(LeakyReLU(0.2))
    model.add(ReLU())
    # model.add(Dropout(0.5))
    model.add(MaxPooling1D())

    # model.add(Conv1D(16, 3, kernel_regularizer=keras.regularizers.l2(l=0.001)))
    # model.add(BatchNormalization())
    # # model.add(LeakyReLU(0.2))
    # model.add(ReLU())
    # # model.add(Dropout(0.5))
    # model.add(MaxPooling1D())

    model.add(Flatten())
    # model.add(Dense(4098, activation='relu'))
    model.add(Dense(128, activation='relu'))
    # model.add(Dropout(0.5))
    model.add(Dense(128, activation='relu'))
    # model.add(Dropout(0.5))
    model.add(Dense(label, activation='softmax'))
    return model

def LSTM_Model():
    model = Sequential()
    model.add((LSTM(256, return_sequences=True, input_shape=(X_train.shape[1], 1))))
    model.add((LSTM(256)))
    # model.add(Dense(32, activation='swish'))
    # model.add(Dropout(0.2))
    # model.add(Dropout(0.5))
    # model.add(Dense(16, activation='relu'))
    model.add(Dense(label, activation='sigmoid'))
    return model

def GRU_Model():
    model = Sequential()
    model.add(GRU(256, activation ='tanh', recurrent_activation ='sigmoid', recurrent_dropout = 0, unroll=False, use_bias=True, reset_after=True, return_sequences=True, input_shape = (X_train.shape[1],1)))
    model.add(GRU(256, activation ='tanh', recurrent_activation ='sigmoid', recurrent_dropout = 0, unroll=False, use_bias=True, reset_after=True))
    model.add(Dense(label, activation='softmax'))
    return model
    

model = DNN_Model()
# model = CNN_Model()
# model = LSTM_Model()
# model = GRU_Model()

model.summary()

# opt = RMSprop(learning_rate = 0.001)
# opt = SGD(learning_rate = 0.001)
opt = Adam(learning_rate = 0.000_001)

model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
# model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_11 (Dense)            (None, 1024)              14336
#
#  dense_12 (Dense)            (None, 256)               262400
#
#  dense_13 (Dense)            (None, 64)                16448
#
#  dense_14 (Dense)            (None, 2)                 130
#
# =================================================================
# Total params: 293,314
# Trainable params: 293,314
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epoch = 500
batch_size = 64

history = model.fit(X_train, y_train, 
                    batch_size = batch_size, epochs = num_epoch, 
                    validation_data = (X_test, y_test))
# Out:
# Epoch 1/500
# 4/4 [==============================] - 1s 70ms/step - loss: 1.2543 - accuracy: 0.3507 - val_loss: 1.2548 - val_accuracy: 0.3500
# Epoch 2/500
# 4/4 [==============================] - 0s 19ms/step - loss: 1.2538 - accuracy: 0.3555 - val_loss: 1.2543 - val_accuracy: 0.3500
# Epoch 3/500
# 4/4 [==============================] - 0s 20ms/step - loss: 1.2532 - accuracy: 0.3555 - val_loss: 1.2538 - val_accuracy: 0.3500
# Epoch 4/500
# 4/4 [==============================] - 0s 14ms/step - loss: 1.2527 - accuracy: 0.3555 - val_loss: 1.2534 - val_accuracy: 0.3500
# Epoch 5/500
# 4/4 [==============================] - 0s 22ms/step - loss: 1.2521 - accuracy: 0.3649 - val_loss: 1.2529 - val_accuracy: 0.3500
# Epoch 6/500
# 4/4 [==============================] - 0s 15ms/step - loss: 1.2516 - accuracy: 0.3649 - val_loss: 1.2525 - val_accuracy: 0.3500
# Epoch 7/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2511 - accuracy: 0.3697 - val_loss: 1.2520 - val_accuracy: 0.3500
# Epoch 8/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2506 - accuracy: 0.3697 - val_loss: 1.2516 - val_accuracy: 0.3833
# Epoch 9/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2501 - accuracy: 0.3697 - val_loss: 1.2511 - val_accuracy: 0.4000
# Epoch 10/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2495 - accuracy: 0.3697 - val_loss: 1.2506 - val_accuracy: 0.4000
# Epoch 11/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2490 - accuracy: 0.3697 - val_loss: 1.2502 - val_accuracy: 0.4167
# Epoch 12/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2485 - accuracy: 0.3697 - val_loss: 1.2497 - val_accuracy: 0.4167
# Epoch 13/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2480 - accuracy: 0.3697 - val_loss: 1.2492 - val_accuracy: 0.4167
# Epoch 14/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2474 - accuracy: 0.3791 - val_loss: 1.2488 - val_accuracy: 0.4167
# Epoch 15/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2469 - accuracy: 0.3839 - val_loss: 1.2483 - val_accuracy: 0.4167
# Epoch 16/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2464 - accuracy: 0.3934 - val_loss: 1.2479 - val_accuracy: 0.4167
# Epoch 17/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2459 - accuracy: 0.3934 - val_loss: 1.2474 - val_accuracy: 0.4167
# Epoch 18/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2454 - accuracy: 0.4076 - val_loss: 1.2469 - val_accuracy: 0.4167
# Epoch 19/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2449 - accuracy: 0.4123 - val_loss: 1.2465 - val_accuracy: 0.4333
# Epoch 20/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2444 - accuracy: 0.4123 - val_loss: 1.2460 - val_accuracy: 0.4333
# Epoch 21/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2438 - accuracy: 0.4123 - val_loss: 1.2456 - val_accuracy: 0.4500
# Epoch 22/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2434 - accuracy: 0.4171 - val_loss: 1.2451 - val_accuracy: 0.4500
# Epoch 23/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2429 - accuracy: 0.4218 - val_loss: 1.2447 - val_accuracy: 0.4833
# Epoch 24/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2424 - accuracy: 0.4265 - val_loss: 1.2443 - val_accuracy: 0.5000
# Epoch 25/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2419 - accuracy: 0.4360 - val_loss: 1.2438 - val_accuracy: 0.5000
# Epoch 26/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2414 - accuracy: 0.4360 - val_loss: 1.2434 - val_accuracy: 0.5000
# Epoch 27/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2409 - accuracy: 0.4408 - val_loss: 1.2429 - val_accuracy: 0.5000
# Epoch 28/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2404 - accuracy: 0.4408 - val_loss: 1.2425 - val_accuracy: 0.5000
# Epoch 29/500
# 4/4 [==============================] - 0s 12ms/step - loss: 1.2399 - accuracy: 0.4455 - val_loss: 1.2421 - val_accuracy: 0.5000
# Epoch 30/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.2394 - accuracy: 0.4455 - val_loss: 1.2416 - val_accuracy: 0.5167
# Epoch 31/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2389 - accuracy: 0.4455 - val_loss: 1.2412 - val_accuracy: 0.5000
# Epoch 32/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2384 - accuracy: 0.4455 - val_loss: 1.2407 - val_accuracy: 0.5167
# Epoch 33/500
# 4/4 [==============================] - 0s 9ms/step - loss: 1.2379 - accuracy: 0.4408 - val_loss: 1.2403 - val_accuracy: 0.5167
# Epoch 34/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2374 - accuracy: 0.4502 - val_loss: 1.2399 - val_accuracy: 0.5167
# Epoch 35/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2369 - accuracy: 0.4550 - val_loss: 1.2394 - val_accuracy: 0.5000
# Epoch 36/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2365 - accuracy: 0.4550 - val_loss: 1.2390 - val_accuracy: 0.5000
# Epoch 37/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2360 - accuracy: 0.4550 - val_loss: 1.2386 - val_accuracy: 0.5000
# Epoch 38/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2355 - accuracy: 0.4550 - val_loss: 1.2381 - val_accuracy: 0.5000
# Epoch 39/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2350 - accuracy: 0.4550 - val_loss: 1.2377 - val_accuracy: 0.5000
# Epoch 40/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2345 - accuracy: 0.4550 - val_loss: 1.2373 - val_accuracy: 0.5000
# Epoch 41/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2340 - accuracy: 0.4550 - val_loss: 1.2369 - val_accuracy: 0.5167
# Epoch 42/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2336 - accuracy: 0.4550 - val_loss: 1.2365 - val_accuracy: 0.5333
# Epoch 43/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2331 - accuracy: 0.4645 - val_loss: 1.2360 - val_accuracy: 0.5333
# Epoch 44/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2326 - accuracy: 0.4692 - val_loss: 1.2356 - val_accuracy: 0.5333
# Epoch 45/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2321 - accuracy: 0.4787 - val_loss: 1.2352 - val_accuracy: 0.5500
# Epoch 46/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2316 - accuracy: 0.4787 - val_loss: 1.2348 - val_accuracy: 0.5500
# Epoch 47/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2311 - accuracy: 0.4834 - val_loss: 1.2343 - val_accuracy: 0.5500
# Epoch 48/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2307 - accuracy: 0.4834 - val_loss: 1.2339 - val_accuracy: 0.5500
# Epoch 49/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2302 - accuracy: 0.4882 - val_loss: 1.2335 - val_accuracy: 0.5500
# Epoch 50/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2297 - accuracy: 0.4882 - val_loss: 1.2331 - val_accuracy: 0.5500
# Epoch 51/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2292 - accuracy: 0.4882 - val_loss: 1.2327 - val_accuracy: 0.5500
# Epoch 52/500
# 4/4 [==============================] - 0s 9ms/step - loss: 1.2287 - accuracy: 0.4929 - val_loss: 1.2323 - val_accuracy: 0.5500
# Epoch 53/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2283 - accuracy: 0.4929 - val_loss: 1.2318 - val_accuracy: 0.5500
# Epoch 54/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2278 - accuracy: 0.4929 - val_loss: 1.2314 - val_accuracy: 0.5500
# Epoch 55/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2273 - accuracy: 0.4976 - val_loss: 1.2310 - val_accuracy: 0.5500
# Epoch 56/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2268 - accuracy: 0.5071 - val_loss: 1.2306 - val_accuracy: 0.5500
# Epoch 57/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2263 - accuracy: 0.5118 - val_loss: 1.2301 - val_accuracy: 0.5500
# Epoch 58/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2259 - accuracy: 0.5118 - val_loss: 1.2297 - val_accuracy: 0.5667
# Epoch 59/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2254 - accuracy: 0.5166 - val_loss: 1.2293 - val_accuracy: 0.5667
# Epoch 60/500
# 4/4 [==============================] - 0s 19ms/step - loss: 1.2249 - accuracy: 0.5213 - val_loss: 1.2289 - val_accuracy: 0.5667
# Epoch 61/500
# 4/4 [==============================] - 0s 9ms/step - loss: 1.2245 - accuracy: 0.5213 - val_loss: 1.2284 - val_accuracy: 0.5667
# Epoch 62/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2240 - accuracy: 0.5261 - val_loss: 1.2280 - val_accuracy: 0.5833
# Epoch 63/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2235 - accuracy: 0.5261 - val_loss: 1.2276 - val_accuracy: 0.5833
# Epoch 64/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2231 - accuracy: 0.5308 - val_loss: 1.2272 - val_accuracy: 0.5833
# Epoch 65/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2226 - accuracy: 0.5355 - val_loss: 1.2268 - val_accuracy: 0.5833
# Epoch 66/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2221 - accuracy: 0.5498 - val_loss: 1.2264 - val_accuracy: 0.5833
# Epoch 67/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2217 - accuracy: 0.5498 - val_loss: 1.2260 - val_accuracy: 0.5833
# Epoch 68/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2212 - accuracy: 0.5545 - val_loss: 1.2256 - val_accuracy: 0.5833
# Epoch 69/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2207 - accuracy: 0.5545 - val_loss: 1.2252 - val_accuracy: 0.5833
# Epoch 70/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2203 - accuracy: 0.5640 - val_loss: 1.2247 - val_accuracy: 0.5833
# Epoch 71/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2198 - accuracy: 0.5640 - val_loss: 1.2243 - val_accuracy: 0.5833
# Epoch 72/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2193 - accuracy: 0.5640 - val_loss: 1.2239 - val_accuracy: 0.5833
# Epoch 73/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2188 - accuracy: 0.5640 - val_loss: 1.2235 - val_accuracy: 0.5833
# Epoch 74/500
# 4/4 [==============================] - 0s 18ms/step - loss: 1.2184 - accuracy: 0.5687 - val_loss: 1.2231 - val_accuracy: 0.5833
# Epoch 75/500
# 4/4 [==============================] - 0s 13ms/step - loss: 1.2179 - accuracy: 0.5687 - val_loss: 1.2226 - val_accuracy: 0.5833
# Epoch 76/500
# 4/4 [==============================] - 0s 15ms/step - loss: 1.2175 - accuracy: 0.5735 - val_loss: 1.2222 - val_accuracy: 0.6000
# Epoch 77/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2170 - accuracy: 0.5735 - val_loss: 1.2218 - val_accuracy: 0.6000
# Epoch 78/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2165 - accuracy: 0.5877 - val_loss: 1.2214 - val_accuracy: 0.6000
# Epoch 79/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2160 - accuracy: 0.5924 - val_loss: 1.2210 - val_accuracy: 0.6000
# Epoch 80/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2156 - accuracy: 0.5924 - val_loss: 1.2206 - val_accuracy: 0.6000
# Epoch 81/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2151 - accuracy: 0.5972 - val_loss: 1.2201 - val_accuracy: 0.6167
# Epoch 82/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2147 - accuracy: 0.6066 - val_loss: 1.2197 - val_accuracy: 0.6167
# Epoch 83/500
# 4/4 [==============================] - 0s 17ms/step - loss: 1.2142 - accuracy: 0.6066 - val_loss: 1.2193 - val_accuracy: 0.6333
# Epoch 84/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2138 - accuracy: 0.6114 - val_loss: 1.2189 - val_accuracy: 0.6500
# Epoch 85/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2133 - accuracy: 0.6114 - val_loss: 1.2184 - val_accuracy: 0.6500
# Epoch 86/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2128 - accuracy: 0.6114 - val_loss: 1.2180 - val_accuracy: 0.6500
# Epoch 87/500
# 4/4 [==============================] - 0s 12ms/step - loss: 1.2124 - accuracy: 0.6114 - val_loss: 1.2176 - val_accuracy: 0.6500
# Epoch 88/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2119 - accuracy: 0.6114 - val_loss: 1.2172 - val_accuracy: 0.6500
# Epoch 89/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2115 - accuracy: 0.6161 - val_loss: 1.2168 - val_accuracy: 0.6500
# Epoch 90/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2110 - accuracy: 0.6161 - val_loss: 1.2163 - val_accuracy: 0.6500
# Epoch 91/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2106 - accuracy: 0.6256 - val_loss: 1.2159 - val_accuracy: 0.6500
# Epoch 92/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2101 - accuracy: 0.6398 - val_loss: 1.2155 - val_accuracy: 0.6333
# Epoch 93/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2096 - accuracy: 0.6445 - val_loss: 1.2150 - val_accuracy: 0.6333
# Epoch 94/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2092 - accuracy: 0.6493 - val_loss: 1.2146 - val_accuracy: 0.6333
# Epoch 95/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2087 - accuracy: 0.6540 - val_loss: 1.2142 - val_accuracy: 0.6500
# Epoch 96/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2083 - accuracy: 0.6588 - val_loss: 1.2138 - val_accuracy: 0.6500
# Epoch 97/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2078 - accuracy: 0.6635 - val_loss: 1.2134 - val_accuracy: 0.6500
# Epoch 98/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2073 - accuracy: 0.6682 - val_loss: 1.2130 - val_accuracy: 0.6500
# Epoch 99/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2069 - accuracy: 0.6730 - val_loss: 1.2125 - val_accuracy: 0.6500
# Epoch 100/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2064 - accuracy: 0.6730 - val_loss: 1.2121 - val_accuracy: 0.6500
# Epoch 101/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2060 - accuracy: 0.6730 - val_loss: 1.2117 - val_accuracy: 0.6500
# Epoch 102/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2055 - accuracy: 0.6777 - val_loss: 1.2113 - val_accuracy: 0.6667
# Epoch 103/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2051 - accuracy: 0.6777 - val_loss: 1.2109 - val_accuracy: 0.6667
# Epoch 104/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2046 - accuracy: 0.6825 - val_loss: 1.2105 - val_accuracy: 0.6667
# Epoch 105/500
# 4/4 [==============================] - 0s 21ms/step - loss: 1.2042 - accuracy: 0.6872 - val_loss: 1.2101 - val_accuracy: 0.6667
# Epoch 106/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2037 - accuracy: 0.6825 - val_loss: 1.2097 - val_accuracy: 0.6667
# Epoch 107/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2032 - accuracy: 0.6872 - val_loss: 1.2092 - val_accuracy: 0.6667
# Epoch 108/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2028 - accuracy: 0.6872 - val_loss: 1.2088 - val_accuracy: 0.6667
# Epoch 109/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2023 - accuracy: 0.6919 - val_loss: 1.2084 - val_accuracy: 0.6667
# Epoch 110/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2019 - accuracy: 0.7062 - val_loss: 1.2080 - val_accuracy: 0.6667
# Epoch 111/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2014 - accuracy: 0.7062 - val_loss: 1.2075 - val_accuracy: 0.6667
# Epoch 112/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2010 - accuracy: 0.7062 - val_loss: 1.2071 - val_accuracy: 0.6833
# Epoch 113/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2005 - accuracy: 0.7062 - val_loss: 1.2067 - val_accuracy: 0.6833
# Epoch 114/500
# 4/4 [==============================] - 0s 12ms/step - loss: 1.2000 - accuracy: 0.7062 - val_loss: 1.2063 - val_accuracy: 0.6833
# Epoch 115/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1996 - accuracy: 0.7062 - val_loss: 1.2058 - val_accuracy: 0.6833
# Epoch 116/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1991 - accuracy: 0.7156 - val_loss: 1.2054 - val_accuracy: 0.7000
# Epoch 117/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1987 - accuracy: 0.7156 - val_loss: 1.2050 - val_accuracy: 0.7000
# Epoch 118/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1982 - accuracy: 0.7156 - val_loss: 1.2046 - val_accuracy: 0.7167
# Epoch 119/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1978 - accuracy: 0.7204 - val_loss: 1.2042 - val_accuracy: 0.7167
# Epoch 120/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1973 - accuracy: 0.7156 - val_loss: 1.2038 - val_accuracy: 0.7167
# Epoch 121/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1969 - accuracy: 0.7156 - val_loss: 1.2034 - val_accuracy: 0.7167
# Epoch 122/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1964 - accuracy: 0.7156 - val_loss: 1.2030 - val_accuracy: 0.7167
# Epoch 123/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1960 - accuracy: 0.7156 - val_loss: 1.2026 - val_accuracy: 0.7167
# Epoch 124/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1955 - accuracy: 0.7156 - val_loss: 1.2021 - val_accuracy: 0.7167
# Epoch 125/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1951 - accuracy: 0.7156 - val_loss: 1.2017 - val_accuracy: 0.7167
# Epoch 126/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1946 - accuracy: 0.7156 - val_loss: 1.2013 - val_accuracy: 0.7167
# Epoch 127/500
# 4/4 [==============================] - 0s 14ms/step - loss: 1.1942 - accuracy: 0.7156 - val_loss: 1.2009 - val_accuracy: 0.7333
# Epoch 128/500
# 4/4 [==============================] - 0s 17ms/step - loss: 1.1937 - accuracy: 0.7204 - val_loss: 1.2004 - val_accuracy: 0.7333
# Epoch 129/500
# 4/4 [==============================] - 0s 13ms/step - loss: 1.1932 - accuracy: 0.7251 - val_loss: 1.2000 - val_accuracy: 0.7333
# Epoch 130/500
# 4/4 [==============================] - 0s 14ms/step - loss: 1.1928 - accuracy: 0.7251 - val_loss: 1.1996 - val_accuracy: 0.7333
# Epoch 131/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1923 - accuracy: 0.7251 - val_loss: 1.1991 - val_accuracy: 0.7333
# Epoch 132/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1919 - accuracy: 0.7251 - val_loss: 1.1987 - val_accuracy: 0.7333
# Epoch 133/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1914 - accuracy: 0.7299 - val_loss: 1.1983 - val_accuracy: 0.7333
# Epoch 134/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1909 - accuracy: 0.7346 - val_loss: 1.1979 - val_accuracy: 0.7333
# Epoch 135/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1905 - accuracy: 0.7346 - val_loss: 1.1975 - val_accuracy: 0.7333
# Epoch 136/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1900 - accuracy: 0.7393 - val_loss: 1.1970 - val_accuracy: 0.7333
# Epoch 137/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1895 - accuracy: 0.7393 - val_loss: 1.1966 - val_accuracy: 0.7333
# Epoch 138/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1891 - accuracy: 0.7488 - val_loss: 1.1962 - val_accuracy: 0.7333
# Epoch 139/500
# 4/4 [==============================] - 0s 13ms/step - loss: 1.1886 - accuracy: 0.7536 - val_loss: 1.1957 - val_accuracy: 0.7333
# Epoch 140/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1882 - accuracy: 0.7536 - val_loss: 1.1953 - val_accuracy: 0.7333
# Epoch 141/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1877 - accuracy: 0.7536 - val_loss: 1.1949 - val_accuracy: 0.7333
# Epoch 142/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1872 - accuracy: 0.7536 - val_loss: 1.1944 - val_accuracy: 0.7333
# Epoch 143/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1868 - accuracy: 0.7536 - val_loss: 1.1940 - val_accuracy: 0.7333
# Epoch 144/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1863 - accuracy: 0.7488 - val_loss: 1.1936 - val_accuracy: 0.7333
# Epoch 145/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1859 - accuracy: 0.7488 - val_loss: 1.1932 - val_accuracy: 0.7333
# Epoch 146/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1854 - accuracy: 0.7536 - val_loss: 1.1927 - val_accuracy: 0.7333
# Epoch 147/500
# 4/4 [==============================] - 0s 9ms/step - loss: 1.1849 - accuracy: 0.7536 - val_loss: 1.1923 - val_accuracy: 0.7333
# Epoch 148/500
# 4/4 [==============================] - 0s 14ms/step - loss: 1.1845 - accuracy: 0.7536 - val_loss: 1.1919 - val_accuracy: 0.7333
# Epoch 149/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1841 - accuracy: 0.7536 - val_loss: 1.1915 - val_accuracy: 0.7333
# Epoch 150/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1836 - accuracy: 0.7536 - val_loss: 1.1911 - val_accuracy: 0.7500
# Epoch 151/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1832 - accuracy: 0.7536 - val_loss: 1.1907 - val_accuracy: 0.7500
# Epoch 152/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1827 - accuracy: 0.7536 - val_loss: 1.1903 - val_accuracy: 0.7667
# Epoch 153/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1822 - accuracy: 0.7536 - val_loss: 1.1898 - val_accuracy: 0.7667
# Epoch 154/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1818 - accuracy: 0.7678 - val_loss: 1.1894 - val_accuracy: 0.7667
# Epoch 155/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1813 - accuracy: 0.7773 - val_loss: 1.1890 - val_accuracy: 0.7667
# Epoch 156/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1809 - accuracy: 0.7773 - val_loss: 1.1886 - val_accuracy: 0.7667
# Epoch 157/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1805 - accuracy: 0.7773 - val_loss: 1.1881 - val_accuracy: 0.7667
# Epoch 158/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1800 - accuracy: 0.7773 - val_loss: 1.1877 - val_accuracy: 0.7667
# Epoch 159/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1796 - accuracy: 0.7773 - val_loss: 1.1873 - val_accuracy: 0.7667
# Epoch 160/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1791 - accuracy: 0.7820 - val_loss: 1.1869 - val_accuracy: 0.7500
# Epoch 161/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1787 - accuracy: 0.7820 - val_loss: 1.1865 - val_accuracy: 0.7500
# Epoch 162/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1782 - accuracy: 0.7820 - val_loss: 1.1861 - val_accuracy: 0.7500
# Epoch 163/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1778 - accuracy: 0.7820 - val_loss: 1.1856 - val_accuracy: 0.7500
# Epoch 164/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1773 - accuracy: 0.7820 - val_loss: 1.1852 - val_accuracy: 0.7500
# Epoch 165/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1769 - accuracy: 0.7820 - val_loss: 1.1847 - val_accuracy: 0.7500
# Epoch 166/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1764 - accuracy: 0.7820 - val_loss: 1.1843 - val_accuracy: 0.7500
# Epoch 167/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1759 - accuracy: 0.7820 - val_loss: 1.1839 - val_accuracy: 0.7500
# Epoch 168/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1755 - accuracy: 0.7820 - val_loss: 1.1834 - val_accuracy: 0.7500
# Epoch 169/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1750 - accuracy: 0.7820 - val_loss: 1.1830 - val_accuracy: 0.7500
# Epoch 170/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.1746 - accuracy: 0.7820 - val_loss: 1.1826 - val_accuracy: 0.7500
# Epoch 171/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1742 - accuracy: 0.7820 - val_loss: 1.1822 - val_accuracy: 0.7500
# Epoch 172/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1737 - accuracy: 0.7820 - val_loss: 1.1818 - val_accuracy: 0.7500
# Epoch 173/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1732 - accuracy: 0.7820 - val_loss: 1.1813 - val_accuracy: 0.7500
# Epoch 174/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1728 - accuracy: 0.7820 - val_loss: 1.1809 - val_accuracy: 0.7500
# Epoch 175/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1723 - accuracy: 0.7820 - val_loss: 1.1805 - val_accuracy: 0.7500
# Epoch 176/500
# 4/4 [==============================] - 0s 15ms/step - loss: 1.1719 - accuracy: 0.7820 - val_loss: 1.1801 - val_accuracy: 0.7500
# Epoch 177/500
# 4/4 [==============================] - 0s 20ms/step - loss: 1.1714 - accuracy: 0.7867 - val_loss: 1.1796 - val_accuracy: 0.7500
# Epoch 178/500
# 4/4 [==============================] - 0s 14ms/step - loss: 1.1710 - accuracy: 0.7867 - val_loss: 1.1792 - val_accuracy: 0.7500
# Epoch 179/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1705 - accuracy: 0.7867 - val_loss: 1.1788 - val_accuracy: 0.7500
# Epoch 180/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1701 - accuracy: 0.7867 - val_loss: 1.1784 - val_accuracy: 0.7500
# Epoch 181/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1696 - accuracy: 0.7867 - val_loss: 1.1780 - val_accuracy: 0.7500
# Epoch 182/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1692 - accuracy: 0.7867 - val_loss: 1.1776 - val_accuracy: 0.7500
# Epoch 183/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1688 - accuracy: 0.7820 - val_loss: 1.1771 - val_accuracy: 0.7500
# Epoch 184/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1683 - accuracy: 0.7820 - val_loss: 1.1767 - val_accuracy: 0.7500
# Epoch 185/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1679 - accuracy: 0.7820 - val_loss: 1.1763 - val_accuracy: 0.7500
# Epoch 186/500
# 4/4 [==============================] - 0s 12ms/step - loss: 1.1674 - accuracy: 0.7820 - val_loss: 1.1759 - val_accuracy: 0.7500
# Epoch 187/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1670 - accuracy: 0.7820 - val_loss: 1.1755 - val_accuracy: 0.7500
# Epoch 188/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1665 - accuracy: 0.7820 - val_loss: 1.1750 - val_accuracy: 0.7500
# Epoch 189/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1661 - accuracy: 0.7820 - val_loss: 1.1746 - val_accuracy: 0.7500
# Epoch 190/500
# 4/4 [==============================] - 0s 23ms/step - loss: 1.1656 - accuracy: 0.7820 - val_loss: 1.1742 - val_accuracy: 0.7500
# Epoch 191/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1652 - accuracy: 0.7867 - val_loss: 1.1737 - val_accuracy: 0.7500
# Epoch 192/500
# 4/4 [==============================] - 0s 12ms/step - loss: 1.1647 - accuracy: 0.7915 - val_loss: 1.1733 - val_accuracy: 0.7500
# Epoch 193/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1643 - accuracy: 0.7915 - val_loss: 1.1729 - val_accuracy: 0.7500
# Epoch 194/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1638 - accuracy: 0.7915 - val_loss: 1.1725 - val_accuracy: 0.7500
# Epoch 195/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1634 - accuracy: 0.7915 - val_loss: 1.1721 - val_accuracy: 0.7667
# Epoch 196/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1629 - accuracy: 0.7915 - val_loss: 1.1717 - val_accuracy: 0.7667
# Epoch 197/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1625 - accuracy: 0.7915 - val_loss: 1.1713 - val_accuracy: 0.7667
# Epoch 198/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1621 - accuracy: 0.7915 - val_loss: 1.1709 - val_accuracy: 0.7667
# Epoch 199/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1616 - accuracy: 0.7915 - val_loss: 1.1705 - val_accuracy: 0.7667
# Epoch 200/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1612 - accuracy: 0.7962 - val_loss: 1.1701 - val_accuracy: 0.7667
# Epoch 201/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1608 - accuracy: 0.7962 - val_loss: 1.1697 - val_accuracy: 0.7667
# Epoch 202/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1603 - accuracy: 0.7962 - val_loss: 1.1693 - val_accuracy: 0.7667
# Epoch 203/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1599 - accuracy: 0.7915 - val_loss: 1.1689 - val_accuracy: 0.7667
# Epoch 204/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1594 - accuracy: 0.7915 - val_loss: 1.1684 - val_accuracy: 0.7667
# Epoch 205/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1590 - accuracy: 0.7915 - val_loss: 1.1680 - val_accuracy: 0.7667
# Epoch 206/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1586 - accuracy: 0.7915 - val_loss: 1.1676 - val_accuracy: 0.7667
# Epoch 207/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1581 - accuracy: 0.7962 - val_loss: 1.1672 - val_accuracy: 0.7667
# Epoch 208/500
# 4/4 [==============================] - 0s 20ms/step - loss: 1.1577 - accuracy: 0.7962 - val_loss: 1.1668 - val_accuracy: 0.7667
# Epoch 209/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1572 - accuracy: 0.7962 - val_loss: 1.1664 - val_accuracy: 0.7667
# Epoch 210/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1568 - accuracy: 0.7962 - val_loss: 1.1660 - val_accuracy: 0.7667
# Epoch 211/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1563 - accuracy: 0.7962 - val_loss: 1.1656 - val_accuracy: 0.7667
# Epoch 212/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1559 - accuracy: 0.7962 - val_loss: 1.1651 - val_accuracy: 0.7667
# Epoch 213/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1555 - accuracy: 0.7962 - val_loss: 1.1647 - val_accuracy: 0.7667
# Epoch 214/500
# 4/4 [==============================] - 0s 12ms/step - loss: 1.1550 - accuracy: 0.7962 - val_loss: 1.1643 - val_accuracy: 0.7667
# Epoch 215/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1546 - accuracy: 0.7962 - val_loss: 1.1639 - val_accuracy: 0.7667
# Epoch 216/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1541 - accuracy: 0.7962 - val_loss: 1.1635 - val_accuracy: 0.7667
# Epoch 217/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1537 - accuracy: 0.7962 - val_loss: 1.1631 - val_accuracy: 0.7667
# Epoch 218/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1532 - accuracy: 0.7962 - val_loss: 1.1627 - val_accuracy: 0.7667
# Epoch 219/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1528 - accuracy: 0.7962 - val_loss: 1.1623 - val_accuracy: 0.7667
# Epoch 220/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1524 - accuracy: 0.7962 - val_loss: 1.1619 - val_accuracy: 0.7667
# Epoch 221/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1519 - accuracy: 0.7962 - val_loss: 1.1615 - val_accuracy: 0.7667
# Epoch 222/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1515 - accuracy: 0.7962 - val_loss: 1.1611 - val_accuracy: 0.7833
# Epoch 223/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1510 - accuracy: 0.8009 - val_loss: 1.1607 - val_accuracy: 0.7833
# Epoch 224/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1506 - accuracy: 0.8009 - val_loss: 1.1603 - val_accuracy: 0.8000
# Epoch 225/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1502 - accuracy: 0.8009 - val_loss: 1.1599 - val_accuracy: 0.8000
# Epoch 226/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1497 - accuracy: 0.8009 - val_loss: 1.1595 - val_accuracy: 0.8000
# Epoch 227/500
# 4/4 [==============================] - 0s 19ms/step - loss: 1.1493 - accuracy: 0.8009 - val_loss: 1.1591 - val_accuracy: 0.8000
# Epoch 228/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1488 - accuracy: 0.8009 - val_loss: 1.1587 - val_accuracy: 0.8000
# Epoch 229/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1484 - accuracy: 0.8009 - val_loss: 1.1583 - val_accuracy: 0.8000
# Epoch 230/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1480 - accuracy: 0.8009 - val_loss: 1.1579 - val_accuracy: 0.8000
# Epoch 231/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1475 - accuracy: 0.8009 - val_loss: 1.1575 - val_accuracy: 0.8000
# Epoch 232/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1471 - accuracy: 0.8009 - val_loss: 1.1571 - val_accuracy: 0.8000
# Epoch 233/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1466 - accuracy: 0.8057 - val_loss: 1.1567 - val_accuracy: 0.8000
# Epoch 234/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1462 - accuracy: 0.8057 - val_loss: 1.1563 - val_accuracy: 0.8000
# Epoch 235/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1457 - accuracy: 0.8057 - val_loss: 1.1558 - val_accuracy: 0.8000
# Epoch 236/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1453 - accuracy: 0.8057 - val_loss: 1.1554 - val_accuracy: 0.8000
# Epoch 237/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1449 - accuracy: 0.8057 - val_loss: 1.1550 - val_accuracy: 0.8000
# Epoch 238/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1444 - accuracy: 0.8057 - val_loss: 1.1546 - val_accuracy: 0.8000
# Epoch 239/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1440 - accuracy: 0.8057 - val_loss: 1.1542 - val_accuracy: 0.8000
# Epoch 240/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1435 - accuracy: 0.8057 - val_loss: 1.1538 - val_accuracy: 0.8000
# Epoch 241/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1431 - accuracy: 0.8104 - val_loss: 1.1535 - val_accuracy: 0.8000
# Epoch 242/500
# 4/4 [==============================] - 0s 12ms/step - loss: 1.1427 - accuracy: 0.8152 - val_loss: 1.1531 - val_accuracy: 0.8000
# Epoch 243/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1423 - accuracy: 0.8152 - val_loss: 1.1527 - val_accuracy: 0.8000
# Epoch 244/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1418 - accuracy: 0.8152 - val_loss: 1.1523 - val_accuracy: 0.8000
# Epoch 245/500
# 4/4 [==============================] - 0s 12ms/step - loss: 1.1414 - accuracy: 0.8152 - val_loss: 1.1519 - val_accuracy: 0.8000
# Epoch 246/500
# 4/4 [==============================] - 0s 20ms/step - loss: 1.1410 - accuracy: 0.8152 - val_loss: 1.1515 - val_accuracy: 0.8000
# Epoch 247/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1405 - accuracy: 0.8152 - val_loss: 1.1511 - val_accuracy: 0.8000
# Epoch 248/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1401 - accuracy: 0.8152 - val_loss: 1.1507 - val_accuracy: 0.8000
# Epoch 249/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1397 - accuracy: 0.8152 - val_loss: 1.1503 - val_accuracy: 0.8000
# Epoch 250/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1392 - accuracy: 0.8152 - val_loss: 1.1500 - val_accuracy: 0.8000
# Epoch 251/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1388 - accuracy: 0.8152 - val_loss: 1.1496 - val_accuracy: 0.8000
# Epoch 252/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1384 - accuracy: 0.8152 - val_loss: 1.1492 - val_accuracy: 0.8000
# Epoch 253/500
# 4/4 [==============================] - 0s 12ms/step - loss: 1.1379 - accuracy: 0.8152 - val_loss: 1.1488 - val_accuracy: 0.8000
# Epoch 254/500
# 4/4 [==============================] - 0s 12ms/step - loss: 1.1375 - accuracy: 0.8199 - val_loss: 1.1484 - val_accuracy: 0.8000
# Epoch 255/500
# 4/4 [==============================] - 0s 18ms/step - loss: 1.1370 - accuracy: 0.8199 - val_loss: 1.1480 - val_accuracy: 0.8000
# Epoch 256/500
# 4/4 [==============================] - 0s 12ms/step - loss: 1.1366 - accuracy: 0.8199 - val_loss: 1.1476 - val_accuracy: 0.8000
# Epoch 257/500
# 4/4 [==============================] - 0s 15ms/step - loss: 1.1362 - accuracy: 0.8199 - val_loss: 1.1472 - val_accuracy: 0.8000
# Epoch 258/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.1357 - accuracy: 0.8246 - val_loss: 1.1468 - val_accuracy: 0.8000
# Epoch 259/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1353 - accuracy: 0.8246 - val_loss: 1.1464 - val_accuracy: 0.8000
# Epoch 260/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1348 - accuracy: 0.8246 - val_loss: 1.1460 - val_accuracy: 0.8000
# Epoch 261/500
# 4/4 [==============================] - 0s 20ms/step - loss: 1.1344 - accuracy: 0.8246 - val_loss: 1.1457 - val_accuracy: 0.8000
# Epoch 262/500
# 4/4 [==============================] - 0s 14ms/step - loss: 1.1340 - accuracy: 0.8294 - val_loss: 1.1453 - val_accuracy: 0.8000
# Epoch 263/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1336 - accuracy: 0.8294 - val_loss: 1.1449 - val_accuracy: 0.8000
# Epoch 264/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1331 - accuracy: 0.8294 - val_loss: 1.1445 - val_accuracy: 0.8000
# Epoch 265/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1327 - accuracy: 0.8341 - val_loss: 1.1441 - val_accuracy: 0.8000
# Epoch 266/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1323 - accuracy: 0.8341 - val_loss: 1.1438 - val_accuracy: 0.8000
# Epoch 267/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1319 - accuracy: 0.8341 - val_loss: 1.1434 - val_accuracy: 0.8000
# Epoch 268/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1314 - accuracy: 0.8341 - val_loss: 1.1430 - val_accuracy: 0.8000
# Epoch 269/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1310 - accuracy: 0.8341 - val_loss: 1.1426 - val_accuracy: 0.8000
# Epoch 270/500
# 4/4 [==============================] - 0s 12ms/step - loss: 1.1306 - accuracy: 0.8341 - val_loss: 1.1423 - val_accuracy: 0.8000
# Epoch 271/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1302 - accuracy: 0.8341 - val_loss: 1.1419 - val_accuracy: 0.8000
# Epoch 272/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1297 - accuracy: 0.8341 - val_loss: 1.1415 - val_accuracy: 0.8000
# Epoch 273/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1293 - accuracy: 0.8389 - val_loss: 1.1411 - val_accuracy: 0.8000
# Epoch 274/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1289 - accuracy: 0.8389 - val_loss: 1.1408 - val_accuracy: 0.8000
# Epoch 275/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1285 - accuracy: 0.8389 - val_loss: 1.1404 - val_accuracy: 0.8000
# Epoch 276/500
# 4/4 [==============================] - 0s 12ms/step - loss: 1.1281 - accuracy: 0.8389 - val_loss: 1.1400 - val_accuracy: 0.8000
# Epoch 277/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1277 - accuracy: 0.8389 - val_loss: 1.1397 - val_accuracy: 0.8000
# Epoch 278/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1272 - accuracy: 0.8389 - val_loss: 1.1393 - val_accuracy: 0.8000
# Epoch 279/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1268 - accuracy: 0.8389 - val_loss: 1.1389 - val_accuracy: 0.8000
# Epoch 280/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1264 - accuracy: 0.8389 - val_loss: 1.1385 - val_accuracy: 0.8000
# Epoch 281/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1260 - accuracy: 0.8389 - val_loss: 1.1382 - val_accuracy: 0.8000
# Epoch 282/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1256 - accuracy: 0.8389 - val_loss: 1.1378 - val_accuracy: 0.8000
# Epoch 283/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1251 - accuracy: 0.8389 - val_loss: 1.1374 - val_accuracy: 0.8000
# Epoch 284/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1247 - accuracy: 0.8389 - val_loss: 1.1370 - val_accuracy: 0.8000
# Epoch 285/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1243 - accuracy: 0.8389 - val_loss: 1.1367 - val_accuracy: 0.8000
# Epoch 286/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1239 - accuracy: 0.8389 - val_loss: 1.1363 - val_accuracy: 0.8000
# Epoch 287/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1235 - accuracy: 0.8389 - val_loss: 1.1360 - val_accuracy: 0.8000
# Epoch 288/500
# 4/4 [==============================] - 0s 9ms/step - loss: 1.1231 - accuracy: 0.8389 - val_loss: 1.1356 - val_accuracy: 0.8000
# Epoch 289/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1226 - accuracy: 0.8389 - val_loss: 1.1352 - val_accuracy: 0.8000
# Epoch 290/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1222 - accuracy: 0.8389 - val_loss: 1.1348 - val_accuracy: 0.8000
# Epoch 291/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1218 - accuracy: 0.8389 - val_loss: 1.1345 - val_accuracy: 0.8000
# Epoch 292/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1214 - accuracy: 0.8389 - val_loss: 1.1341 - val_accuracy: 0.8000
# Epoch 293/500
# 4/4 [==============================] - 0s 18ms/step - loss: 1.1210 - accuracy: 0.8389 - val_loss: 1.1337 - val_accuracy: 0.8000
# Epoch 294/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1206 - accuracy: 0.8389 - val_loss: 1.1333 - val_accuracy: 0.8000
# Epoch 295/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1201 - accuracy: 0.8389 - val_loss: 1.1330 - val_accuracy: 0.8000
# Epoch 296/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1197 - accuracy: 0.8389 - val_loss: 1.1326 - val_accuracy: 0.8000
# Epoch 297/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1193 - accuracy: 0.8389 - val_loss: 1.1323 - val_accuracy: 0.8000
# Epoch 298/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1189 - accuracy: 0.8389 - val_loss: 1.1319 - val_accuracy: 0.8000
# Epoch 299/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1185 - accuracy: 0.8389 - val_loss: 1.1315 - val_accuracy: 0.8000
# Epoch 300/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1180 - accuracy: 0.8389 - val_loss: 1.1311 - val_accuracy: 0.8000
# Epoch 301/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1176 - accuracy: 0.8389 - val_loss: 1.1308 - val_accuracy: 0.8000
# Epoch 302/500
# 4/4 [==============================] - 0s 12ms/step - loss: 1.1172 - accuracy: 0.8389 - val_loss: 1.1304 - val_accuracy: 0.8000
# Epoch 303/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1168 - accuracy: 0.8389 - val_loss: 1.1300 - val_accuracy: 0.8000
# Epoch 304/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1163 - accuracy: 0.8389 - val_loss: 1.1296 - val_accuracy: 0.8000
# Epoch 305/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1159 - accuracy: 0.8389 - val_loss: 1.1292 - val_accuracy: 0.8000
# Epoch 306/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1155 - accuracy: 0.8436 - val_loss: 1.1289 - val_accuracy: 0.8000
# Epoch 307/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1151 - accuracy: 0.8436 - val_loss: 1.1285 - val_accuracy: 0.8000
# Epoch 308/500
# 4/4 [==============================] - 0s 28ms/step - loss: 1.1147 - accuracy: 0.8436 - val_loss: 1.1281 - val_accuracy: 0.8000
# Epoch 309/500
# 4/4 [==============================] - 0s 14ms/step - loss: 1.1142 - accuracy: 0.8436 - val_loss: 1.1278 - val_accuracy: 0.8000
# Epoch 310/500
# 4/4 [==============================] - 0s 18ms/step - loss: 1.1138 - accuracy: 0.8436 - val_loss: 1.1274 - val_accuracy: 0.8000
# Epoch 311/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1134 - accuracy: 0.8436 - val_loss: 1.1270 - val_accuracy: 0.8000
# Epoch 312/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1130 - accuracy: 0.8436 - val_loss: 1.1267 - val_accuracy: 0.8000
# Epoch 313/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1126 - accuracy: 0.8483 - val_loss: 1.1263 - val_accuracy: 0.8000
# Epoch 314/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1122 - accuracy: 0.8483 - val_loss: 1.1260 - val_accuracy: 0.8000
# Epoch 315/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1118 - accuracy: 0.8483 - val_loss: 1.1256 - val_accuracy: 0.8000
# Epoch 316/500
# 4/4 [==============================] - 0s 9ms/step - loss: 1.1114 - accuracy: 0.8483 - val_loss: 1.1253 - val_accuracy: 0.8000
# Epoch 317/500
# 4/4 [==============================] - 0s 12ms/step - loss: 1.1110 - accuracy: 0.8483 - val_loss: 1.1249 - val_accuracy: 0.8000
# Epoch 318/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1106 - accuracy: 0.8483 - val_loss: 1.1245 - val_accuracy: 0.8000
# Epoch 319/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1101 - accuracy: 0.8483 - val_loss: 1.1242 - val_accuracy: 0.8000
# Epoch 320/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1097 - accuracy: 0.8483 - val_loss: 1.1238 - val_accuracy: 0.8167
# Epoch 321/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1093 - accuracy: 0.8483 - val_loss: 1.1235 - val_accuracy: 0.8167
# Epoch 322/500
# 4/4 [==============================] - 0s 18ms/step - loss: 1.1089 - accuracy: 0.8483 - val_loss: 1.1231 - val_accuracy: 0.8167
# Epoch 323/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1085 - accuracy: 0.8483 - val_loss: 1.1228 - val_accuracy: 0.8167
# Epoch 324/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1081 - accuracy: 0.8483 - val_loss: 1.1224 - val_accuracy: 0.8167
# Epoch 325/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1077 - accuracy: 0.8483 - val_loss: 1.1221 - val_accuracy: 0.8167
# Epoch 326/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1073 - accuracy: 0.8483 - val_loss: 1.1217 - val_accuracy: 0.8167
# Epoch 327/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1069 - accuracy: 0.8483 - val_loss: 1.1214 - val_accuracy: 0.8167
# Epoch 328/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1065 - accuracy: 0.8483 - val_loss: 1.1211 - val_accuracy: 0.8167
# Epoch 329/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1061 - accuracy: 0.8483 - val_loss: 1.1207 - val_accuracy: 0.8167
# Epoch 330/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1057 - accuracy: 0.8483 - val_loss: 1.1204 - val_accuracy: 0.8167
# Epoch 331/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1053 - accuracy: 0.8483 - val_loss: 1.1200 - val_accuracy: 0.8167
# Epoch 332/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1048 - accuracy: 0.8483 - val_loss: 1.1196 - val_accuracy: 0.8167
# Epoch 333/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1044 - accuracy: 0.8483 - val_loss: 1.1193 - val_accuracy: 0.8167
# Epoch 334/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1040 - accuracy: 0.8483 - val_loss: 1.1189 - val_accuracy: 0.8167
# Epoch 335/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1036 - accuracy: 0.8483 - val_loss: 1.1186 - val_accuracy: 0.8167
# Epoch 336/500
# 4/4 [==============================] - 0s 15ms/step - loss: 1.1032 - accuracy: 0.8483 - val_loss: 1.1182 - val_accuracy: 0.8167
# Epoch 337/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1028 - accuracy: 0.8483 - val_loss: 1.1179 - val_accuracy: 0.8167
# Epoch 338/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1024 - accuracy: 0.8483 - val_loss: 1.1175 - val_accuracy: 0.8167
# Epoch 339/500
# ...
# Epoch 389/500
# 4/4 [==============================] - 0s 9ms/step - loss: 1.0819 - accuracy: 0.8578 - val_loss: 1.1002 - val_accuracy: 0.8333
# Epoch 390/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0815 - accuracy: 0.8578 - val_loss: 1.0998 - val_accuracy: 0.8333
# Epoch 391/500
# 4/4 [==============================] - 0s 9ms/step - loss: 1.0811 - accuracy: 0.8578 - val_loss: 1.0995 - val_accuracy: 0.8333
# Epoch 392/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0807 - accuracy: 0.8578 - val_loss: 1.0992 - val_accuracy: 0.8333
# Epoch 393/500
# 4/4 [==============================] - 0s 12ms/step - loss: 1.0804 - accuracy: 0.8578 - val_loss: 1.0989 - val_accuracy: 0.8333
# Epoch 394/500
# 4/4 [==============================] - 0s 9ms/step - loss: 1.0800 - accuracy: 0.8578 - val_loss: 1.0985 - val_accuracy: 0.8333
# Epoch 395/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0796 - accuracy: 0.8578 - val_loss: 1.0982 - val_accuracy: 0.8333
# Epoch 396/500
# 4/4 [==============================] - 0s 9ms/step - loss: 1.0792 - accuracy: 0.8578 - val_loss: 1.0979 - val_accuracy: 0.8333
# Epoch 397/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.0788 - accuracy: 0.8578 - val_loss: 1.0976 - val_accuracy: 0.8333
# Epoch 398/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0784 - accuracy: 0.8578 - val_loss: 1.0972 - val_accuracy: 0.8333
# Epoch 399/500
# 4/4 [==============================] - 0s 17ms/step - loss: 1.0780 - accuracy: 0.8578 - val_loss: 1.0969 - val_accuracy: 0.8333
# Epoch 400/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0776 - accuracy: 0.8578 - val_loss: 1.0966 - val_accuracy: 0.8333
# Epoch 401/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0772 - accuracy: 0.8578 - val_loss: 1.0962 - val_accuracy: 0.8333
# Epoch 402/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0768 - accuracy: 0.8578 - val_loss: 1.0959 - val_accuracy: 0.8333
# Epoch 403/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.0765 - accuracy: 0.8578 - val_loss: 1.0956 - val_accuracy: 0.8333
# Epoch 404/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0761 - accuracy: 0.8578 - val_loss: 1.0953 - val_accuracy: 0.8333
# Epoch 405/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0757 - accuracy: 0.8578 - val_loss: 1.0949 - val_accuracy: 0.8333
# Epoch 406/500
# 4/4 [==============================] - 0s 12ms/step - loss: 1.0753 - accuracy: 0.8578 - val_loss: 1.0946 - val_accuracy: 0.8333
# Epoch 407/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0749 - accuracy: 0.8578 - val_loss: 1.0943 - val_accuracy: 0.8333
# Epoch 408/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0745 - accuracy: 0.8578 - val_loss: 1.0940 - val_accuracy: 0.8333
# Epoch 409/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0742 - accuracy: 0.8578 - val_loss: 1.0937 - val_accuracy: 0.8333
# Epoch 410/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.0738 - accuracy: 0.8578 - val_loss: 1.0933 - val_accuracy: 0.8333
# Epoch 411/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0734 - accuracy: 0.8626 - val_loss: 1.0930 - val_accuracy: 0.8333
# Epoch 412/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0730 - accuracy: 0.8626 - val_loss: 1.0927 - val_accuracy: 0.8333
# Epoch 413/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0726 - accuracy: 0.8626 - val_loss: 1.0924 - val_accuracy: 0.8333
# Epoch 414/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0723 - accuracy: 0.8626 - val_loss: 1.0920 - val_accuracy: 0.8333
# Epoch 415/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0719 - accuracy: 0.8626 - val_loss: 1.0917 - val_accuracy: 0.8333
# Epoch 416/500
# 4/4 [==============================] - 0s 9ms/step - loss: 1.0715 - accuracy: 0.8626 - val_loss: 1.0914 - val_accuracy: 0.8333
# Epoch 417/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.0711 - accuracy: 0.8626 - val_loss: 1.0911 - val_accuracy: 0.8333
# Epoch 418/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0707 - accuracy: 0.8626 - val_loss: 1.0908 - val_accuracy: 0.8333
# Epoch 419/500
# 4/4 [==============================] - 0s 13ms/step - loss: 1.0704 - accuracy: 0.8626 - val_loss: 1.0904 - val_accuracy: 0.8333
# Epoch 420/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0700 - accuracy: 0.8626 - val_loss: 1.0901 - val_accuracy: 0.8333
# Epoch 421/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.0696 - accuracy: 0.8626 - val_loss: 1.0898 - val_accuracy: 0.8333
# Epoch 422/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0692 - accuracy: 0.8626 - val_loss: 1.0895 - val_accuracy: 0.8333
# Epoch 423/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0689 - accuracy: 0.8626 - val_loss: 1.0892 - val_accuracy: 0.8333
# Epoch 424/500
# 4/4 [==============================] - 0s 9ms/step - loss: 1.0685 - accuracy: 0.8626 - val_loss: 1.0889 - val_accuracy: 0.8333
# Epoch 425/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0681 - accuracy: 0.8626 - val_loss: 1.0886 - val_accuracy: 0.8333
# Epoch 426/500
# 4/4 [==============================] - 0s 22ms/step - loss: 1.0677 - accuracy: 0.8626 - val_loss: 1.0882 - val_accuracy: 0.8333
# Epoch 427/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.0674 - accuracy: 0.8626 - val_loss: 1.0879 - val_accuracy: 0.8333
# Epoch 428/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.0670 - accuracy: 0.8626 - val_loss: 1.0876 - val_accuracy: 0.8333
# Epoch 429/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.0666 - accuracy: 0.8626 - val_loss: 1.0873 - val_accuracy: 0.8333
# Epoch 430/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0662 - accuracy: 0.8626 - val_loss: 1.0870 - val_accuracy: 0.8333
# Epoch 431/500
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0659 - accuracy: 0.8626 - val_loss: 1.0866 - val_accuracy: 0.8333
# Epoch 432/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.0655 - accuracy: 0.8626 - val_loss: 1.0863 - val_accuracy: 0.8333
# Epoch 433/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0651 - accuracy: 0.8626 - val_loss: 1.0860 - val_accuracy: 0.8333
# Epoch 434/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.0647 - accuracy: 0.8626 - val_loss: 1.0857 - val_accuracy: 0.8333
# Epoch 435/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0643 - accuracy: 0.8626 - val_loss: 1.0853 - val_accuracy: 0.8333
# Epoch 436/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0639 - accuracy: 0.8626 - val_loss: 1.0850 - val_accuracy: 0.8333
# Epoch 437/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0636 - accuracy: 0.8626 - val_loss: 1.0847 - val_accuracy: 0.8333
# Epoch 438/500
# 4/4 [==============================] - 0s 13ms/step - loss: 1.0632 - accuracy: 0.8626 - val_loss: 1.0844 - val_accuracy: 0.8333
# Epoch 439/500
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0628 - accuracy: 0.8626 - val_loss: 1.0841 - val_accuracy: 0.8333
# Epoch 440/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0624 - accuracy: 0.8626 - val_loss: 1.0838 - val_accuracy: 0.8333
# Epoch 441/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0621 - accuracy: 0.8626 - val_loss: 1.0835 - val_accuracy: 0.8333
# Epoch 442/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0617 - accuracy: 0.8626 - val_loss: 1.0832 - val_accuracy: 0.8333
# Epoch 443/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.0613 - accuracy: 0.8626 - val_loss: 1.0828 - val_accuracy: 0.8333
# Epoch 444/500
# 4/4 [==============================] - 0s 15ms/step - loss: 1.0609 - accuracy: 0.8626 - val_loss: 1.0825 - val_accuracy: 0.8333
# Epoch 445/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0605 - accuracy: 0.8626 - val_loss: 1.0822 - val_accuracy: 0.8333
# Epoch 446/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0602 - accuracy: 0.8626 - val_loss: 1.0819 - val_accuracy: 0.8333
# Epoch 447/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0598 - accuracy: 0.8626 - val_loss: 1.0816 - val_accuracy: 0.8333
# Epoch 448/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0594 - accuracy: 0.8626 - val_loss: 1.0813 - val_accuracy: 0.8333
# Epoch 449/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.0590 - accuracy: 0.8626 - val_loss: 1.0809 - val_accuracy: 0.8333
# Epoch 450/500
# 4/4 [==============================] - 0s 13ms/step - loss: 1.0587 - accuracy: 0.8626 - val_loss: 1.0806 - val_accuracy: 0.8333
# Epoch 451/500
# 4/4 [==============================] - 0s 12ms/step - loss: 1.0583 - accuracy: 0.8626 - val_loss: 1.0803 - val_accuracy: 0.8333
# Epoch 452/500
# 4/4 [==============================] - 0s 12ms/step - loss: 1.0579 - accuracy: 0.8626 - val_loss: 1.0800 - val_accuracy: 0.8333
# Epoch 453/500
# 4/4 [==============================] - 0s 25ms/step - loss: 1.0575 - accuracy: 0.8626 - val_loss: 1.0797 - val_accuracy: 0.8333
# Epoch 454/500
# 4/4 [==============================] - 0s 15ms/step - loss: 1.0571 - accuracy: 0.8626 - val_loss: 1.0793 - val_accuracy: 0.8333
# Epoch 455/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0568 - accuracy: 0.8626 - val_loss: 1.0790 - val_accuracy: 0.8333
# Epoch 456/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.0564 - accuracy: 0.8626 - val_loss: 1.0787 - val_accuracy: 0.8333
# Epoch 457/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0560 - accuracy: 0.8626 - val_loss: 1.0784 - val_accuracy: 0.8333
# Epoch 458/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0556 - accuracy: 0.8626 - val_loss: 1.0781 - val_accuracy: 0.8333
# Epoch 459/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0553 - accuracy: 0.8626 - val_loss: 1.0778 - val_accuracy: 0.8333
# Epoch 460/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0549 - accuracy: 0.8626 - val_loss: 1.0774 - val_accuracy: 0.8333
# Epoch 461/500
# 4/4 [==============================] - 0s 13ms/step - loss: 1.0545 - accuracy: 0.8626 - val_loss: 1.0771 - val_accuracy: 0.8333
# Epoch 462/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0541 - accuracy: 0.8626 - val_loss: 1.0768 - val_accuracy: 0.8333
# Epoch 463/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0537 - accuracy: 0.8626 - val_loss: 1.0765 - val_accuracy: 0.8333
# Epoch 464/500
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0534 - accuracy: 0.8626 - val_loss: 1.0762 - val_accuracy: 0.8333
# Epoch 465/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.0530 - accuracy: 0.8626 - val_loss: 1.0758 - val_accuracy: 0.8333
# Epoch 466/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0526 - accuracy: 0.8626 - val_loss: 1.0755 - val_accuracy: 0.8333
# Epoch 467/500
# 4/4 [==============================] - 0s 12ms/step - loss: 1.0522 - accuracy: 0.8626 - val_loss: 1.0752 - val_accuracy: 0.8333
# Epoch 468/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0518 - accuracy: 0.8626 - val_loss: 1.0749 - val_accuracy: 0.8333
# Epoch 469/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0515 - accuracy: 0.8626 - val_loss: 1.0746 - val_accuracy: 0.8333
# Epoch 470/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0511 - accuracy: 0.8626 - val_loss: 1.0743 - val_accuracy: 0.8333
# Epoch 471/500
# 4/4 [==============================] - 0s 9ms/step - loss: 1.0507 - accuracy: 0.8626 - val_loss: 1.0740 - val_accuracy: 0.8333
# Epoch 472/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0503 - accuracy: 0.8626 - val_loss: 1.0737 - val_accuracy: 0.8333
# Epoch 473/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0500 - accuracy: 0.8626 - val_loss: 1.0733 - val_accuracy: 0.8333
# Epoch 474/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.0496 - accuracy: 0.8626 - val_loss: 1.0730 - val_accuracy: 0.8333
# Epoch 475/500
# 4/4 [==============================] - 0s 12ms/step - loss: 1.0493 - accuracy: 0.8626 - val_loss: 1.0727 - val_accuracy: 0.8333
# Epoch 476/500
# 4/4 [==============================] - 0s 12ms/step - loss: 1.0489 - accuracy: 0.8626 - val_loss: 1.0724 - val_accuracy: 0.8333
# Epoch 477/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0485 - accuracy: 0.8626 - val_loss: 1.0721 - val_accuracy: 0.8333
# Epoch 478/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.0482 - accuracy: 0.8626 - val_loss: 1.0718 - val_accuracy: 0.8333
# Epoch 479/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.0478 - accuracy: 0.8626 - val_loss: 1.0715 - val_accuracy: 0.8333
# Epoch 480/500
# 4/4 [==============================] - 0s 12ms/step - loss: 1.0474 - accuracy: 0.8626 - val_loss: 1.0713 - val_accuracy: 0.8333
# Epoch 481/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0471 - accuracy: 0.8626 - val_loss: 1.0710 - val_accuracy: 0.8333
# Epoch 482/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0468 - accuracy: 0.8626 - val_loss: 1.0707 - val_accuracy: 0.8333
# Epoch 483/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0464 - accuracy: 0.8626 - val_loss: 1.0704 - val_accuracy: 0.8333
# Epoch 484/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0460 - accuracy: 0.8626 - val_loss: 1.0701 - val_accuracy: 0.8333
# Epoch 485/500
# 4/4 [==============================] - 0s 9ms/step - loss: 1.0457 - accuracy: 0.8626 - val_loss: 1.0698 - val_accuracy: 0.8333
# Epoch 486/500
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0453 - accuracy: 0.8626 - val_loss: 1.0695 - val_accuracy: 0.8333
# Epoch 487/500
# 4/4 [==============================] - 0s 9ms/step - loss: 1.0450 - accuracy: 0.8626 - val_loss: 1.0692 - val_accuracy: 0.8333
# Epoch 488/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.0446 - accuracy: 0.8626 - val_loss: 1.0689 - val_accuracy: 0.8333
# Epoch 489/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0442 - accuracy: 0.8626 - val_loss: 1.0686 - val_accuracy: 0.8333
# Epoch 490/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.0439 - accuracy: 0.8626 - val_loss: 1.0683 - val_accuracy: 0.8333
# Epoch 491/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0435 - accuracy: 0.8626 - val_loss: 1.0680 - val_accuracy: 0.8333
# Epoch 492/500
# 4/4 [==============================] - 0s 9ms/step - loss: 1.0432 - accuracy: 0.8626 - val_loss: 1.0677 - val_accuracy: 0.8333
# Epoch 493/500
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0428 - accuracy: 0.8626 - val_loss: 1.0674 - val_accuracy: 0.8333
# Epoch 494/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.0424 - accuracy: 0.8626 - val_loss: 1.0671 - val_accuracy: 0.8333
# Epoch 495/500
# 4/4 [==============================] - 0s 17ms/step - loss: 1.0421 - accuracy: 0.8626 - val_loss: 1.0668 - val_accuracy: 0.8333
# Epoch 496/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0417 - accuracy: 0.8626 - val_loss: 1.0665 - val_accuracy: 0.8333
# Epoch 497/500
# 4/4 [==============================] - 0s 12ms/step - loss: 1.0414 - accuracy: 0.8626 - val_loss: 1.0662 - val_accuracy: 0.8333
# Epoch 498/500
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0410 - accuracy: 0.8626 - val_loss: 1.0659 - val_accuracy: 0.8333
# Epoch 499/500
# 4/4 [==============================] - 0s 11ms/step - loss: 1.0406 - accuracy: 0.8626 - val_loss: 1.0656 - val_accuracy: 0.8333
# Epoch 500/500
# 4/4 [==============================] - 0s 12ms/step - loss: 1.0402 - accuracy: 0.8626 - val_loss: 1.0653 - val_accuracy: 0.8333

# %%
fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(25, 4))
ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[0].set_title('Accuracy')
ax[0].set_xlabel('Accuracy')
ax[0].set_ylabel('Epoch')

ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[1].set_title('Loss')
ax[1].set_xlabel('Loss')
ax[1].set_ylabel('Epoch')

plt.legend(['Train', 'Test'])
plt.show()

# %%
from sklearn.metrics import classification_report
y_pred = np.rint(model.predict(X_val, verbose=0))

print(classification_report(y_val,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.93      0.87        14
#            1       0.93      0.82      0.87        17
#
#    micro avg       0.87      0.87      0.87        31
#    macro avg       0.87      0.88      0.87        31
# weighted avg       0.88      0.87      0.87        31
#  samples avg       0.87      0.87      0.87        31

# %%
labels = ['No Disease', 'Disease']

y_pred = np.rint(model.predict(X_val, verbose=0).argmax(axis=1))
con_mat = confusion_matrix(y_val.argmax(axis=1),y_pred)

cm_percent = con_mat.astype('float') / con_mat.sum(axis=1)[:, np.newaxis]

sns.heatmap(cm_percent, annot=True, fmt='.2%', cmap='Blues', xticklabels=labels, yticklabels=labels)

plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # 6. Supervised Learning

# %%
X = data.drop(columns=['target']).values
Y = data['target']

# print(Counter(Y))
# undersample = RandomUnderSampler()
# # undersample = SMOTE()
# X, Y = undersample.fit_resample(X, Y)
# print(Counter(Y))

Y = Y.values

# scaler = MinMaxScaler(feature_range=(0,1))
scaler = PowerTransformer(method='yeo-johnson', standardize=True)
X = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X, Y, train_size=0.9, random_state = 42)

print(X_train.shape)
print(X_test.shape)
# Out:
# (271, 13)
# (31, 13)

# %% [markdown]
# ### 6.2 Stacking Classifier

# %%
adaboost = AdaBoostClassifier(n_estimators=100, random_state=42)
bagging = BaggingClassifier(n_jobs=-1)
extraTrees = ExtraTreesClassifier(max_depth=100, n_jobs=-1, random_state=42)
gradient = GradientBoostingClassifier(max_depth=100, n_estimators=100, learning_rate=.01,  random_state=42)
randomForest = RandomForestClassifier(max_depth=100, random_state=42, n_jobs=-1)
histGradient = HistGradientBoostingClassifier()
XGB = XGBClassifier(n_jobs=-1)
knn = KNeighborsClassifier(n_jobs=-1)
decisionTree = DecisionTreeClassifier(random_state=42, max_depth=100)
pac = PassiveAggressiveClassifier(random_state=42)
linear = LogisticRegression(random_state=42)

model = StackingClassifier([
    ('bagging', bagging),
    ('adaboost', adaboost),
    ('extraTress', extraTrees),
    ('randomforest', randomForest),
    ('decisionTree', decisionTree),
    ('histGradient', histGradient),
    ('XGB', XGB),
    ('pac', pac),
    ('linear', linear),
    # ('gradient', gradient),
    # ('knn', knn),
], n_jobs=-1)

# %%
model.fit(X_train, y_train)
# Out:
# StackingClassifier(estimators=[('bagging', BaggingClassifier(n_jobs=-1)),
#                                ('adaboost',
#                                 AdaBoostClassifier(n_estimators=100,
#                                                    random_state=42)),
#                                ('extraTress',
#                                 ExtraTreesClassifier(max_depth=100, n_jobs=-1,
#                                                      random_state=42)),
#                                ('randomforest',
#                                 RandomForestClassifier(max_depth=100, n_jobs=-1,
#                                                        random_state=42)),
#                                ('decisionTree',
#                                 DecisionTreeClassifier(max_depth=100,
#                                                        r...
#                                               max_cat_threshold=None,
#                                               max_cat_to_onehot=None,
#                                               max_delta_step=None,
#                                               max_depth=None, max_leaves=None,
#                                               min_child_weight=None,
#                                               missing=nan,
#                                               monotone_constraints=None,
#                                               n_estimators=100, n_jobs=-1,
#                                               num_parallel_tree=None,
#                                               predictor=None, random_state=None, ...)),
#                                ('pac',
#                                 PassiveAggressiveClassifier(random_state=42)),
#                                ('linear', LogisticRegression(random_state=42))],
#                    n_jobs=-1)

# %%
print("Train Score : ",round((model.score(X_train, y_train)*100), 2),'%')
print("Test Score  : ",round((model.score(X_test, y_test)*100), 2),'%')
# Out:
# Train Score :  100.0 %
# Test Score  :  80.65 %

# %%
y_pred = model.predict(X_test)
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.75      0.80        16
#            1       0.76      0.87      0.81        15
#
#     accuracy                           0.81        31
#    macro avg       0.81      0.81      0.81        31
# weighted avg       0.81      0.81      0.81        31

# %%
labels = ['No Disease', 'Disease']

y_pred = model.predict(X_test)
con_mat = confusion_matrix(y_test,y_pred)

cm_percent = con_mat.astype('float') / con_mat.sum(axis=1)[:, np.newaxis]

sns.heatmap(cm_percent, annot=True, fmt='.2%', cmap='Blues', xticklabels=labels, yticklabels=labels)

plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix - Fake News Detection')
plt.show()

# %% [markdown]
# ### 6.2. Pycaret

# %%
s = ClassificationExperiment()
s.setup(data, target = 'target', session_id = 123)
# Out:
# <style type="text/css">
# #T_4b62a_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4b62a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b62a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4b62a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b62a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4b62a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4b62a_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4b62a_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4b62a_row1_col1" class="data row1 col1" >target</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4b62a_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_4b62a_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4b62a_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_4b62a_row3_col1" class="data row3 col1" >(302, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4b62a_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_4b62a_row4_col1" class="data row4 col1" >(302, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4b62a_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_4b62a_row5_col1" class="data row5 col1" >(211, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4b62a_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_4b62a_row6_col1" class="data row6 col1" >(91, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4b62a_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_4b62a_row7_col1" class="data row7 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4b62a_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_4b62a_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4b62a_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_4b62a_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4b62a_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_4b62a_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4b62a_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_4b62a_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4b62a_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_4b62a_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_4b62a_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_4b62a_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_4b62a_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_4b62a_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_4b62a_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_4b62a_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_4b62a_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_4b62a_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_4b62a_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_4b62a_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_4b62a_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_4b62a_row18_col1" class="data row18 col1" >de87</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = s.compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              21:18:11
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library

# %%
s.evaluate_model(best)

# %%
print(best)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=123, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
s.predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ea290">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea290_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ea290_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ea290_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_ea290_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_ea290_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_ea290_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_ea290_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_ea290_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea290_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ea290_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_ea290_row0_col1" class="data row0 col1" >0.8462</td>
#       <td id="T_ea290_row0_col2" class="data row0 col2" >0.9082</td>
#       <td id="T_ea290_row0_col3" class="data row0 col3" >0.9184</td>
#       <td id="T_ea290_row0_col4" class="data row0 col4" >0.8182</td>
#       <td id="T_ea290_row0_col5" class="data row0 col5" >0.8654</td>
#       <td id="T_ea290_row0_col6" class="data row0 col6" >0.6873</td>
#       <td id="T_ea290_row0_col7" class="data row0 col7" >0.6935</td>
#     </tr>
#   </tbody>
# </table>
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 300   68    1   0       144   193    1        1      141      0      3.4
# 276   58    1   0       146   218    0        1      105      0      2.0
# 84    42    0   0       102   265    0        0      122      0      0.6
# 141   43    1   0       115   303    0        1      181      0      1.2
# 226   62    1   1       120   281    0        0      103      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 153   66    0   2       146   278    0        0      152      0      0.0
# 11    48    0   2       130   275    0        1      139      0      0.2
# 81    45    1   1       128   308    0        0      170      0      0.0
# 162   41    1   1       120   157    0        1      182      0      0.0
# 214   56    1   0       125   249    1        0      144      1      1.2
#
#      slope  ca  thal  target  prediction_label  prediction_score
# 300      1   2     3       0                 0            0.9656
# 276      1   1     3       0                 0            0.9710
# 84       1   0     2       1                 1            0.6207
# 141      1   0     2       1                 1            0.6176
# 226      1   1     3       0                 0            0.9002
# ..     ...  ..   ...     ...               ...               ...
# 153      1   1     2       1                 1            0.9173
# 11       2   0     2       1                 1            0.9615
# 81       2   0     2       1                 1            0.8216
# 162      2   0     2       1                 1            0.9372
# 214      1   1     2       0                 0            0.8795
#
# [91 rows x 16 columns]

# %%
lgbm = s.create_model('xgboost')
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              18:02:50
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# <style type="text/css">
# #T_9c2dd_row10_col0, #T_9c2dd_row10_col1, #T_9c2dd_row10_col2, #T_9c2dd_row10_col3, #T_9c2dd_row10_col4, #T_9c2dd_row10_col5, #T_9c2dd_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_9c2dd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c2dd_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_9c2dd_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_9c2dd_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_9c2dd_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_9c2dd_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_9c2dd_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_9c2dd_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c2dd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9c2dd_row0_col0" class="data row0 col0" >0.7718</td>
#       <td id="T_9c2dd_row0_col1" class="data row0 col1" >0.8167</td>
#       <td id="T_9c2dd_row0_col2" class="data row0 col2" >0.7180</td>
#       <td id="T_9c2dd_row0_col3" class="data row0 col3" >0.7497</td>
#       <td id="T_9c2dd_row0_col4" class="data row0 col4" >0.7335</td>
#       <td id="T_9c2dd_row0_col5" class="data row0 col5" >0.5342</td>
#       <td id="T_9c2dd_row0_col6" class="data row0 col6" >0.5346</td>
#     </tr>
#     <tr>
#       <th id="T_9c2dd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9c2dd_row1_col0" class="data row1 col0" >0.7747</td>
#       <td id="T_9c2dd_row1_col1" class="data row1 col1" >0.8213</td>
#       <td id="T_9c2dd_row1_col2" class="data row1 col2" >0.7183</td>
#       <td id="T_9c2dd_row1_col3" class="data row1 col3" >0.7547</td>
#       <td id="T_9c2dd_row1_col4" class="data row1 col4" >0.7360</td>
#       <td id="T_9c2dd_row1_col5" class="data row1 col5" >0.5396</td>
#       <td id="T_9c2dd_row1_col6" class="data row1 col6" >0.5401</td>
#     </tr>
#     <tr>
#       <th id="T_9c2dd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9c2dd_row2_col0" class="data row2 col0" >0.7757</td>
#       <td id="T_9c2dd_row2_col1" class="data row2 col1" >0.8226</td>
#       <td id="T_9c2dd_row2_col2" class="data row2 col2" >0.7208</td>
#       <td id="T_9c2dd_row2_col3" class="data row2 col3" >0.7552</td>
#       <td id="T_9c2dd_row2_col4" class="data row2 col4" >0.7376</td>
#       <td id="T_9c2dd_row2_col5" class="data row2 col5" >0.5419</td>
#       <td id="T_9c2dd_row2_col6" class="data row2 col6" >0.5424</td>
#     </tr>
#     <tr>
#       <th id="T_9c2dd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9c2dd_row3_col0" class="data row3 col0" >0.7683</td>
#       <td id="T_9c2dd_row3_col1" class="data row3 col1" >0.8147</td>
#       <td id="T_9c2dd_row3_col2" class="data row3 col2" >0.7119</td>
#       <td id="T_9c2dd_row3_col3" class="data row3 col3" >0.7465</td>
#       <td id="T_9c2dd_row3_col4" class="data row3 col4" >0.7288</td>
#       <td id="T_9c2dd_row3_col5" class="data row3 col5" >0.5267</td>
#       <td id="T_9c2dd_row3_col6" class="data row3 col6" >0.5272</td>
#     </tr>
#     <tr>
#       <th id="T_9c2dd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9c2dd_row4_col0" class="data row4 col0" >0.7714</td>
#       <td id="T_9c2dd_row4_col1" class="data row4 col1" >0.8189</td>
#       <td id="T_9c2dd_row4_col2" class="data row4 col2" >0.7178</td>
#       <td id="T_9c2dd_row4_col3" class="data row4 col3" >0.7491</td>
#       <td id="T_9c2dd_row4_col4" class="data row4 col4" >0.7331</td>
#       <td id="T_9c2dd_row4_col5" class="data row4 col5" >0.5334</td>
#       <td id="T_9c2dd_row4_col6" class="data row4 col6" >0.5337</td>
#     </tr>
#     <tr>
#       <th id="T_9c2dd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9c2dd_row5_col0" class="data row5 col0" >0.7700</td>
#       <td id="T_9c2dd_row5_col1" class="data row5 col1" >0.8144</td>
#       <td id="T_9c2dd_row5_col2" class="data row5 col2" >0.7148</td>
#       <td id="T_9c2dd_row5_col3" class="data row5 col3" >0.7482</td>
#       <td id="T_9c2dd_row5_col4" class="data row5 col4" >0.7311</td>
#       <td id="T_9c2dd_row5_col5" class="data row5 col5" >0.5304</td>
#       <td id="T_9c2dd_row5_col6" class="data row5 col6" >0.5308</td>
#     </tr>
#     <tr>
#       <th id="T_9c2dd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9c2dd_row6_col0" class="data row6 col0" >0.7762</td>
#       <td id="T_9c2dd_row6_col1" class="data row6 col1" >0.8220</td>
#       <td id="T_9c2dd_row6_col2" class="data row6 col2" >0.7227</td>
#       <td id="T_9c2dd_row6_col3" class="data row6 col3" >0.7552</td>
#       <td id="T_9c2dd_row6_col4" class="data row6 col4" >0.7386</td>
#       <td id="T_9c2dd_row6_col5" class="data row6 col5" >0.5432</td>
#       <td id="T_9c2dd_row6_col6" class="data row6 col6" >0.5436</td>
#     </tr>
#     <tr>
#       <th id="T_9c2dd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9c2dd_row7_col0" class="data row7 col0" >0.7739</td>
#       <td id="T_9c2dd_row7_col1" class="data row7 col1" >0.8207</td>
#       <td id="T_9c2dd_row7_col2" class="data row7 col2" >0.7208</td>
#       <td id="T_9c2dd_row7_col3" class="data row7 col3" >0.7520</td>
#       <td id="T_9c2dd_row7_col4" class="data row7 col4" >0.7361</td>
#       <td id="T_9c2dd_row7_col5" class="data row7 col5" >0.5385</td>
#       <td id="T_9c2dd_row7_col6" class="data row7 col6" >0.5389</td>
#     </tr>
#     <tr>
#       <th id="T_9c2dd_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9c2dd_row8_col0" class="data row8 col0" >0.7744</td>
#       <td id="T_9c2dd_row8_col1" class="data row8 col1" >0.8216</td>
#       <td id="T_9c2dd_row8_col2" class="data row8 col2" >0.7189</td>
#       <td id="T_9c2dd_row8_col3" class="data row8 col3" >0.7538</td>
#       <td id="T_9c2dd_row8_col4" class="data row8 col4" >0.7360</td>
#       <td id="T_9c2dd_row8_col5" class="data row8 col5" >0.5392</td>
#       <td id="T_9c2dd_row8_col6" class="data row8 col6" >0.5397</td>
#     </tr>
#     <tr>
#       <th id="T_9c2dd_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9c2dd_row9_col0" class="data row9 col0" >0.7723</td>
#       <td id="T_9c2dd_row9_col1" class="data row9 col1" >0.8190</td>
#       <td id="T_9c2dd_row9_col2" class="data row9 col2" >0.7165</td>
#       <td id="T_9c2dd_row9_col3" class="data row9 col3" >0.7513</td>
#       <td id="T_9c2dd_row9_col4" class="data row9 col4" >0.7335</td>
#       <td id="T_9c2dd_row9_col5" class="data row9 col5" >0.5349</td>
#       <td id="T_9c2dd_row9_col6" class="data row9 col6" >0.5353</td>
#     </tr>
#     <tr>
#       <th id="T_9c2dd_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_9c2dd_row10_col0" class="data row10 col0" >0.7729</td>
#       <td id="T_9c2dd_row10_col1" class="data row10 col1" >0.8192</td>
#       <td id="T_9c2dd_row10_col2" class="data row10 col2" >0.7180</td>
#       <td id="T_9c2dd_row10_col3" class="data row10 col3" >0.7516</td>
#       <td id="T_9c2dd_row10_col4" class="data row10 col4" >0.7344</td>
#       <td id="T_9c2dd_row10_col5" class="data row10 col5" >0.5362</td>
#       <td id="T_9c2dd_row10_col6" class="data row10 col6" >0.5366</td>
#     </tr>
#     <tr>
#       <th id="T_9c2dd_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_9c2dd_row11_col0" class="data row11 col0" >0.0024</td>
#       <td id="T_9c2dd_row11_col1" class="data row11 col1" >0.0028</td>
#       <td id="T_9c2dd_row11_col2" class="data row11 col2" >0.0030</td>
#       <td id="T_9c2dd_row11_col3" class="data row11 col3" >0.0030</td>
#       <td id="T_9c2dd_row11_col4
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
X = data.drop(columns=['satisfaction']).values
Y = data['satisfaction']

# %%
scores = cross_val_score(lgbm, X_train, y_train, cv=20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 scores = cross_val_score(lgbm, X_train, y_train, cv=20)
#
# NameError: name 'X_train' is not defined

# %%
sns.lineplot(scores)
# Out:
# <Axes: >

# %%
preds = s.predict_model(lgbm)
preds
# Out:
# <style type="text/css">
# </style>
# <table id="T_40b2e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40b2e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_40b2e_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_40b2e_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_40b2e_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_40b2e_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_40b2e_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_40b2e_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_40b2e_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40b2e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_40b2e_row0_col0" class="data row0 col0" >Extreme Gradient Boosting</td>
#       <td id="T_40b2e_row0_col1" class="data row0 col1" >0.7745</td>
#       <td id="T_40b2e_row0_col2" class="data row0 col2" >0.8197</td>
#       <td id="T_40b2e_row0_col3" class="data row0 col3" >0.7199</td>
#       <td id="T_40b2e_row0_col4" class="data row0 col4" >0.7531</td>
#       <td id="T_40b2e_row0_col5" class="data row0 col5" >0.7362</td>
#       <td id="T_40b2e_row0_col6" class="data row0 col6" >0.5394</td>
#       <td id="T_40b2e_row0_col7" class="data row0 col7" >0.5399</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred = (abs(preds['satisfaction'] - preds['prediction_label'])).sum()

print(f'{pred} / {preds.shape[0]} : {round(pred/preds.shape[0]*100, 2)} % (False Predictions)')
# Out:
# 33248 / 147438 : 22.55 % (False Predictions)
