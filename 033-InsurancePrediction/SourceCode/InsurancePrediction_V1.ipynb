# %% [markdown]
# # 1. Import Libraries

# %%
import tensorflow as tf
gpu = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpu[0], True)

# %%
import math
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
sns.set_style("whitegrid")
plt.style.use("fivethirtyeight")

from math import * 
from collections import Counter
from tqdm.notebook import tqdm
tqdm.pandas()

from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE

from tensorflow import keras
from keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD, Adam,  RMSprop, Nadam
from tensorflow.python.keras import models, layers, optimizers
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Dense, Flatten, Conv1D, MaxPooling1D, LSTM, GRU, Embedding,\
    BatchNormalization, LeakyReLU, Dropout, ReLU, Bidirectional, GlobalMaxPooling1D

from sklearn.model_selection import train_test_split
from   sklearn.model_selection import cross_val_score

from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PowerTransformer, MinMaxScaler, LabelEncoder, RobustScaler
from sklearn.feature_selection import chi2, RFE, SelectFromModel, SelectKBest
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score, RocCurveDisplay, classification_report 

from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import PassiveAggressiveClassifier, LogisticRegression

from sklearn.ensemble import (
    BaggingClassifier,
    StackingClassifier,
    AdaBoostClassifier, 
    ExtraTreesClassifier,
    RandomForestClassifier,
    RandomForestClassifier,
    GradientBoostingClassifier, 
    HistGradientBoostingClassifier
)
from xgboost import XGBClassifier

from pycaret.classification import ClassificationExperiment

# %% [markdown]
# # 2. Load Data

# %%
data = pd.read_csv('../Dataset/TravelInsurancePrediction.csv')
data = data.drop(columns=['Unnamed: 0'])
data = data.drop_duplicates()
data
# Out:
#       Age               Employment Type GraduateOrNot  AnnualIncome  \
# 0      31             Government Sector           Yes        400000
# 1      31  Private Sector/Self Employed           Yes       1250000
# 2      34  Private Sector/Self Employed           Yes        500000
# 3      28  Private Sector/Self Employed           Yes        700000
# 4      28  Private Sector/Self Employed           Yes        700000
# ...   ...                           ...           ...           ...
# 1976   32             Government Sector           Yes        900000
# 1981   27             Government Sector           Yes        850000
# 1982   33  Private Sector/Self Employed           Yes       1500000
# 1983   28  Private Sector/Self Employed           Yes       1750000
# 1985   34  Private Sector/Self Employed           Yes       1000000
#
#       FamilyMembers  ChronicDiseases FrequentFlyer EverTravelledAbroad  \
# 0                 6                1            No                  No
# 1                 7                0            No                  No
# 2                 4                1            No                  No
# 3                 3                1            No                  No
# 4                 8                1           Yes                  No
# ...             ...              ...           ...                 ...
# 1976              6                0            No                  No
# 1981              3                0            No                  No
# 1982              4                0           Yes                 Yes
# 1983              5                1            No                 Yes
# 1985              6                0           Yes                 Yes
#
#       TravelInsurance
# 0                   0
# 1                   0
# 2                   1
# 3                   0
# 4                   0
# ...               ...
# 1976                0
# 1981                1
# 1982                1
# 1983                0
# 1985                1
#
# [1249 rows x 9 columns]

# %% [markdown]
# # 3. Initial Analysis

# %% [markdown]
# ### 3.1. Metadata

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1249 entries, 0 to 1985
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  1249 non-null   int8
#  1   Employment Type      1249 non-null   int64
#  2   GraduateOrNot        1249 non-null   int64
#  3   AnnualIncome         1249 non-null   int32
#  4   FamilyMembers        1249 non-null   int8
#  5   ChronicDiseases      1249 non-null   int8
#  6   FrequentFlyer        1249 non-null   int64
#  7   EverTravelledAbroad  1249 non-null   int64
#  8   TravelInsurance      1249 non-null   int8
# dtypes: int32(1), int64(4), int8(4)
# memory usage: 58.5 KB

# %%
data.describe().transpose()
# Out:
#                   count           mean            std       min       25%  \
# Age              1987.0      29.650226       2.913308      25.0      28.0
# AnnualIncome     1987.0  932762.959235  376855.684748  300000.0  600000.0
# FamilyMembers    1987.0       4.752894       1.609650       2.0       4.0
# ChronicDiseases  1987.0       0.277806       0.448030       0.0       0.0
# TravelInsurance  1987.0       0.357323       0.479332       0.0       0.0
#
#                       50%        75%        max
# Age                  29.0       32.0       35.0
# AnnualIncome     900000.0  1250000.0  1800000.0
# FamilyMembers         5.0        6.0        9.0
# ChronicDiseases       0.0        1.0        1.0
# TravelInsurance       0.0        1.0        1.0

# %%
data.isnull().sum()
# Out:
# Age                    0
# Employment Type        0
# GraduateOrNot          0
# AnnualIncome           0
# FamilyMembers          0
# ChronicDiseases        0
# FrequentFlyer          0
# EverTravelledAbroad    0
# TravelInsurance        0
# dtype: int64

# %%
no_of_columns = data.shape[0]
percentage_of_missing_data = data.isnull().sum()/no_of_columns
print(round(percentage_of_missing_data*100), 2)
# Out:
# Age                    0.0
# Employment Type        0.0
# GraduateOrNot          0.0
# AnnualIncome           0.0
# FamilyMembers          0.0
# ChronicDiseases        0.0
# FrequentFlyer          0.0
# EverTravelledAbroad    0.0
# TravelInsurance        0.0
# dtype: float64 2

# %%
print(f'Number of duplicates data : {data.duplicated().sum()}')
# Out:
# Number of duplicates data : 0

# %%
data.nunique()
# Out:
# Age                    11
# Employment Type         2
# GraduateOrNot           2
# AnnualIncome           30
# FamilyMembers           8
# ChronicDiseases         2
# FrequentFlyer           2
# EverTravelledAbroad     2
# TravelInsurance         2
# dtype: int64

# %% [markdown]
# ### 3.2. Columns Processing

# %%
numerical_columns = [column_name for column_name in data.columns if data[column_name].dtype != 'object']
categorical_columns = [column_name for column_name in data.columns if data[column_name].dtype == 'object']

print(f'Numerical Columns   : {numerical_columns}')
print(f'Categorical Columns : {categorical_columns}')
# Out:
# Numerical Columns   : ['Age', 'AnnualIncome', 'FamilyMembers', 'ChronicDiseases', 'TravelInsurance']
# Categorical Columns : ['Employment Type', 'GraduateOrNot', 'FrequentFlyer', 'EverTravelledAbroad']

# %%
def impute_nan(data):
    for col in numerical_columns:
        data[col] = data[col].fillna(data[col].mean())

    for col in categorical_columns:
        data[col] = data[col].fillna(data[col].value_counts().index[0])
impute_nan(data)

# %%
def downcasting_dtypes(data):
    fcols = data.select_dtypes('float').columns
    icols = data.select_dtypes('integer').columns

    data[fcols] = data[fcols].apply(pd.to_numeric, downcast='float')
    data[icols] = data[icols].apply(pd.to_numeric, downcast='integer')

downcasting_dtypes(data)

# %%
def change_columns_to_numerical(data):
    LE = LabelEncoder()

    for column in categorical_columns:
        data[column] = LE.fit_transform(data[column])
        data[column] = data[column].apply(pd.to_numeric, downcast='integer')
        print(f'{column} : {LE.classes_}') 

change_columns_to_numerical(data)
# Out:
# Employment Type : ['Government Sector' 'Private Sector/Self Employed']
# GraduateOrNot : ['No' 'Yes']
# FrequentFlyer : ['No' 'Yes']
# EverTravelledAbroad : ['No' 'Yes']

# %% [markdown]
# ### 3.3. EDA

# %%
plt.subplots(figsize = (20,2))
ax = sns.countplot(data = data, y = 'TravelInsurance', palette='YlOrBr')
ax.bar_label(ax.containers[0])
plt.show()

# %%
num_cols = 3
num_rows = math.ceil(len(numerical_columns) / num_cols)

fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 5))

for i, column in enumerate(numerical_columns):
    row = i // num_cols
    col = i % num_cols
    sns.kdeplot(data = data, x = column, ax=axes[row, col]) \
        .set_title("Distribusi nilai kolom " + column)
    

for i in range(len(numerical_columns), num_rows * num_cols):
    row = i // num_cols
    col = i % num_cols
    axes[row, col].axis('off')

plt.tight_layout()
plt.show()

# %%
num_cols = 4
num_rows = math.ceil(len(numerical_columns) / num_cols)

fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 5))

for i, column in enumerate(numerical_columns):
    row = i // num_cols
    col = i % num_cols
    sns.kdeplot(data=data, x=column, hue="TravelInsurance", 
                fill=True, alpha=.2, palette="YlOrRd", 
                common_norm=False, ax=axes[row, col],
                warn_singular=False)\
        .set_title(column)

for i in range(len(numerical_columns), num_rows * num_cols):
    row = i // num_cols
    col = i % num_cols
    axes[row, col].axis('off')

plt.tight_layout()
plt.show()

# %%
# plt.figure(figsize=(20, 10))

# plt.scatter(data.age[data.target==1],
#             data.thalach[data.target==1],
#             c="salmon")

# plt.scatter(data.age[data.target==0],
#             data.thalach[data.target==0],
#             c="lightblue")

# plt.title("Heart Disease in function of Age and Max Heart Rate")
# plt.xlabel("Age")
# plt.ylabel("Max Heart Rate")
# plt.legend(["Disease", "No Disease"])

# %%
sns.pairplot(data, hue='TravelInsurance')
plt.show()

# %%
num_cols = 3
num_rows = math.ceil(len(numerical_columns) / num_cols)

fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 5))
for i, column in enumerate(numerical_columns):
    row = i // num_cols
    col = i % num_cols
    sns.boxplot(x=data[column], ax=axes[row, col], palette="Oranges").set_title(column)
    
for i in range(len(numerical_columns), num_rows * num_cols):
    row = i // num_cols
    col = i % num_cols
    axes[row, col].axis('off')

plt.tight_layout()
plt.show()

# %%
# Q1 = data['text_len'].quantile(0.25)
# Q3 = data['text_len'].quantile(1.)

# print(Q1)
# print(Q3)

# data = data[(data['text_len'] > Q1) & (data['text_len'] < Q3)]

# fig, axes = plt.subplots(figsize=(25, 2))
# sns.boxplot(x = data['text_len'], palette="Oranges")

# sns.stripplot(x=data['text_len'], data=data,
#               size=4, color=".3", linewidth=0, palette="crest", hue=data['text_len'])

# %% [markdown]
# ### 3.4. Data Correlation

# %%
corr_data = data[numerical_columns].corr().round(2)

mask = np.zeros_like(corr_data)
mask[np.triu_indices_from(mask)] = True

plt.figure(figsize=(25, 10))
# sns.heatmap(corr_data, annot=True, mask=mask, cmap='RdBu')
sns.heatmap(corr_data, annot=True, cmap='RdBu')
plt.title("Correlation Matrix", size=20)
plt.show()

# %% [markdown]
# # 4. Data Preprocessing

# %% [markdown]
# ### 4.1. Features Selections

# %%
### Pearson Correlation
def cor_selector(X, y,num_feats):
    cor_list = []
    feature_name = X.columns.tolist()
    # calculate the correlation with y for each feature
    for i in X.columns.tolist():
        cor = np.corrcoef(X[i], y)[0, 1]
        cor_list.append(cor)
    # replace NaN with 0
    cor_list = [0 if np.isnan(i) else i for i in cor_list]
    # feature name
    cor_feature = X.iloc[:,np.argsort(np.abs(cor_list))[-num_feats:]].columns.tolist()
    # feature selection? 0 for not select, 1 for select
    cor_support = [True if i in cor_feature else False for i in feature_name]
    print(str(len(cor_feature)), 'selected features')
    print(cor_feature)
    return cor_feature

### Chi-Squared
def chi_squared_elimination(X, Y,num_feats):
    X_norm = MinMaxScaler().fit_transform(X)
    chi_selector = SelectKBest(chi2, k=num_feats)
    chi_selector.fit(X_norm, Y)
    chi_support = chi_selector.get_support()
    chi_feature = X.loc[:,chi_support].columns.tolist()
    print(str(len(chi_feature)), 'selected features')
    print(chi_feature)
    return chi_feature

### Recursive Feature Elimination
def recursive_elimination(X, Y,num_feats):
    X_norm = MinMaxScaler().fit_transform(X)
    rfe_selector = RFE(estimator=LogisticRegression(), n_features_to_select=num_feats, step=10, verbose=5)
    rfe_selector.fit(X_norm, Y)
    rfe_support = rfe_selector.get_support()
    rfe_feature = X.loc[:,rfe_support].columns.tolist()
    print(str(len(rfe_feature)), 'selected features')
    print(rfe_feature)
    return rfe_feature

### Lasso: SelectFromModel
def lasso_elimination(X, Y, num_feats):
    X_norm = MinMaxScaler().fit_transform(X)
    embeded_lr_selector = SelectFromModel(LogisticRegression(penalty="l2"), max_features=num_feats)
    embeded_lr_selector.fit(X_norm, Y)
    embeded_lr_support = embeded_lr_selector.get_support()
    embeded_lr_feature = X.loc[:,embeded_lr_support].columns.tolist()
    print(str(len(embeded_lr_feature)), 'selected features')
    print(embeded_lr_feature)
    return embeded_lr_feature

### LightGBM: SelectFromModel
def LGBMC_elimination(X, Y, num_feats):
    lgbc=LGBMClassifier(n_estimators=500, learning_rate=0.05, num_leaves=32, colsample_bytree=0.2,
                reg_alpha=3, reg_lambda=1, min_split_gain=0.01, min_child_weight=40)

    embeded_lgb_selector = SelectFromModel(lgbc, max_features=num_feats)
    embeded_lgb_selector.fit(X, Y)
    embeded_lgb_support = embeded_lgb_selector.get_support()
    embeded_lgb_feature = X.loc[:,embeded_lgb_support].columns.tolist()
    print(str(len(embeded_lgb_feature)), 'selected features')
    print(embeded_lgb_feature)
    return embeded_lgb_feature

### Tree-based: SelectFromModel
def RFC_elimination (X, Y, num_feats):
    embeded_rf_selector = SelectFromModel(RandomForestClassifier(n_estimators=100), max_features=num_feats)
    embeded_rf_selector.fit(X, Y)

    embeded_rf_support = embeded_rf_selector.get_support()
    embeded_rf_feature = X.loc[:,embeded_rf_support].columns.tolist()
    print(str(len(embeded_rf_feature)), 'selected features')
    print(embeded_rf_feature)
    return embeded_rf_feature

# %%
X = data.drop(columns=['Potability'])
Y = data['Potability']

num_feats = 10

selected_feature = cor_selector(X, Y,num_feats)
# selected_feature = chi_squared_elimination(X, Y,num_feats)
# selected_feature = recursive_elimination(X, Y,num_feats)
# selected_feature = lasso_elimination(X, Y, num_feats)
# selected_feature = LGBMC_elimination(X, Y, num_feats)
# selected_feature = RFC_elimination(X, Y, num_feats)

X = data[selected_feature]
Y = data['Credit_Score']


print(Counter(Y))
undersample = RandomUnderSampler()
X, Y = undersample.fit_resample(X, Y)
print(Counter(Y))

Y = to_categorical(Y)

scaler = MinMaxScaler(feature_range=(0,1))
X = scaler.fit_transform(X)

X_train, X_val, y_train, y_val = train_test_split(X, Y, train_size=0.9, random_state = 42)
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, train_size=0.78, random_state = 42)

print(X_train.shape)
print(X_test.shape)
print(X_val.shape)
# Out:
# 10 selected features
# ['Monthly_Balance', 'Num_Bank_Accounts', 'Credit_History_Age', 'Num_Credit_Card', 'Num_of_Loan', 'Delay_from_due_date', 'Outstanding_Debt', 'Interest_Rate', 'Num_Credit_Inquiries', 'Credit_Mix']
# Counter({0: 53174, 2: 28998, 1: 17828})
# Counter({0: 17828, 1: 17828, 2: 17828})
# (37545, 10)
# (10590, 10)
# (5349, 10)

# %% [markdown]
# # 5 Neural Network Algoritms

# %%
X = data.drop(columns=['TravelInsurance']).values
Y = data['TravelInsurance']

print(Counter(Y))
# sampling = RandomUnderSampler()
sampling = SMOTE()
X, Y = sampling.fit_resample(X, Y)
print(Counter(Y))

Y = pd.get_dummies(Y).values

# scaler = MinMaxScaler(feature_range=(0,1))
scaler = PowerTransformer(method='yeo-johnson', standardize=True)
X = scaler.fit_transform(X)

X_train, X_val, y_train, y_val = train_test_split(X, Y, train_size=0.9, random_state = 42)
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, train_size=0.78, random_state = 42)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
print(X_val.shape, y_val.shape)

label = y_train.shape[1]
# Out:
# Counter({0: 766, 1: 483})
# Counter({0: 766, 1: 766})
# (1074, 8) (1074, 2)
# (304, 8) (304, 2)
# (154, 8) (154, 2)

# %%
def DNN_Model():
    model = Sequential()
    model.add(Dense(1024, activation='relu', kernel_regularizer=keras.regularizers.l2(l=0.01), input_shape=(X_train.shape[1],)))
    model.add(Dense(256, activation='relu', kernel_regularizer=keras.regularizers.l2(l=0.01)))
    model.add(Dense(64, activation='relu', kernel_regularizer=keras.regularizers.l2(l=0.01)))
    model.add(Dense(label, activation='softmax'))
    
    return model

def CNN_Model():
    model = Sequential()

    model.add(Conv1D(128, 3, kernel_regularizer=keras.regularizers.l2(l=0.001), input_shape=(X_train.shape[1], 1)))
    model.add(BatchNormalization())
    # model.add(LeakyReLU(0.2))
    model.add(ReLU())
    # model.add(Dropout(0.8))
    model.add(MaxPooling1D())

    # model.add(Conv1D(64, 3, kernel_regularizer=keras.regularizers.l2(l=0.001)))
    # model.add(BatchNormalization())
    # # model.add(LeakyReLU(0.2))
    # model.add(ReLU())
    # model.add(Dropout(0.5))
    # model.add(MaxPooling1D())

    model.add(Conv1D(64, 3, kernel_regularizer=keras.regularizers.l2(l=0.001)))
    model.add(BatchNormalization())
    # model.add(LeakyReLU(0.2))
    model.add(ReLU())
    # model.add(Dropout(0.5))
    model.add(MaxPooling1D())

    # model.add(Conv1D(16, 3, kernel_regularizer=keras.regularizers.l2(l=0.001)))
    # model.add(BatchNormalization())
    # # model.add(LeakyReLU(0.2))
    # model.add(ReLU())
    # # model.add(Dropout(0.5))
    # model.add(MaxPooling1D())

    model.add(Flatten())
    # model.add(Dense(4098, activation='relu'))
    model.add(Dense(128, activation='relu'))
    # model.add(Dropout(0.5))
    model.add(Dense(128, activation='relu'))
    # model.add(Dropout(0.5))
    model.add(Dense(label, activation='softmax'))
    return model

def LSTM_Model():
    model = Sequential()
    model.add((LSTM(256, return_sequences=True, input_shape=(X_train.shape[1], 1))))
    model.add((LSTM(256)))
    # model.add(Dense(32, activation='swish'))
    # model.add(Dropout(0.2))
    # model.add(Dropout(0.5))
    # model.add(Dense(16, activation='relu'))
    model.add(Dense(label, activation='sigmoid'))
    return model

def GRU_Model():
    model = Sequential()
    model.add(GRU(256, activation ='tanh', recurrent_activation ='sigmoid', recurrent_dropout = 0, unroll=False, use_bias=True, reset_after=True, return_sequences=True, input_shape = (X_train.shape[1],1)))
    model.add(GRU(256, activation ='tanh', recurrent_activation ='sigmoid', recurrent_dropout = 0, unroll=False, use_bias=True, reset_after=True))
    model.add(Dense(label, activation='softmax'))
    return model
    

model = DNN_Model()
# model = CNN_Model()
# model = LSTM_Model()
# model = GRU_Model()

model.summary()

# opt = RMSprop(learning_rate = 0.001)
# opt = SGD(learning_rate = 0.001)
opt = Adam(learning_rate = 0.000_01)

model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
# model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_40 (Dense)            (None, 1024)              9216
#
#  dense_41 (Dense)            (None, 256)               262400
#
#  dense_42 (Dense)            (None, 64)                16448
#
#  dense_43 (Dense)            (None, 2)                 130
#
# =================================================================
# Total params: 288,194
# Trainable params: 288,194
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epoch = 300
batch_size = 32

history = model.fit(X_train, y_train, verbose = 2,
                    batch_size = batch_size, epochs = num_epoch, 
                    validation_data = (X_test, y_test))
# Out:
# Epoch 1/300
# 34/34 - 0s - loss: 0.7823 - accuracy: 0.7235 - val_loss: 0.8063 - val_accuracy: 0.7039 - 250ms/epoch - 7ms/step
# Epoch 2/300
# 34/34 - 0s - loss: 0.7808 - accuracy: 0.7207 - val_loss: 0.8048 - val_accuracy: 0.7007 - 126ms/epoch - 4ms/step
# Epoch 3/300
# 34/34 - 0s - loss: 0.7791 - accuracy: 0.7216 - val_loss: 0.8029 - val_accuracy: 0.7039 - 120ms/epoch - 4ms/step
# Epoch 4/300
# 34/34 - 0s - loss: 0.7777 - accuracy: 0.7225 - val_loss: 0.8016 - val_accuracy: 0.7039 - 118ms/epoch - 3ms/step
# Epoch 5/300
# 34/34 - 0s - loss: 0.7757 - accuracy: 0.7216 - val_loss: 0.7995 - val_accuracy: 0.7039 - 121ms/epoch - 4ms/step
# Epoch 6/300
# 34/34 - 0s - loss: 0.7741 - accuracy: 0.7263 - val_loss: 0.7980 - val_accuracy: 0.7039 - 159ms/epoch - 5ms/step
# Epoch 7/300
# 34/34 - 0s - loss: 0.7725 - accuracy: 0.7225 - val_loss: 0.7967 - val_accuracy: 0.7072 - 112ms/epoch - 3ms/step
# Epoch 8/300
# 34/34 - 0s - loss: 0.7710 - accuracy: 0.7235 - val_loss: 0.7950 - val_accuracy: 0.7007 - 110ms/epoch - 3ms/step
# Epoch 9/300
# 34/34 - 0s - loss: 0.7693 - accuracy: 0.7235 - val_loss: 0.7934 - val_accuracy: 0.7039 - 117ms/epoch - 3ms/step
# Epoch 10/300
# 34/34 - 0s - loss: 0.7683 - accuracy: 0.7235 - val_loss: 0.7920 - val_accuracy: 0.7072 - 112ms/epoch - 3ms/step
# Epoch 11/300
# 34/34 - 0s - loss: 0.7665 - accuracy: 0.7235 - val_loss: 0.7904 - val_accuracy: 0.7007 - 112ms/epoch - 3ms/step
# Epoch 12/300
# 34/34 - 0s - loss: 0.7648 - accuracy: 0.7235 - val_loss: 0.7886 - val_accuracy: 0.7039 - 110ms/epoch - 3ms/step
# Epoch 13/300
# 34/34 - 0s - loss: 0.7637 - accuracy: 0.7253 - val_loss: 0.7873 - val_accuracy: 0.7072 - 106ms/epoch - 3ms/step
# Epoch 14/300
# 34/34 - 0s - loss: 0.7618 - accuracy: 0.7272 - val_loss: 0.7860 - val_accuracy: 0.7072 - 113ms/epoch - 3ms/step
# Epoch 15/300
# 34/34 - 0s - loss: 0.7603 - accuracy: 0.7197 - val_loss: 0.7846 - val_accuracy: 0.7007 - 109ms/epoch - 3ms/step
# Epoch 16/300
# 34/34 - 0s - loss: 0.7589 - accuracy: 0.7197 - val_loss: 0.7832 - val_accuracy: 0.7007 - 144ms/epoch - 4ms/step
# Epoch 17/300
# 34/34 - 0s - loss: 0.7575 - accuracy: 0.7197 - val_loss: 0.7816 - val_accuracy: 0.7072 - 118ms/epoch - 3ms/step
# Epoch 18/300
# 34/34 - 0s - loss: 0.7562 - accuracy: 0.7197 - val_loss: 0.7801 - val_accuracy: 0.7039 - 107ms/epoch - 3ms/step
# Epoch 19/300
# 34/34 - 0s - loss: 0.7547 - accuracy: 0.7225 - val_loss: 0.7787 - val_accuracy: 0.7039 - 110ms/epoch - 3ms/step
# Epoch 20/300
# 34/34 - 0s - loss: 0.7533 - accuracy: 0.7253 - val_loss: 0.7775 - val_accuracy: 0.7072 - 110ms/epoch - 3ms/step
# Epoch 21/300
# 34/34 - 0s - loss: 0.7518 - accuracy: 0.7272 - val_loss: 0.7761 - val_accuracy: 0.7072 - 113ms/epoch - 3ms/step
# Epoch 22/300
# 34/34 - 0s - loss: 0.7506 - accuracy: 0.7272 - val_loss: 0.7747 - val_accuracy: 0.7072 - 111ms/epoch - 3ms/step
# Epoch 23/300
# 34/34 - 0s - loss: 0.7494 - accuracy: 0.7281 - val_loss: 0.7735 - val_accuracy: 0.7072 - 109ms/epoch - 3ms/step
# Epoch 24/300
# 34/34 - 0s - loss: 0.7479 - accuracy: 0.7263 - val_loss: 0.7723 - val_accuracy: 0.7039 - 115ms/epoch - 3ms/step
# Epoch 25/300
# 34/34 - 0s - loss: 0.7466 - accuracy: 0.7207 - val_loss: 0.7713 - val_accuracy: 0.7007 - 109ms/epoch - 3ms/step
# Epoch 26/300
# 34/34 - 0s - loss: 0.7455 - accuracy: 0.7207 - val_loss: 0.7697 - val_accuracy: 0.7039 - 108ms/epoch - 3ms/step
# Epoch 27/300
# 34/34 - 0s - loss: 0.7440 - accuracy: 0.7272 - val_loss: 0.7682 - val_accuracy: 0.7072 - 111ms/epoch - 3ms/step
# Epoch 28/300
# 34/34 - 0s - loss: 0.7427 - accuracy: 0.7244 - val_loss: 0.7671 - val_accuracy: 0.7072 - 111ms/epoch - 3ms/step
# Epoch 29/300
# 34/34 - 0s - loss: 0.7414 - accuracy: 0.7253 - val_loss: 0.7658 - val_accuracy: 0.7072 - 105ms/epoch - 3ms/step
# Epoch 30/300
# 34/34 - 0s - loss: 0.7402 - accuracy: 0.7225 - val_loss: 0.7649 - val_accuracy: 0.7039 - 104ms/epoch - 3ms/step
# Epoch 31/300
# 34/34 - 0s - loss: 0.7389 - accuracy: 0.7188 - val_loss: 0.7636 - val_accuracy: 0.7072 - 107ms/epoch - 3ms/step
# Epoch 32/300
# 34/34 - 0s - loss: 0.7382 - accuracy: 0.7263 - val_loss: 0.7622 - val_accuracy: 0.7072 - 109ms/epoch - 3ms/step
# Epoch 33/300
# 34/34 - 0s - loss: 0.7366 - accuracy: 0.7197 - val_loss: 0.7612 - val_accuracy: 0.7039 - 110ms/epoch - 3ms/step
# Epoch 34/300
# 34/34 - 0s - loss: 0.7356 - accuracy: 0.7207 - val_loss: 0.7599 - val_accuracy: 0.7039 - 143ms/epoch - 4ms/step
# Epoch 35/300
# 34/34 - 0s - loss: 0.7342 - accuracy: 0.7253 - val_loss: 0.7588 - val_accuracy: 0.7072 - 107ms/epoch - 3ms/step
# Epoch 36/300
# 34/34 - 0s - loss: 0.7331 - accuracy: 0.7207 - val_loss: 0.7577 - val_accuracy: 0.7039 - 107ms/epoch - 3ms/step
# Epoch 37/300
# 34/34 - 0s - loss: 0.7321 - accuracy: 0.7225 - val_loss: 0.7567 - val_accuracy: 0.7072 - 108ms/epoch - 3ms/step
# Epoch 38/300
# 34/34 - 0s - loss: 0.7306 - accuracy: 0.7253 - val_loss: 0.7556 - val_accuracy: 0.7039 - 107ms/epoch - 3ms/step
# Epoch 39/300
# 34/34 - 0s - loss: 0.7297 - accuracy: 0.7244 - val_loss: 0.7544 - val_accuracy: 0.7072 - 106ms/epoch - 3ms/step
# Epoch 40/300
# 34/34 - 0s - loss: 0.7284 - accuracy: 0.7235 - val_loss: 0.7530 - val_accuracy: 0.7039 - 109ms/epoch - 3ms/step
# Epoch 41/300
# 34/34 - 0s - loss: 0.7273 - accuracy: 0.7244 - val_loss: 0.7521 - val_accuracy: 0.7072 - 108ms/epoch - 3ms/step
# Epoch 42/300
# 34/34 - 0s - loss: 0.7265 - accuracy: 0.7281 - val_loss: 0.7507 - val_accuracy: 0.7072 - 104ms/epoch - 3ms/step
# Epoch 43/300
# 34/34 - 0s - loss: 0.7252 - accuracy: 0.7235 - val_loss: 0.7498 - val_accuracy: 0.7072 - 126ms/epoch - 4ms/step
# Epoch 44/300
# 34/34 - 0s - loss: 0.7242 - accuracy: 0.7263 - val_loss: 0.7488 - val_accuracy: 0.7072 - 108ms/epoch - 3ms/step
# Epoch 45/300
# 34/34 - 0s - loss: 0.7233 - accuracy: 0.7235 - val_loss: 0.7479 - val_accuracy: 0.7039 - 109ms/epoch - 3ms/step
# Epoch 46/300
# 34/34 - 0s - loss: 0.7222 - accuracy: 0.7244 - val_loss: 0.7466 - val_accuracy: 0.7039 - 116ms/epoch - 3ms/step
# Epoch 47/300
# 34/34 - 0s - loss: 0.7212 - accuracy: 0.7225 - val_loss: 0.7459 - val_accuracy: 0.7072 - 110ms/epoch - 3ms/step
# Epoch 48/300
# 34/34 - 0s - loss: 0.7200 - accuracy: 0.7216 - val_loss: 0.7450 - val_accuracy: 0.7039 - 104ms/epoch - 3ms/step
# Epoch 49/300
# 34/34 - 0s - loss: 0.7190 - accuracy: 0.7188 - val_loss: 0.7438 - val_accuracy: 0.7039 - 111ms/epoch - 3ms/step
# Epoch 50/300
# 34/34 - 0s - loss: 0.7179 - accuracy: 0.7253 - val_loss: 0.7428 - val_accuracy: 0.7072 - 110ms/epoch - 3ms/step
# Epoch 51/300
# 34/34 - 0s - loss: 0.7171 - accuracy: 0.7263 - val_loss: 0.7419 - val_accuracy: 0.7072 - 132ms/epoch - 4ms/step
# Epoch 52/300
# 34/34 - 0s - loss: 0.7161 - accuracy: 0.7235 - val_loss: 0.7410 - val_accuracy: 0.7072 - 137ms/epoch - 4ms/step
# Epoch 53/300
# 34/34 - 0s - loss: 0.7151 - accuracy: 0.7253 - val_loss: 0.7400 - val_accuracy: 0.7072 - 108ms/epoch - 3ms/step
# Epoch 54/300
# 34/34 - 0s - loss: 0.7142 - accuracy: 0.7216 - val_loss: 0.7388 - val_accuracy: 0.7039 - 109ms/epoch - 3ms/step
# Epoch 55/300
# 34/34 - 0s - loss: 0.7131 - accuracy: 0.7197 - val_loss: 0.7380 - val_accuracy: 0.7039 - 104ms/epoch - 3ms/step
# Epoch 56/300
# 34/34 - 0s - loss: 0.7121 - accuracy: 0.7225 - val_loss: 0.7370 - val_accuracy: 0.7072 - 107ms/epoch - 3ms/step
# Epoch 57/300
# 34/34 - 0s - loss: 0.7113 - accuracy: 0.7244 - val_loss: 0.7360 - val_accuracy: 0.7072 - 106ms/epoch - 3ms/step
# Epoch 58/300
# 34/34 - 0s - loss: 0.7105 - accuracy: 0.7225 - val_loss: 0.7351 - val_accuracy: 0.7072 - 113ms/epoch - 3ms/step
# Epoch 59/300
# 34/34 - 0s - loss: 0.7096 - accuracy: 0.7179 - val_loss: 0.7345 - val_accuracy: 0.7072 - 111ms/epoch - 3ms/step
# Epoch 60/300
# 34/34 - 0s - loss: 0.7087 - accuracy: 0.7235 - val_loss: 0.7332 - val_accuracy: 0.7072 - 108ms/epoch - 3ms/step
# Epoch 61/300
# 34/34 - 0s - loss: 0.7079 - accuracy: 0.7225 - val_loss: 0.7326 - val_accuracy: 0.7072 - 106ms/epoch - 3ms/step
# Epoch 62/300
# 34/34 - 0s - loss: 0.7069 - accuracy: 0.7263 - val_loss: 0.7316 - val_accuracy: 0.7039 - 110ms/epoch - 3ms/step
# Epoch 63/300
# 34/34 - 0s - loss: 0.7060 - accuracy: 0.7235 - val_loss: 0.7308 - val_accuracy: 0.7039 - 113ms/epoch - 3ms/step
# Epoch 64/300
# 34/34 - 0s - loss: 0.7051 - accuracy: 0.7197 - val_loss: 0.7298 - val_accuracy: 0.7039 - 105ms/epoch - 3ms/step
# Epoch 65/300
# 34/34 - 0s - loss: 0.7043 - accuracy: 0.7235 - val_loss: 0.7291 - val_accuracy: 0.7072 - 108ms/epoch - 3ms/step
# Epoch 66/300
# 34/34 - 0s - loss: 0.7035 - accuracy: 0.7253 - val_loss: 0.7283 - val_accuracy: 0.7072 - 104ms/epoch - 3ms/step
# Epoch 67/300
# 34/34 - 0s - loss: 0.7027 - accuracy: 0.7235 - val_loss: 0.7272 - val_accuracy: 0.7105 - 107ms/epoch - 3ms/step
# Epoch 68/300
# 34/34 - 0s - loss: 0.7017 - accuracy: 0.7188 - val_loss: 0.7267 - val_accuracy: 0.7039 - 108ms/epoch - 3ms/step
# Epoch 69/300
# 34/34 - 0s - loss: 0.7011 - accuracy: 0.7263 - val_loss: 0.7258 - val_accuracy: 0.7072 - 140ms/epoch - 4ms/step
# Epoch 70/300
# 34/34 - 0s - loss: 0.7003 - accuracy: 0.7244 - val_loss: 0.7252 - val_accuracy: 0.7072 - 130ms/epoch - 4ms/step
# Epoch 71/300
# 34/34 - 0s - loss: 0.6996 - accuracy: 0.7225 - val_loss: 0.7242 - val_accuracy: 0.7105 - 108ms/epoch - 3ms/step
# Epoch 72/300
# 34/34 - 0s - loss: 0.6986 - accuracy: 0.7244 - val_loss: 0.7233 - val_accuracy: 0.7072 - 109ms/epoch - 3ms/step
# Epoch 73/300
# 34/34 - 0s - loss: 0.6978 - accuracy: 0.7244 - val_loss: 0.7228 - val_accuracy: 0.7105 - 109ms/epoch - 3ms/step
# Epoch 74/300
# 34/34 - 0s - loss: 0.6972 - accuracy: 0.7216 - val_loss: 0.7219 - val_accuracy: 0.7105 - 107ms/epoch - 3ms/step
# Epoch 75/300
# 34/34 - 0s - loss: 0.6963 - accuracy: 0.7235 - val_loss: 0.7213 - val_accuracy: 0.7072 - 110ms/epoch - 3ms/step
# Epoch 76/300
# 34/34 - 0s - loss: 0.6956 - accuracy: 0.7244 - val_loss: 0.7207 - val_accuracy: 0.7072 - 105ms/epoch - 3ms/step
# Epoch 77/300
# 34/34 - 0s - loss: 0.6948 - accuracy: 0.7216 - val_loss: 0.7199 - val_accuracy: 0.7072 - 112ms/epoch - 3ms/step
# Epoch 78/300
# 34/34 - 0s - loss: 0.6941 - accuracy: 0.7253 - val_loss: 0.7193 - val_accuracy: 0.7072 - 111ms/epoch - 3ms/step
# Epoch 79/300
# 34/34 - 0s - loss: 0.6935 - accuracy: 0.7263 - val_loss: 0.7187 - val_accuracy: 0.7105 - 110ms/epoch - 3ms/step
# Epoch 80/300
# 34/34 - 0s - loss: 0.6927 - accuracy: 0.7216 - val_loss: 0.7177 - val_accuracy: 0.7072 - 108ms/epoch - 3ms/step
# Epoch 81/300
# 34/34 - 0s - loss: 0.6920 - accuracy: 0.7263 - val_loss: 0.7171 - val_accuracy: 0.7105 - 115ms/epoch - 3ms/step
# Epoch 82/300
# 34/34 - 0s - loss: 0.6914 - accuracy: 0.7253 - val_loss: 0.7164 - val_accuracy: 0.7072 - 114ms/epoch - 3ms/step
# Epoch 83/300
# 34/34 - 0s - loss: 0.6906 - accuracy: 0.7188 - val_loss: 0.7161 - val_accuracy: 0.7072 - 123ms/epoch - 4ms/step
# Epoch 84/300
# 34/34 - 0s - loss: 0.6899 - accuracy: 0.7235 - val_loss: 0.7153 - val_accuracy: 0.7072 - 104ms/epoch - 3ms/step
# Epoch 85/300
# 34/34 - 0s - loss: 0.6893 - accuracy: 0.7207 - val_loss: 0.7145 - val_accuracy: 0.7138 - 111ms/epoch - 3ms/step
# Epoch 86/300
# 34/34 - 0s - loss: 0.6885 - accuracy: 0.7253 - val_loss: 0.7138 - val_accuracy: 0.7072 - 113ms/epoch - 3ms/step
# Epoch 87/300
# 34/34 - 0s - loss: 0.6879 - accuracy: 0.7253 - val_loss: 0.7133 - val_accuracy: 0.7039 - 141ms/epoch - 4ms/step
# Epoch 88/300
# 34/34 - 0s - loss: 0.6873 - accuracy: 0.7225 - val_loss: 0.7125 - val_accuracy: 0.7039 - 107ms/epoch - 3ms/step
# Epoch 89/300
# 34/34 - 0s - loss: 0.6867 - accuracy: 0.7244 - val_loss: 0.7119 - val_accuracy: 0.7072 - 107ms/epoch - 3ms/step
# Epoch 90/300
# 34/34 - 0s - loss: 0.6859 - accuracy: 0.7253 - val_loss: 0.7112 - val_accuracy: 0.7105 - 104ms/epoch - 3ms/step
# Epoch 91/300
# 34/34 - 0s - loss: 0.6854 - accuracy: 0.7253 - val_loss: 0.7105 - val_accuracy: 0.7105 - 109ms/epoch - 3ms/step
# Epoch 92/300
# 34/34 - 0s - loss: 0.6847 - accuracy: 0.7263 - val_loss: 0.7100 - val_accuracy: 0.7105 - 109ms/epoch - 3ms/step
# Epoch 93/300
# 34/34 - 0s - loss: 0.6842 - accuracy: 0.7253 - val_loss: 0.7094 - val_accuracy: 0.7105 - 109ms/epoch - 3ms/step
# Epoch 94/300
# 34/34 - 0s - loss: 0.6835 - accuracy: 0.7253 - val_loss: 0.7088 - val_accuracy: 0.7105 - 109ms/epoch - 3ms/step
# Epoch 95/300
# 34/34 - 0s - loss: 0.6831 - accuracy: 0.7244 - val_loss: 0.7083 - val_accuracy: 0.7105 - 111ms/epoch - 3ms/step
# Epoch 96/300
# 34/34 - 0s - loss: 0.6822 - accuracy: 0.7272 - val_loss: 0.7074 - val_accuracy: 0.7072 - 111ms/epoch - 3ms/step
# Epoch 97/300
# 34/34 - 0s - loss: 0.6816 - accuracy: 0.7263 - val_loss: 0.7067 - val_accuracy: 0.7007 - 107ms/epoch - 3ms/step
# Epoch 98/300
# 34/34 - 0s - loss: 0.6811 - accuracy: 0.7253 - val_loss: 0.7062 - val_accuracy: 0.7105 - 117ms/epoch - 3ms/step
# Epoch 99/300
# 34/34 - 0s - loss: 0.6804 - accuracy: 0.7263 - val_loss: 0.7057 - val_accuracy: 0.7138 - 110ms/epoch - 3ms/step
# Epoch 100/300
# 34/34 - 0s - loss: 0.6798 - accuracy: 0.7244 - val_loss: 0.7052 - val_accuracy: 0.7138 - 108ms/epoch - 3ms/step
# Epoch 101/300
# 34/34 - 0s - loss: 0.6793 - accuracy: 0.7253 - val_loss: 0.7049 - val_accuracy: 0.7039 - 111ms/epoch - 3ms/step
# Epoch 102/300
# 34/34 - 0s - loss: 0.6788 - accuracy: 0.7263 - val_loss: 0.7042 - val_accuracy: 0.7138 - 107ms/epoch - 3ms/step
# Epoch 103/300
# 34/34 - 0s - loss: 0.6781 - accuracy: 0.7253 - val_loss: 0.7033 - val_accuracy: 0.7105 - 109ms/epoch - 3ms/step
# Epoch 104/300
# 34/34 - 0s - loss: 0.6777 - accuracy: 0.7253 - val_loss: 0.7029 - val_accuracy: 0.7039 - 127ms/epoch - 4ms/step
# Epoch 105/300
# 34/34 - 0s - loss: 0.6771 - accuracy: 0.7272 - val_loss: 0.7022 - val_accuracy: 0.7072 - 142ms/epoch - 4ms/step
# Epoch 106/300
# 34/34 - 0s - loss: 0.6766 - accuracy: 0.7244 - val_loss: 0.7021 - val_accuracy: 0.7105 - 117ms/epoch - 3ms/step
# Epoch 107/300
# 34/34 - 0s - loss: 0.6763 - accuracy: 0.7272 - val_loss: 0.7013 - val_accuracy: 0.7039 - 109ms/epoch - 3ms/step
# Epoch 108/300
# 34/34 - 0s - loss: 0.6755 - accuracy: 0.7235 - val_loss: 0.7007 - val_accuracy: 0.7105 - 108ms/epoch - 3ms/step
# Epoch 109/300
# 34/34 - 0s - loss: 0.6751 - accuracy: 0.7272 - val_loss: 0.7003 - val_accuracy: 0.7072 - 113ms/epoch - 3ms/step
# Epoch 110/300
# 34/34 - 0s - loss: 0.6745 - accuracy: 0.7244 - val_loss: 0.6998 - val_accuracy: 0.7105 - 108ms/epoch - 3ms/step
# Epoch 111/300
# 34/34 - 0s - loss: 0.6740 - accuracy: 0.7253 - val_loss: 0.6995 - val_accuracy: 0.7105 - 105ms/epoch - 3ms/step
# Epoch 112/300
# 34/34 - 0s - loss: 0.6733 - accuracy: 0.7253 - val_loss: 0.6989 - val_accuracy: 0.7105 - 112ms/epoch - 3ms/step
# Epoch 113/300
# 34/34 - 0s - loss: 0.6729 - accuracy: 0.7253 - val_loss: 0.6984 - val_accuracy: 0.7105 - 107ms/epoch - 3ms/step
# Epoch 114/300
# 34/34 - 0s - loss: 0.6728 - accuracy: 0.7225 - val_loss: 0.6980 - val_accuracy: 0.7138 - 109ms/epoch - 3ms/step
# Epoch 115/300
# 34/34 - 0s - loss: 0.6720 - accuracy: 0.7253 - val_loss: 0.6973 - val_accuracy: 0.7105 - 118ms/epoch - 3ms/step
# Epoch 116/300
# 34/34 - 0s - loss: 0.6717 - accuracy: 0.7235 - val_loss: 0.6970 - val_accuracy: 0.7039 - 109ms/epoch - 3ms/step
# Epoch 117/300
# 34/34 - 0s - loss: 0.6711 - accuracy: 0.7244 - val_loss: 0.6965 - val_accuracy: 0.7138 - 106ms/epoch - 3ms/step
# Epoch 118/300
# 34/34 - 0s - loss: 0.6706 - accuracy: 0.7253 - val_loss: 0.6964 - val_accuracy: 0.7138 - 115ms/epoch - 3ms/step
# Epoch 119/300
# 34/34 - 0s - loss: 0.6701 - accuracy: 0.7253 - val_loss: 0.6956 - val_accuracy: 0.7105 - 106ms/epoch - 3ms/step
# Epoch 120/300
# 34/34 - 0s - loss: 0.6699 - accuracy: 0.7225 - val_loss: 0.6954 - val_accuracy: 0.7138 - 136ms/epoch - 4ms/step
# Epoch 121/300
# 34/34 - 0s - loss: 0.6693 - accuracy: 0.7253 - val_loss: 0.6943 - val_accuracy: 0.7072 - 124ms/epoch - 4ms/step
# Epoch 122/300
# 34/34 - 0s - loss: 0.6689 - accuracy: 0.7235 - val_loss: 0.6943 - val_accuracy: 0.7039 - 142ms/epoch - 4ms/step
# Epoch 123/300
# 34/34 - 0s - loss: 0.6682 - accuracy: 0.7253 - val_loss: 0.6939 - val_accuracy: 0.7105 - 108ms/epoch - 3ms/step
# Epoch 124/300
# 34/34 - 0s - loss: 0.6678 - accuracy: 0.7253 - val_loss: 0.6935 - val_accuracy: 0.7138 - 110ms/epoch - 3ms/step
# Epoch 125/300
# 34/34 - 0s - loss: 0.6675 - accuracy: 0.7263 - val_loss: 0.6929 - val_accuracy: 0.7105 - 108ms/epoch - 3ms/step
# Epoch 126/300
# 34/34 - 0s - loss: 0.6669 - accuracy: 0.7253 - val_loss: 0.6924 - val_accuracy: 0.7105 - 111ms/epoch - 3ms/step
# Epoch 127/300
# 34/34 - 0s - loss: 0.6666 - accuracy: 0.7263 - val_loss: 0.6923 - val_accuracy: 0.7105 - 110ms/epoch - 3ms/step
# Epoch 128/300
# 34/34 - 0s - loss: 0.6661 - accuracy: 0.7225 - val_loss: 0.6918 - val_accuracy: 0.7105 - 110ms/epoch - 3ms/step
# Epoch 129/300
# 34/34 - 0s - loss: 0.6656 - accuracy: 0.7253 - val_loss: 0.6915 - val_accuracy: 0.7072 - 120ms/epoch - 4ms/step
# Epoch 130/300
# 34/34 - 0s - loss: 0.6652 - accuracy: 0.7244 - val_loss: 0.6911 - val_accuracy: 0.7039 - 104ms/epoch - 3ms/step
# Epoch 131/300
# 34/34 - 0s - loss: 0.6648 - accuracy: 0.7263 - val_loss: 0.6907 - val_accuracy: 0.7039 - 109ms/epoch - 3ms/step
# Epoch 132/300
# 34/34 - 0s - loss: 0.6644 - accuracy: 0.7263 - val_loss: 0.6903 - val_accuracy: 0.7105 - 112ms/epoch - 3ms/step
# Epoch 133/300
# 34/34 - 0s - loss: 0.6639 - accuracy: 0.7263 - val_loss: 0.6900 - val_accuracy: 0.7105 - 108ms/epoch - 3ms/step
# Epoch 134/300
# 34/34 - 0s - loss: 0.6637 - accuracy: 0.7253 - val_loss: 0.6894 - val_accuracy: 0.7105 - 110ms/epoch - 3ms/step
# Epoch 135/300
# 34/34 - 0s - loss: 0.6634 - accuracy: 0.7253 - val_loss: 0.6890 - val_accuracy: 0.7105 - 110ms/epoch - 3ms/step
# Epoch 136/300
# 34/34 - 0s - loss: 0.6630 - accuracy: 0.7263 - val_loss: 0.6884 - val_accuracy: 0.7039 - 108ms/epoch - 3ms/step
# Epoch 137/300
# 34/34 - 0s - loss: 0.6630 - accuracy: 0.7291 - val_loss: 0.6884 - val_accuracy: 0.7138 - 112ms/epoch - 3ms/step
# Epoch 138/300
# 34/34 - 0s - loss: 0.6622 - accuracy: 0.7244 - val_loss: 0.6878 - val_accuracy: 0.7072 - 107ms/epoch - 3ms/step
# Epoch 139/300
# 34/34 - 0s - loss: 0.6617 - accuracy: 0.7272 - val_loss: 0.6876 - val_accuracy: 0.7105 - 142ms/epoch - 4ms/step
# Epoch 140/300
# 34/34 - 0s - loss: 0.6613 - accuracy: 0.7263 - val_loss: 0.6872 - val_accuracy: 0.7039 - 130ms/epoch - 4ms/step
# Epoch 141/300
# 34/34 - 0s - loss: 0.6611 - accuracy: 0.7272 - val_loss: 0.6869 - val_accuracy: 0.7039 - 113ms/epoch - 3ms/step
# Epoch 142/300
# 34/34 - 0s - loss: 0.6605 - accuracy: 0.7272 - val_loss: 0.6864 - val_accuracy: 0.7072 - 118ms/epoch - 3ms/step
# Epoch 143/300
# 34/34 - 0s - loss: 0.6603 - accuracy: 0.7244 - val_loss: 0.6864 - val_accuracy: 0.7138 - 107ms/epoch - 3ms/step
# Epoch 144/300
# 34/34 - 0s - loss: 0.6599 - accuracy: 0.7253 - val_loss: 0.6859 - val_accuracy: 0.7072 - 113ms/epoch - 3ms/step
# Epoch 145/300
# 34/34 - 0s - loss: 0.6594 - accuracy: 0.7253 - val_loss: 0.6854 - val_accuracy: 0.7105 - 107ms/epoch - 3ms/step
# Epoch 146/300
# 34/34 - 0s - loss: 0.6591 - accuracy: 0.7263 - val_loss: 0.6851 - val_accuracy: 0.7105 - 114ms/epoch - 3ms/step
# Epoch 147/300
# 34/34 - 0s - loss: 0.6588 - accuracy: 0.7253 - val_loss: 0.6848 - val_accuracy: 0.7105 - 109ms/epoch - 3ms/step
# Epoch 148/300
# 34/34 - 0s - loss: 0.6586 - accuracy: 0.7253 - val_loss: 0.6845 - val_accuracy: 0.7105 - 108ms/epoch - 3ms/step
# Epoch 149/300
# 34/34 - 0s - loss: 0.6581 - accuracy: 0.7253 - val_loss: 0.6839 - val_accuracy: 0.7072 - 141ms/epoch - 4ms/step
# Epoch 150/300
# 34/34 - 0s - loss: 0.6578 - accuracy: 0.7281 - val_loss: 0.6837 - val_accuracy: 0.7105 - 113ms/epoch - 3ms/step
# Epoch 151/300
# 34/34 - 0s - loss: 0.6573 - accuracy: 0.7263 - val_loss: 0.6833 - val_accuracy: 0.7105 - 110ms/epoch - 3ms/step
# Epoch 152/300
# 34/34 - 0s - loss: 0.6571 - accuracy: 0.7263 - val_loss: 0.6831 - val_accuracy: 0.7105 - 106ms/epoch - 3ms/step
# Epoch 153/300
# 34/34 - 0s - loss: 0.6567 - accuracy: 0.7263 - val_loss: 0.6829 - val_accuracy: 0.7105 - 107ms/epoch - 3ms/step
# Epoch 154/300
# 34/34 - 0s - loss: 0.6564 - accuracy: 0.7263 - val_loss: 0.6824 - val_accuracy: 0.7105 - 120ms/epoch - 4ms/step
# Epoch 155/300
# 34/34 - 0s - loss: 0.6560 - accuracy: 0.7244 - val_loss: 0.6820 - val_accuracy: 0.7105 - 130ms/epoch - 4ms/step
# Epoch 156/300
# 34/34 - 0s - loss: 0.6558 - accuracy: 0.7253 - val_loss: 0.6816 - val_accuracy: 0.7105 - 140ms/epoch - 4ms/step
# Epoch 157/300
# 34/34 - 0s - loss: 0.6554 - accuracy: 0.7263 - val_loss: 0.6813 - val_accuracy: 0.7039 - 120ms/epoch - 4ms/step
# Epoch 158/300
# 34/34 - 0s - loss: 0.6551 - accuracy: 0.7272 - val_loss: 0.6812 - val_accuracy: 0.7105 - 109ms/epoch - 3ms/step
# Epoch 159/300
# 34/34 - 0s - loss: 0.6548 - accuracy: 0.7263 - val_loss: 0.6807 - val_accuracy: 0.7105 - 115ms/epoch - 3ms/step
# Epoch 160/300
# 34/34 - 0s - loss: 0.6547 - accuracy: 0.7300 - val_loss: 0.6806 - val_accuracy: 0.7105 - 110ms/epoch - 3ms/step
# Epoch 161/300
# 34/34 - 0s - loss: 0.6542 - accuracy: 0.7272 - val_loss: 0.6803 - val_accuracy: 0.7105 - 109ms/epoch - 3ms/step
# Epoch 162/300
# 34/34 - 0s - loss: 0.6538 - accuracy: 0.7272 - val_loss: 0.6797 - val_accuracy: 0.7072 - 106ms/epoch - 3ms/step
# Epoch 163/300
# 34/34 - 0s - loss: 0.6535 - accuracy: 0.7263 - val_loss: 0.6797 - val_accuracy: 0.7072 - 113ms/epoch - 3ms/step
# Epoch 164/300
# 34/34 - 0s - loss: 0.6533 - accuracy: 0.7272 - val_loss: 0.6794 - val_accuracy: 0.7105 - 115ms/epoch - 3ms/step
# Epoch 165/300
# 34/34 - 0s - loss: 0.6529 - accuracy: 0.7272 - val_loss: 0.6790 - val_accuracy: 0.7105 - 110ms/epoch - 3ms/step
# Epoch 166/300
# 34/34 - 0s - loss: 0.6526 - accuracy: 0.7281 - val_loss: 0.6788 - val_accuracy: 0.7105 - 119ms/epoch - 3ms/step
# Epoch 167/300
# 34/34 - 0s - loss: 0.6524 - accuracy: 0.7263 - val_loss: 0.6783 - val_accuracy: 0.7105 - 111ms/epoch - 3ms/step
# Epoch 168/300
# 34/34 - 0s - loss: 0.6519 - accuracy: 0.7272 - val_loss: 0.6781 - val_accuracy: 0.7105 - 106ms/epoch - 3ms/step
# Epoch 169/300
# 34/34 - 0s - loss: 0.6517 - accuracy: 0.7272 - val_loss: 0.6781 - val_accuracy: 0.7105 - 109ms/epoch - 3ms/step
# Epoch 170/300
# 34/34 - 0s - loss: 0.6514 - accuracy: 0.7263 - val_loss: 0.6777 - val_accuracy: 0.7105 - 113ms/epoch - 3ms/step
# Epoch 171/300
# 34/34 - 0s - loss: 0.6511 - accuracy: 0.7263 - val_loss: 0.6773 - val_accuracy: 0.7105 - 112ms/epoch - 3ms/step
# Epoch 172/300
# 34/34 - 0s - loss: 0.6509 - accuracy: 0.7291 - val_loss: 0.6767 - val_accuracy: 0.7138 - 109ms/epoch - 3ms/step
# Epoch 173/300
# 34/34 - 0s - loss: 0.6508 - accuracy: 0.7253 - val_loss: 0.6767 - val_accuracy: 0.7072 - 126ms/epoch - 4ms/step
# Epoch 174/300
# 34/34 - 0s - loss: 0.6504 - accuracy: 0.7253 - val_loss: 0.6764 - val_accuracy: 0.7105 - 138ms/epoch - 4ms/step
# Epoch 175/300
# 34/34 - 0s - loss: 0.6502 - accuracy: 0.7291 - val_loss: 0.6763 - val_accuracy: 0.7105 - 113ms/epoch - 3ms/step
# Epoch 176/300
# 34/34 - 0s - loss: 0.6499 - accuracy: 0.7244 - val_loss: 0.6758 - val_accuracy: 0.7105 - 119ms/epoch - 3ms/step
# Epoch 177/300
# 34/34 - 0s - loss: 0.6495 - accuracy: 0.7272 - val_loss: 0.6758 - val_accuracy: 0.7105 - 112ms/epoch - 3ms/step
# Epoch 178/300
# 34/34 - 0s - loss: 0.6493 - accuracy: 0.7281 - val_loss: 0.6754 - val_accuracy: 0.7105 - 110ms/epoch - 3ms/step
# Epoch 179/300
# 34/34 - 0s - loss: 0.6489 - accuracy: 0.7263 - val_loss: 0.6752 - val_accuracy: 0.7105 - 110ms/epoch - 3ms/step
# Epoch 180/300
# 34/34 - 0s - loss: 0.6488 - accuracy: 0.7291 - val_loss: 0.6749 - val_accuracy: 0.7105 - 110ms/epoch - 3ms/step
# Epoch 181/300
# 34/34 - 0s - loss: 0.6485 - accuracy: 0.7300 - val_loss: 0.6746 - val_accuracy: 0.7138 - 113ms/epoch - 3ms/step
# Epoch 182/300
# 34/34 - 0s - loss: 0.6482 - accuracy: 0.7253 - val_loss: 0.6744 - val_accuracy: 0.7105 - 112ms/epoch - 3ms/step
# Epoch 183/300
# 34/34 - 0s - loss: 0.6479 - accuracy: 0.7263 - val_loss: 0.6742 - val_accuracy: 0.7105 - 112ms/epoch - 3ms/step
# Epoch 184/300
# 34/34 - 0s - loss: 0.6477 - accuracy: 0.7300 - val_loss: 0.6741 - val_accuracy: 0.7105 - 113ms/epoch - 3ms/step
# Epoch 185/300
# 34/34 - 0s - loss: 0.6474 - accuracy: 0.7281 - val_loss: 0.6737 - val_accuracy: 0.7105 - 111ms/epoch - 3ms/step
# Epoch 186/300
# 34/34 - 0s - loss: 0.6472 - accuracy: 0.7281 - val_loss: 0.6734 - val_accuracy: 0.7105 - 110ms/epoch - 3ms/step
# Epoch 187/300
# 34/34 - 0s - loss: 0.6471 - accuracy: 0.7253 - val_loss: 0.6735 - val_accuracy: 0.7105 - 115ms/epoch - 3ms/step
# Epoch 188/300
# 34/34 - 0s - loss: 0.6466 - accuracy: 0.7253 - val_loss: 0.6731 - val_accuracy: 0.7105 - 119ms/epoch - 4ms/step
# Epoch 189/300
# 34/34 - 0s - loss: 0.6465 - accuracy: 0.7272 - val_loss: 0.6727 - val_accuracy: 0.7105 - 135ms/epoch - 4ms/step
# Epoch 190/300
# 34/34 - 0s - loss: 0.6462 - accuracy: 0.7263 - val_loss: 0.6726 - val_accuracy: 0.7105 - 129ms/epoch - 4ms/step
# Epoch 191/300
# 34/34 - 0s - loss: 0.6460 - accuracy: 0.7291 - val_loss: 0.6722 - val_accuracy: 0.7105 - 139ms/epoch - 4ms/step
# Epoch 192/300
# 34/34 - 0s - loss: 0.6458 - accuracy: 0.7281 - val_loss: 0.6719 - val_accuracy: 0.7072 - 113ms/epoch - 3ms/step
# Epoch 193/300
# 34/34 - 0s - loss: 0.6454 - accuracy: 0.7263 - val_loss: 0.6720 - val_accuracy: 0.7105 - 110ms/epoch - 3ms/step
# Epoch 194/300
# 34/34 - 0s - loss: 0.6455 - accuracy: 0.7253 - val_loss: 0.6716 - val_accuracy: 0.7105 - 108ms/epoch - 3ms/step
# Epoch 195/300
# 34/34 - 0s - loss: 0.6449 - accuracy: 0.7263 - val_loss: 0.6712 - val_accuracy: 0.7138 - 115ms/epoch - 3ms/step
# Epoch 196/300
# 34/34 - 0s - loss: 0.6448 - accuracy: 0.7291 - val_loss: 0.6713 - val_accuracy: 0.7138 - 112ms/epoch - 3ms/step
# Epoch 197/300
# 34/34 - 0s - loss: 0.6445 - accuracy: 0.7272 - val_loss: 0.6708 - val_accuracy: 0.7105 - 116ms/epoch - 3ms/step
# Epoch 198/300
# 34/34 - 0s - loss: 0.6443 - accuracy: 0.7263 - val_loss: 0.6707 - val_accuracy: 0.7105 - 112ms/epoch - 3ms/step
# Epoch 199/300
# 34/34 - 0s - loss: 0.6440 - accuracy: 0.7263 - val_loss: 0.6707 - val_accuracy: 0.7072 - 113ms/epoch - 3ms/step
# Epoch 200/300
# 34/34 - 0s - loss: 0.6438 - accuracy: 0.7272 - val_loss: 0.6700 - val_accuracy: 0.7105 - 111ms/epoch - 3ms/step
# Epoch 201/300
# 34/34 - 0s - loss: 0.6437 - accuracy: 0.7291 - val_loss: 0.6697 - val_accuracy: 0.7105 - 112ms/epoch - 3ms/step
# Epoch 202/300
# 34/34 - 0s - loss: 0.6434 - accuracy: 0.7272 - val_loss: 0.6696 - val_accuracy: 0.7105 - 111ms/epoch - 3ms/step
# Epoch 203/300
# 34/34 - 0s - loss: 0.6433 - accuracy: 0.7272 - val_loss: 0.6694 - val_accuracy: 0.7105 - 113ms/epoch - 3ms/step
# Epoch 204/300
# 34/34 - 0s - loss: 0.6430 - accuracy: 0.7291 - val_loss: 0.6690 - val_accuracy: 0.7105 - 114ms/epoch - 3ms/step
# Epoch 205/300
# 34/34 - 0s - loss: 0.6426 - accuracy: 0.7291 - val_loss: 0.6693 - val_accuracy: 0.7105 - 114ms/epoch - 3ms/step
# Epoch 206/300
# 34/34 - 0s - loss: 0.6424 - accuracy: 0.7291 - val_loss: 0.6688 - val_accuracy: 0.7105 - 108ms/epoch - 3ms/step
# Epoch 207/300
# 34/34 - 0s - loss: 0.6421 - accuracy: 0.7291 - val_loss: 0.6687 - val_accuracy: 0.7105 - 128ms/epoch - 4ms/step
# Epoch 208/300
# 34/34 - 0s - loss: 0.6425 - accuracy: 0.7291 - val_loss: 0.6683 - val_accuracy: 0.7105 - 140ms/epoch - 4ms/step
# Epoch 209/300
# 34/34 - 0s - loss: 0.6419 - accuracy: 0.7309 - val_loss: 0.6682 - val_accuracy: 0.7105 - 109ms/epoch - 3ms/step
# Epoch 210/300
# 34/34 - 0s - loss: 0.6417 - accuracy: 0.7291 - val_loss: 0.6683 - val_accuracy: 0.7138 - 117ms/epoch - 3ms/step
# Epoch 211/300
# 34/34 - 0s - loss: 0.6414 - accuracy: 0.7291 - val_loss: 0.6680 - val_accuracy: 0.7105 - 106ms/epoch - 3ms/step
# Epoch 212/300
# 34/34 - 0s - loss: 0.6412 - accuracy: 0.7309 - val_loss: 0.6674 - val_accuracy: 0.7105 - 113ms/epoch - 3ms/step
# Epoch 213/300
# 34/34 - 0s - loss: 0.6409 - accuracy: 0.7281 - val_loss: 0.6674 - val_accuracy: 0.7105 - 110ms/epoch - 3ms/step
# Epoch 214/300
# 34/34 - 0s - loss: 0.6407 - accuracy: 0.7309 - val_loss: 0.6670 - val_accuracy: 0.7105 - 111ms/epoch - 3ms/step
# Epoch 215/300
# 34/34 - 0s - loss: 0.6405 - accuracy: 0.7309 - val_loss: 0.6670 - val_accuracy: 0.7105 - 109ms/epoch - 3ms/step
# Epoch 216/300
# 34/34 - 0s - loss: 0.6404 - accuracy: 0.7281 - val_loss: 0.6667 - val_accuracy: 0.7105 - 114ms/epoch - 3ms/step
# Epoch 217/300
# 34/34 - 0s - loss: 0.6402 - accuracy: 0.7309 - val_loss: 0.6666 - val_accuracy: 0.7105 - 111ms/epoch - 3ms/step
# Epoch 218/300
# 34/34 - 0s - loss: 0.6398 - accuracy: 0.7291 - val_loss: 0.6665 - val_accuracy: 0.7105 - 112ms/epoch - 3ms/step
# Epoch 219/300
# 34/34 - 0s - loss: 0.6399 - accuracy: 0.7300 - val_loss: 0.6664 - val_accuracy: 0.7105 - 115ms/epoch - 3ms/step
# Epoch 220/300
# 34/34 - 0s - loss: 0.6397 - accuracy: 0.7281 - val_loss: 0.6664 - val_accuracy: 0.7138 - 105ms/epoch - 3ms/step
# Epoch 221/300
# 34/34 - 0s - loss: 0.6394 - accuracy: 0.7263 - val_loss: 0.6659 - val_accuracy: 0.7105 - 113ms/epoch - 3ms/step
# Epoch 222/300
# 34/34 - 0s - loss: 0.6394 - accuracy: 0.7300 - val_loss: 0.6658 - val_accuracy: 0.7138 - 123ms/epoch - 4ms/step
# Epoch 223/300
# 34/34 - 0s - loss: 0.6391 - accuracy: 0.7309 - val_loss: 0.6655 - val_accuracy: 0.7105 - 140ms/epoch - 4ms/step
# Epoch 224/300
# 34/34 - 0s - loss: 0.6389 - accuracy: 0.7291 - val_loss: 0.6655 - val_accuracy: 0.7138 - 117ms/epoch - 3ms/step
# Epoch 225/300
# 34/34 - 0s - loss: 0.6386 - accuracy: 0.7291 - val_loss: 0.6652 - val_accuracy: 0.7105 - 143ms/epoch - 4ms/step
# Epoch 226/300
# 34/34 - 0s - loss: 0.6383 - accuracy: 0.7318 - val_loss: 0.6651 - val_accuracy: 0.7105 - 110ms/epoch - 3ms/step
# Epoch 227/300
# 34/34 - 0s - loss: 0.6383 - accuracy: 0.7300 - val_loss: 0.6648 - val_accuracy: 0.7105 - 112ms/epoch - 3ms/step
# Epoch 228/300
# 34/34 - 0s - loss: 0.6379 - accuracy: 0.7291 - val_loss: 0.6646 - val_accuracy: 0.7105 - 107ms/epoch - 3ms/step
# Epoch 229/300
# 34/34 - 0s - loss: 0.6378 - accuracy: 0.7300 - val_loss: 0.6645 - val_accuracy: 0.7105 - 113ms/epoch - 3ms/step
# Epoch 230/300
# 34/34 - 0s - loss: 0.6377 - accuracy: 0.7309 - val_loss: 0.6643 - val_accuracy: 0.7105 - 108ms/epoch - 3ms/step
# Epoch 231/300
# 34/34 - 0s - loss: 0.6374 - accuracy: 0.7291 - val_loss: 0.6639 - val_accuracy: 0.7105 - 112ms/epoch - 3ms/step
# Epoch 232/300
# 34/34 - 0s - loss: 0.6373 - accuracy: 0.7272 - val_loss: 0.6639 - val_accuracy: 0.7138 - 113ms/epoch - 3ms/step
# Epoch 233/300
# 34/34 - 0s - loss: 0.6372 - accuracy: 0.7300 - val_loss: 0.6640 - val_accuracy: 0.7105 - 108ms/epoch - 3ms/step
# Epoch 234/300
# 34/34 - 0s - loss: 0.6371 - accuracy: 0.7309 - val_loss: 0.6635 - val_accuracy: 0.7105 - 118ms/epoch - 3ms/step
# Epoch 235/300
# 34/34 - 0s - loss: 0.6368 - accuracy: 0.7281 - val_loss: 0.6633 - val_accuracy: 0.7105 - 115ms/epoch - 3ms/step
# Epoch 236/300
# 34/34 - 0s - loss: 0.6366 - accuracy: 0.7272 - val_loss: 0.6633 - val_accuracy: 0.7105 - 112ms/epoch - 3ms/step
# Epoch 237/300
# 34/34 - 0s - loss: 0.6364 - accuracy: 0.7318 - val_loss: 0.6633 - val_accuracy: 0.7105 - 111ms/epoch - 3ms/step
# Epoch 238/300
# 34/34 - 0s - loss: 0.6363 - accuracy: 0.7291 - val_loss: 0.6629 - val_accuracy: 0.7105 - 109ms/epoch - 3ms/step
# Epoch 239/300
# 34/34 - 0s - loss: 0.6360 - accuracy: 0.7300 - val_loss: 0.6627 - val_accuracy: 0.7138 - 110ms/epoch - 3ms/step
# Epoch 240/300
# 34/34 - 0s - loss: 0.6362 - accuracy: 0.7309 - val_loss: 0.6624 - val_accuracy: 0.7138 - 113ms/epoch - 3ms/step
# Epoch 241/300
# 34/34 - 0s - loss: 0.6360 - accuracy: 0.7291 - val_loss: 0.6625 - val_accuracy: 0.7138 - 109ms/epoch - 3ms/step
# Epoch 242/300
# 34/34 - 0s - loss: 0.6355 - accuracy: 0.7272 - val_loss: 0.6620 - val_accuracy: 0.7138 - 147ms/epoch - 4ms/step
# Epoch 243/300
# 34/34 - 0s - loss: 0.6353 - accuracy: 0.7291 - val_loss: 0.6620 - val_accuracy: 0.7105 - 121ms/epoch - 4ms/step
# Epoch 244/300
# 34/34 - 0s - loss: 0.6351 - accuracy: 0.7281 - val_loss: 0.6617 - val_accuracy: 0.7138 - 109ms/epoch - 3ms/step
# Epoch 245/300
# 34/34 - 0s - loss: 0.6350 - accuracy: 0.7263 - val_loss: 0.6617 - val_accuracy: 0.7138 - 106ms/epoch - 3ms/step
# Epoch 246/300
# 34/34 - 0s - loss: 0.6352 - accuracy: 0.7309 - val_loss: 0.6619 - val_accuracy: 0.7105 - 111ms/epoch - 3ms/step
# Epoch 247/300
# 34/34 - 0s - loss: 0.6347 - accuracy: 0.7281 - val_loss: 0.6613 - val_accuracy: 0.7138 - 112ms/epoch - 3ms/step
# Epoch 248/300
# 34/34 - 0s - loss: 0.6345 - accuracy: 0.7309 - val_loss: 0.6612 - val_accuracy: 0.7105 - 108ms/epoch - 3ms/step
# Epoch 249/300
# 34/34 - 0s - loss: 0.6343 - accuracy: 0.7291 - val_loss: 0.6611 - val_accuracy: 0.7105 - 115ms/epoch - 3ms/step
# Epoch 250/300
# 34/34 - 0s - loss: 0.6343 - accuracy: 0.7309 - val_loss: 0.6609 - val_accuracy: 0.7105 - 115ms/epoch - 3ms/step
# Epoch 251/300
# 34/34 - 0s - loss: 0.6341 - accuracy: 0.7300 - val_loss: 0.6610 - val_accuracy: 0.7138 - 110ms/epoch - 3ms/step
# Epoch 252/300
# 34/34 - 0s - loss: 0.6339 - accuracy: 0.7291 - val_loss: 0.6609 - val_accuracy: 0.7138 - 109ms/epoch - 3ms/step
# Epoch 253/300
# 34/34 - 0s - loss: 0.6337 - accuracy: 0.7291 - val_loss: 0.6607 - val_accuracy: 0.7171 - 118ms/epoch - 3ms/step
# Epoch 254/300
# 34/34 - 0s - loss: 0.6337 - accuracy: 0.7272 - val_loss: 0.6603 - val_accuracy: 0.7138 - 144ms/epoch - 4ms/step
# Epoch 255/300
# 34/34 - 0s - loss: 0.6333 - accuracy: 0.7281 - val_loss: 0.6601 - val_accuracy: 0.7105 - 110ms/epoch - 3ms/step
# Epoch 256/300
# 34/34 - 0s - loss: 0.6336 - accuracy: 0.7272 - val_loss: 0.6599 - val_accuracy: 0.7138 - 112ms/epoch - 3ms/step
# Epoch 257/300
# 34/34 - 0s - loss: 0.6331 - accuracy: 0.7318 - val_loss: 0.6599 - val_accuracy: 0.7105 - 117ms/epoch - 3ms/step
# Epoch 258/300
# 34/34 - 0s - loss: 0.6331 - accuracy: 0.7281 - val_loss: 0.6595 - val_accuracy: 0.7138 - 121ms/epoch - 4ms/step
# Epoch 259/300
# 34/34 - 0s - loss: 0.6328 - accuracy: 0.7291 - val_loss: 0.6598 - val_accuracy: 0.7138 - 137ms/epoch - 4ms/step
# Epoch 260/300
# 34/34 - 0s - loss: 0.6328 - accuracy: 0.7272 - val_loss: 0.6594 - val_accuracy: 0.7105 - 124ms/epoch - 4ms/step
# Epoch 261/300
# 34/34 - 0s - loss: 0.6324 - accuracy: 0.7291 - val_loss: 0.6591 - val_accuracy: 0.7105 - 117ms/epoch - 3ms/step
# Epoch 262/300
# 34/34 - 0s - loss: 0.6323 - accuracy: 0.7291 - val_loss: 0.6592 - val_accuracy: 0.7138 - 115ms/epoch - 3ms/step
# Epoch 263/300
# 34/34 - 0s - loss: 0.6324 - accuracy: 0.7309 - val_loss: 0.6588 - val_accuracy: 0.7105 - 112ms/epoch - 3ms/step
# Epoch 264/300
# 34/34 - 0s - loss: 0.6319 - accuracy: 0.7309 - val_loss: 0.6588 - val_accuracy: 0.7105 - 109ms/epoch - 3ms/step
# Epoch 265/300
# 34/34 - 0s - loss: 0.6318 - accuracy: 0.7291 - val_loss: 0.6587 - val_accuracy: 0.7105 - 112ms/epoch - 3ms/step
# Epoch 266/300
# 34/34 - 0s - loss: 0.6318 - accuracy: 0.7300 - val_loss: 0.6586 - val_accuracy: 0.7105 - 118ms/epoch - 3ms/step
# Epoch 267/300
# 34/34 - 0s - loss: 0.6316 - accuracy: 0.7328 - val_loss: 0.6584 - val_accuracy: 0.7105 - 113ms/epoch - 3ms/step
# Epoch 268/300
# 34/34 - 0s - loss: 0.6314 - accuracy: 0.7328 - val_loss: 0.6582 - val_accuracy: 0.7105 - 107ms/epoch - 3ms/step
# Epoch 269/300
# 34/34 - 0s - loss: 0.6312 - accuracy: 0.7300 - val_loss: 0.6583 - val_accuracy: 0.7105 - 116ms/epoch - 3ms/step
# Epoch 270/300
# 34/34 - 0s - loss: 0.6314 - accuracy: 0.7300 - val_loss: 0.6578 - val_accuracy: 0.7171 - 110ms/epoch - 3ms/step
# Epoch 271/300
# 34/34 - 0s - loss: 0.6309 - accuracy: 0.7328 - val_loss: 0.6580 - val_accuracy: 0.7105 - 109ms/epoch - 3ms/step
# Epoch 272/300
# 34/34 - 0s - loss: 0.6308 - accuracy: 0.7318 - val_loss: 0.6578 - val_accuracy: 0.7105 - 110ms/epoch - 3ms/step
# Epoch 273/300
# 34/34 - 0s - loss: 0.6307 - accuracy: 0.7272 - val_loss: 0.6575 - val_accuracy: 0.7105 - 115ms/epoch - 3ms/step
# Epoch 274/300
# 34/34 - 0s - loss: 0.6306 - accuracy: 0.7309 - val_loss: 0.6572 - val_accuracy: 0.7138 - 118ms/epoch - 3ms/step
# Epoch 275/300
# 34/34 - 0s - loss: 0.6303 - accuracy: 0.7300 - val_loss: 0.6573 - val_accuracy: 0.7105 - 115ms/epoch - 3ms/step
# Epoch 276/300
# 34/34 - 0s - loss: 0.6303 - accuracy: 0.7291 - val_loss: 0.6570 - val_accuracy: 0.7105 - 137ms/epoch - 4ms/step
# Epoch 277/300
# 34/34 - 0s - loss: 0.6302 - accuracy: 0.7309 - val_loss: 0.6570 - val_accuracy: 0.7105 - 127ms/epoch - 4ms/step
# Epoch 278/300
# 34/34 - 0s - loss: 0.6300 - accuracy: 0.7272 - val_loss: 0.6569 - val_accuracy: 0.7138 - 109ms/epoch - 3ms/step
# Epoch 279/300
# 34/34 - 0s - loss: 0.6299 - accuracy: 0.7337 - val_loss: 0.6567 - val_accuracy: 0.7138 - 109ms/epoch - 3ms/step
# Epoch 280/300
# 34/34 - 0s - loss: 0.6299 - accuracy: 0.7291 - val_loss: 0.6570 - val_accuracy: 0.7138 - 117ms/epoch - 3ms/step
# Epoch 281/300
# 34/34 - 0s - loss: 0.6296 - accuracy: 0.7309 - val_loss: 0.6567 - val_accuracy: 0.7138 - 115ms/epoch - 3ms/step
# Epoch 282/300
# 34/34 - 0s - loss: 0.6294 - accuracy: 0.7291 - val_loss: 0.6563 - val_accuracy: 0.7105 - 110ms/epoch - 3ms/step
# Epoch 283/300
# 34/34 - 0s - loss: 0.6294 - accuracy: 0.7281 - val_loss: 0.6564 - val_accuracy: 0.7105 - 108ms/epoch - 3ms/step
# Epoch 284/300
# 34/34 - 0s - loss: 0.6294 - accuracy: 0.7281 - val_loss: 0.6559 - val_accuracy: 0.7138 - 110ms/epoch - 3ms/step
# Epoch 285/300
# 34/34 - 0s - loss: 0.6289 - accuracy: 0.7309 - val_loss: 0.6558 - val_accuracy: 0.7138 - 134ms/epoch - 4ms/step
# Epoch 286/300
# 34/34 - 0s - loss: 0.6290 - accuracy: 0.7291 - val_loss: 0.6557 - val_accuracy: 0.7138 - 112ms/epoch - 3ms/step
# Epoch 287/300
# 34/34 - 0s - loss: 0.6287 - accuracy: 0.7272 - val_loss: 0.6557 - val_accuracy: 0.7138 - 116ms/epoch - 3ms/step
# Epoch 288/300
# 34/34 - 0s - loss: 0.6286 - accuracy: 0.7291 - val_loss: 0.6556 - val_accuracy: 0.7138 - 116ms/epoch - 3ms/step
# Epoch 289/300
# 34/34 - 0s - loss: 0.6285 - accuracy: 0.7291 - val_loss: 0.6553 - val_accuracy: 0.7138 - 110ms/epoch - 3ms/step
# Epoch 290/300
# 34/34 - 0s - loss: 0.6286 - accuracy: 0.7300 - val_loss: 0.6554 - val_accuracy: 0.7138 - 115ms/epoch - 3ms/step
# Epoch 291/300
# 34/34 - 0s - loss: 0.6282 - accuracy: 0.7309 - val_loss: 0.6553 - val_accuracy: 0.7138 - 110ms/epoch - 3ms/step
# Epoch 292/300
# 34/34 - 0s - loss: 0.6280 - accuracy: 0.7281 - val_loss: 0.6550 - val_accuracy: 0.7138 - 114ms/epoch - 3ms/step
# Epoch 293/300
# 34/34 - 0s - loss: 0.6280 - accuracy: 0.7300 - val_loss: 0.6552 - val_accuracy: 0.7105 - 147ms/epoch - 4ms/step
# Epoch 294/300
# 34/34 - 0s - loss: 0.6278 - accuracy: 0.7300 - val_loss: 0.6548 - val_accuracy: 0.7105 - 127ms/epoch - 4ms/step
# Epoch 295/300
# 34/34 - 0s - loss: 0.6276 - accuracy: 0.7291 - val_loss: 0.6549 - val_accuracy: 0.7138 - 118ms/epoch - 3ms/step
# Epoch 296/300
# 34/34 - 0s - loss: 0.6277 - accuracy: 0.7309 - val_loss: 0.6546 - val_accuracy: 0.7138 - 110ms/epoch - 3ms/step
# Epoch 297/300
# 34/34 - 0s - loss: 0.6276 - accuracy: 0.7281 - val_loss: 0.6545 - val_accuracy: 0.7138 - 114ms/epoch - 3ms/step
# Epoch 298/300
# 34/34 - 0s - loss: 0.6274 - accuracy: 0.7291 - val_loss: 0.6543 - val_accuracy: 0.7105 - 115ms/epoch - 3ms/step
# Epoch 299/300
# 34/34 - 0s - loss: 0.6272 - accuracy: 0.7328 - val_loss: 0.6542 - val_accuracy: 0.7105 - 111ms/epoch - 3ms/step
# Epoch 300/300
# 34/34 - 0s - loss: 0.6271 - accuracy: 0.7300 - val_loss: 0.6543 - val_accuracy: 0.7105 - 110ms/epoch - 3ms/step

# %%
fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(25, 4))
ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[0].set_title('Accuracy')
ax[0].set_xlabel('Accuracy')
ax[0].set_ylabel('Epoch')

ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[1].set_title('Loss')
ax[1].set_xlabel('Loss')
ax[1].set_ylabel('Epoch')

plt.legend(['Train', 'Test'])
plt.show()

# %%
from sklearn.metrics import classification_report
y_pred = np.rint(model.predict(X_val, verbose=0))

print(classification_report(y_val,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89         4
#            1       1.00      0.83      0.91         6
#
#    micro avg       0.90      0.90      0.90        10
#    macro avg       0.90      0.92      0.90        10
# weighted avg       0.92      0.90      0.90        10
#  samples avg       0.90      0.90      0.90        10

# %%
labels = ['0', '1']

y_pred = np.rint(model.predict(X_val, verbose=0).argmax(axis=1))
con_mat = confusion_matrix(y_val.argmax(axis=1),y_pred)

cm_percent = con_mat.astype('float') / con_mat.sum(axis=1)[:, np.newaxis]

sns.heatmap(cm_percent, annot=True, fmt='.2%', cmap='Blues', xticklabels=labels, yticklabels=labels)

plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # 6. Supervised Learning

# %%
X = data.drop(columns=['status']).values
Y = data['status']

print(Counter(Y))
undersample = RandomUnderSampler()
# undersample = SMOTE()
X, Y = undersample.fit_resample(X, Y)
print(Counter(Y))

Y = Y.values

# scaler = MinMaxScaler(feature_range=(0,1))
scaler = PowerTransformer(method='yeo-johnson', standardize=True)
X = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X, Y, train_size=0.9, random_state = 42)

print(X_train.shape)
print(X_test.shape)
# Out:
# Counter({1: 147, 0: 48})
# Counter({0: 48, 1: 48})
# (86, 22)
# (10, 22)

# %% [markdown]
# ### 6.2 Stacking Classifier

# %%
adaboost = AdaBoostClassifier(n_estimators=100, random_state=42)
bagging = BaggingClassifier(n_jobs=-1)
extraTrees = ExtraTreesClassifier(max_depth=100, n_jobs=-1, random_state=42)
gradient = GradientBoostingClassifier(max_depth=100, n_estimators=100, learning_rate=.01,  random_state=42)
randomForest = RandomForestClassifier(max_depth=100, random_state=42, n_jobs=-1)
histGradient = HistGradientBoostingClassifier()
XGB = XGBClassifier(n_jobs=-1)
knn = KNeighborsClassifier(n_jobs=-1)
decisionTree = DecisionTreeClassifier(random_state=42, max_depth=100)
pac = PassiveAggressiveClassifier(random_state=42)
linear = LogisticRegression(random_state=42)

model = StackingClassifier([
    # ('bagging', bagging),
    # ('adaboost', adaboost),
    # ('extraTress', extraTrees),
    # ('randomforest', randomForest),
    # ('decisionTree', decisionTree),
    # ('histGradient', histGradient),
    ('XGB', XGB),
    # ('pac', pac),
    # ('linear', linear),
    # ('gradient', gradient),
    # ('knn', knn),
], n_jobs=-1)

# %%
model.fit(X_train, y_train)
# Out:
# StackingClassifier(estimators=[('XGB',
#                                 XGBClassifier(base_score=None, booster=None,
#                                               callbacks=None,
#                                               colsample_bylevel=None,
#                                               colsample_bynode=None,
#                                               colsample_bytree=None,
#                                               early_stopping_rounds=None,
#                                               enable_categorical=False,
#                                               eval_metric=None,
#                                               feature_types=None, gamma=None,
#                                               gpu_id=None, grow_policy=None,
#                                               importance_type=None,
#                                               interaction_constraints=None,
#                                               learning_rate=None, max_bin=None,
#                                               max_cat_threshold=None,
#                                               max_cat_to_onehot=None,
#                                               max_delta_step=None,
#                                               max_depth=None, max_leaves=None,
#                                               min_child_weight=None,
#                                               missing=nan,
#                                               monotone_constraints=None,
#                                               n_estimators=100, n_jobs=-1,
#                                               num_parallel_tree=None,
#                                               predictor=None, random_state=None, ...))],
#                    n_jobs=-1)

# %%
print("Train Score : ",round((model.score(X_train, y_train)*100), 2),'%')
print("Test Score  : ",round((model.score(X_test, y_test)*100), 2),'%')
# Out:
# Train Score :  100.0 %
# Test Score  :  90.0 %

# %%
y_pred = model.predict(X_test)
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89         5
#            1       0.83      1.00      0.91         5
#
#     accuracy                           0.90        10
#    macro avg       0.92      0.90      0.90        10
# weighted avg       0.92      0.90      0.90        10

# %%
labels = ['0', '1']

y_pred = model.predict(X_test)
con_mat = confusion_matrix(y_test,y_pred)

cm_percent = con_mat.astype('float') / con_mat.sum(axis=1)[:, np.newaxis]

sns.heatmap(cm_percent, annot=True, fmt='.2%', cmap='Blues', xticklabels=labels, yticklabels=labels)

plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix - Fake News Detection')
plt.show()

# %% [markdown]
# ### 6.2. Pycaret

# %%
s = ClassificationExperiment()
s.setup(data, target = 'diagnosis', session_id = 123)

# %%
best = s.compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              09:02:22
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library

# %%
s.evaluate_model(best)

# %%
print(best)
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_samples_leaf=1,
#                      min_samples_split=2, min_weight_fraction_leaf=0.0,
#                      n_estimators=100, n_jobs=-1, oob_score=False,
#                      random_state=123, verbose=0, warm_start=False)

# %%
s.predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7df00">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7df00_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7df00_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_7df00_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_7df00_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_7df00_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_7df00_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_7df00_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_7df00_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7df00_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7df00_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_7df00_row0_col1" class="data row0 col1" >0.9649</td>
#       <td id="T_7df00_row0_col2" class="data row0 col2" >0.9918</td>
#       <td id="T_7df00_row0_col3" class="data row0 col3" >0.9688</td>
#       <td id="T_7df00_row0_col4" class="data row0 col4" >0.9394</td>
#       <td id="T_7df00_row0_col5" class="data row0 col5" >0.9538</td>
#       <td id="T_7df00_row0_col6" class="data row0 col6" >0.9256</td>
#       <td id="T_7df00_row0_col7" class="data row0 col7" >0.9258</td>
#     </tr>
#   </tbody>
# </table>
#      radius_mean  texture_mean  perimeter_mean    area_mean  smoothness_mean  \
# 115    11.930000     21.530001       76.529999   438.600006          0.09768
# 21      9.504000     12.440000       60.340000   273.899994          0.10240
# 382    12.050000     22.719999       78.750000   447.799988          0.06935
# 136    11.710000     16.670000       74.720001   423.600006          0.10510
# 2      19.690001     21.250000      130.000000  1203.000000          0.10960
# ..           ...           ...             ...          ...              ...
# 526    13.460000     18.750000       87.440002   551.099976          0.10750
# 142    11.430000     17.309999       73.660004   398.000000          0.10920
# 238    14.220000     27.850000       92.550003   623.900024          0.08223
# 106    11.640000     18.330000       75.169998   412.500000          0.11420
# 437    14.040000     15.980000       89.779999   611.200012          0.08458
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 115           0.07849         0.03328              0.02008         0.1688
# 21            0.06492         0.02956              0.02076         0.1815
# 382           0.10730         0.07943              0.02978         0.1203
# 136           0.06095         0.03592              0.02600         0.1339
# 2             0.15990         0.19740              0.12790         0.2069
# ..                ...             ...                  ...            ...
# 526           0.11380         0.04201              0.03152         0.1723
# 142           0.09486         0.02031              0.01861         0.1645
# 238           0.10390         0.11030              0.04408         0.1342
# 106           0.10170         0.07070              0.03485         0.1801
# 437           0.05895         0.03534              0.02944         0.1714
#
#      fractal_dimension_mean  ...   area_worst  smoothness_worst  \
# 115                 0.06194  ...   583.000000           0.15000
# 21                  0.06905  ...   314.899994           0.13240
# 382                 0.06659  ...   488.399994           0.08799
# 136                 0.05945  ...   546.700012           0.12710
# 2                   0.05999  ...  1709.000000           0.14440
# ..                      ...  ...          ...               ...
# 526                 0.06317  ...   719.799988           0.16240
# 142                 0.06562  ...   503.000000           0.14130
# 238                 0.06129  ...   764.000000           0.10810
# 106                 0.06520  ...   521.700012           0.16880
# 437                 0.05898  ...   750.000000           0.11950
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 115             0.2399          0.15030               0.07247          0.2438
# 21              0.1148          0.08867               0.06227          0.2450
# 382             0.3214          0.29120               0.10920          0.2191
# 136             0.1028          0.10460               0.06968          0.1712
# 2               0.4245          0.45040               0.24300          0.3613
# ..                 ...              ...                   ...             ...
# 526             0.3124          0.26540               0.14270          0.3518
# 142             0.1792          0.07708               0.06402          0.2584
# 238             0.2426          0.30640               0.08219          0.1890
# 106             0.2660          0.28730               0.12180          0.2806
# 437             0.1252          0.11170               0.07453          0.2725
#
#      fractal_dimension_worst  diagnosis  prediction_label  prediction_score
# 115                  0.08541          0                 0              0.99
# 21                   0.07773          0                 0              1.00
# 382                  0.09349          0                 0              0.93
# 136                  0.07343          0                 0              0.98
# 2                    0.08758          1                 1              1.00
# ..                       ...        ...               ...               ...
# 526                  0.08665          0                 0              0.74
# 142                  0.08096          0                 0              1.00
# 238                  0.07796          0                 0              0.62
# 106                  0.09097          0                 0              0.89
# 437                  0.07234          0                 0              0.92
#
# [171 rows x 33 columns]

# %%
model = s.create_model('et')
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              09:07:18
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# <style type="text/css">
# #T_a89c6_row10_col0, #T_a89c6_row10_col1, #T_a89c6_row10_col2, #T_a89c6_row10_col3, #T_a89c6_row10_col4, #T_a89c6_row10_col5, #T_a89c6_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_a89c6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a89c6_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_a89c6_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_a89c6_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_a89c6_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_a89c6_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_a89c6_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_a89c6_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a89c6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a89c6_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_a89c6_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_a89c6_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_a89c6_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_a89c6_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_a89c6_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_a89c6_row0_col6" class="data row0 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a89c6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a89c6_row1_col0" class="data row1 col0" >0.9500</td>
#       <td id="T_a89c6_row1_col1" class="data row1 col1" >0.9853</td>
#       <td id="T_a89c6_row1_col2" class="data row1 col2" >0.8667</td>
#       <td id="T_a89c6_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_a89c6_row1_col4" class="data row1 col4" >0.9286</td>
#       <td id="T_a89c6_row1_col5" class="data row1 col5" >0.8904</td>
#       <td id="T_a89c6_row1_col6" class="data row1 col6" >0.8958</td>
#     </tr>
#     <tr>
#       <th id="T_a89c6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a89c6_row2_col0" class="data row2 col0" >0.9250</td>
#       <td id="T_a89c6_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_a89c6_row2_col2" class="data row2 col2" >0.8000</td>
#       <td id="T_a89c6_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_a89c6_row2_col4" class="data row2 col4" >0.8889</td>
#       <td id="T_a89c6_row2_col5" class="data row2 col5" >0.8333</td>
#       <td id="T_a89c6_row2_col6" class="data row2 col6" >0.8452</td>
#     </tr>
#     <tr>
#       <th id="T_a89c6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a89c6_row3_col0" class="data row3 col0" >0.9500</td>
#       <td id="T_a89c6_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_a89c6_row3_col2" class="data row3 col2" >0.8667</td>
#       <td id="T_a89c6_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_a89c6_row3_col4" class="data row3 col4" >0.9286</td>
#       <td id="T_a89c6_row3_col5" class="data row3 col5" >0.8904</td>
#       <td id="T_a89c6_row3_col6" class="data row3 col6" >0.8958</td>
#     </tr>
#     <tr>
#       <th id="T_a89c6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a89c6_row4_col0" class="data row4 col0" >0.9750</td>
#       <td id="T_a89c6_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_a89c6_row4_col2" class="data row4 col2" >0.9333</td>
#       <td id="T_a89c6_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_a89c6_row4_col4" class="data row4 col4" >0.9655</td>
#       <td id="T_a89c6_row4_col5" class="data row4 col5" >0.9459</td>
#       <td id="T_a89c6_row4_col6" class="data row4 col6" >0.9473</td>
#     </tr>
#     <tr>
#       <th id="T_a89c6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a89c6_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_a89c6_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_a89c6_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_a89c6_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_a89c6_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_a89c6_row5_col5" class="data row5 col5" >1.0000</td>
#       <td id="T_a89c6_row5_col6" class="data row5 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a89c6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a89c6_row6_col0" class="data row6 col0" >0.9500</td>
#       <td id="T_a89c6_row6_col1" class="data row6 col1" >0.9960</td>
#       <td id="T_a89c6_row6_col2" class="data row6 col2" >0.9333</td>
#       <td id="T_a89c6_row6_col3" class="data row6 col3" >0.9333</td>
#       <td id="T_a89c6_row6_col4" class="data row6 col4" >0.9333</td>
#       <td id="T_a89c6_row6_col5" class="data row6 col5" >0.8933</td>
#       <td id="T_a89c6_row6_col6" class="data row6 col6" >0.8933</td>
#     </tr>
#     <tr>
#       <th id="T_a89c6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a89c6_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_a89c6_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_a89c6_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_a89c6_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_a89c6_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_a89c6_row7_col5" class="data row7 col5" >1.0000</td>
#       <td id="T_a89c6_row7_col6" class="data row7 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a89c6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a89c6_row8_col0" class="data row8 col0" >0.9487</td>
#       <td id="T_a89c6_row8_col1" class="data row8 col1" >0.9800</td>
#       <td id="T_a89c6_row8_col2" class="data row8 col2" >0.9286</td>
#       <td id="T_a89c6_row8_col3" class="data row8 col3" >0.9286</td>
#       <td id="T_a89c6_row8_col4" class="data row8 col4" >0.9286</td>
#       <td id="T_a89c6_row8_col5" class="data row8 col5" >0.8886</td>
#       <td id="T_a89c6_row8_col6" class="data row8 col6" >0.8886</td>
#     </tr>
#     <tr>
#       <th id="T_a89c6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a89c6_row9_col0" class="data row9 col0" >0.9744</td>
#       <td id="T_a89c6_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_a89c6_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_a89c6_row9_col3" class="data row9 col3" >0.9333</td>
#       <td id="T_a89c6_row9_col4" class="data row9 col4" >0.9655</td>
#       <td id="T_a89c6_row9_col5" class="data row9 col5" >0.9451</td>
#       <td id="T_a89c6_row9_col6" class="data row9 col6" >0.9466</td>
#     </tr>
#     <tr>
#       <th id="T_a89c6_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_a89c6_row10_col0" class="data row10 col0" >0.9673</td>
#       <td id="T_a89c6_row10_col1" class="data row10 col1" >0.9961</td>
#       <td id="T_a89c6_row10_col2" class="data row10 col2" >0.9329</td>
#       <td id="T_a89c6_row10_col3" class="data row10 col3" >0.9795</td>
#       <td id="T_a89c6_row10_col4" class="data row10 col4" >0.9539</td>
#       <td id="T_a89c6_row10_col5" class="data row10 col5" >0.9287</td>
#       <td id="T_a89c6_row10_col6" class="data row10 col6" >0.9313</td>
#     </tr>
#     <tr>
#       <th id="T_a89c6_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_a89c6_row11_col0" class="data row11 col0" >0.0252</td>
#       <td id="T_a89c6_row11_col1" class="data row11 col1" >0.0069</td>
#       <td id="T_a89c6_row11_col2" class="data row11 col2" >0.0667</td>
#       <td id="T_a89c6_row11_col3" class="data row11 col3" >0.0313</td>
#       <td id="T_a89c6_row11_col4

# %%
X = data.drop(columns=['diagnosis']).values
Y = data['diagnosis']

# %%
scores = cross_val_score(model, X, Y, cv=20)
sns.lineplot(scores)
# Out:
# <Axes: >

# %%
preds = s.predict_model(model)
preds
# Out:
# <style type="text/css">
# </style>
# <table id="T_7f01a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f01a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7f01a_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_7f01a_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_7f01a_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_7f01a_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_7f01a_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_7f01a_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_7f01a_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f01a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7f01a_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_7f01a_row0_col1" class="data row0 col1" >0.9649</td>
#       <td id="T_7f01a_row0_col2" class="data row0 col2" >0.9918</td>
#       <td id="T_7f01a_row0_col3" class="data row0 col3" >0.9688</td>
#       <td id="T_7f01a_row0_col4" class="data row0 col4" >0.9394</td>
#       <td id="T_7f01a_row0_col5" class="data row0 col5" >0.9538</td>
#       <td id="T_7f01a_row0_col6" class="data row0 col6" >0.9256</td>
#       <td id="T_7f01a_row0_col7" class="data row0 col7" >0.9258</td>
#     </tr>
#   </tbody>
# </table>
#      radius_mean  texture_mean  perimeter_mean    area_mean  smoothness_mean  \
# 115    11.930000     21.530001       76.529999   438.600006          0.09768
# 21      9.504000     12.440000       60.340000   273.899994          0.10240
# 382    12.050000     22.719999       78.750000   447.799988          0.06935
# 136    11.710000     16.670000       74.720001   423.600006          0.10510
# 2      19.690001     21.250000      130.000000  1203.000000          0.10960
# ..           ...           ...             ...          ...              ...
# 526    13.460000     18.750000       87.440002   551.099976          0.10750
# 142    11.430000     17.309999       73.660004   398.000000          0.10920
# 238    14.220000     27.850000       92.550003   623.900024          0.08223
# 106    11.640000     18.330000       75.169998   412.500000          0.11420
# 437    14.040000     15.980000       89.779999   611.200012          0.08458
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 115           0.07849         0.03328              0.02008         0.1688
# 21            0.06492         0.02956              0.02076         0.1815
# 382           0.10730         0.07943              0.02978         0.1203
# 136           0.06095         0.03592              0.02600         0.1339
# 2             0.15990         0.19740              0.12790         0.2069
# ..                ...             ...                  ...            ...
# 526           0.11380         0.04201              0.03152         0.1723
# 142           0.09486         0.02031              0.01861         0.1645
# 238           0.10390         0.11030              0.04408         0.1342
# 106           0.10170         0.07070              0.03485         0.1801
# 437           0.05895         0.03534              0.02944         0.1714
#
#      fractal_dimension_mean  ...   area_worst  smoothness_worst  \
# 115                 0.06194  ...   583.000000           0.15000
# 21                  0.06905  ...   314.899994           0.13240
# 382                 0.06659  ...   488.399994           0.08799
# 136                 0.05945  ...   546.700012           0.12710
# 2                   0.05999  ...  1709.000000           0.14440
# ..                      ...  ...          ...               ...
# 526                 0.06317  ...   719.799988           0.16240
# 142                 0.06562  ...   503.000000           0.14130
# 238                 0.06129  ...   764.000000           0.10810
# 106                 0.06520  ...   521.700012           0.16880
# 437                 0.05898  ...   750.000000           0.11950
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 115             0.2399          0.15030               0.07247          0.2438
# 21              0.1148          0.08867               0.06227          0.2450
# 382             0.3214          0.29120               0.10920          0.2191
# 136             0.1028          0.10460               0.06968          0.1712
# 2               0.4245          0.45040               0.24300          0.3613
# ..                 ...              ...                   ...             ...
# 526             0.3124          0.26540               0.14270          0.3518
# 142             0.1792          0.07708               0.06402          0.2584
# 238             0.2426          0.30640               0.08219          0.1890
# 106             0.2660          0.28730               0.12180          0.2806
# 437             0.1252          0.11170               0.07453          0.2725
#
#      fractal_dimension_worst  diagnosis  prediction_label  prediction_score
# 115                  0.08541          0                 0              0.99
# 21                   0.07773          0                 0              1.00
# 382                  0.09349          0                 0              0.93
# 136                  0.07343          0                 0              0.98
# 2                    0.08758          1                 1              1.00
# ..                       ...        ...               ...               ...
# 526                  0.08665          0                 0              0.74
# 142                  0.08096          0                 0              1.00
# 238                  0.07796          0                 0              0.62
# 106                  0.09097          0                 0              0.89
# 437                  0.07234          0                 0              0.92
#
# [171 rows x 33 columns]

# %%
pred = (abs(preds['diagnosis'] - preds['prediction_label'])).sum()

print(f'{pred} / {preds.shape[0]} : {round(pred/preds.shape[0]*100, 2)} % (False Predictions)')
# Out:
# 6 / 171 : 3.51 % (False Predictions)
