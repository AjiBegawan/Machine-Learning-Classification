# %% [markdown]
# # 1. Import Libraries

# %%
import tensorflow as tf
gpu = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpu[0], True)

# %%
import math
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
sns.set_style("whitegrid")
plt.style.use("fivethirtyeight")

from math import * 
from collections import Counter
from tqdm.notebook import tqdm
tqdm.pandas()

from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE

from tensorflow import keras
from keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD, Adam,  RMSprop, Nadam
from tensorflow.python.keras import models, layers, optimizers
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Dense, Flatten, Conv1D, MaxPooling1D, LSTM, GRU, Embedding,\
    BatchNormalization, LeakyReLU, Dropout, ReLU, Bidirectional, GlobalMaxPooling1D

from sklearn.model_selection import train_test_split
from   sklearn.model_selection import cross_val_score

from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PowerTransformer, MinMaxScaler, LabelEncoder
from sklearn.feature_selection import chi2, RFE, SelectFromModel, SelectKBest
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score, RocCurveDisplay, classification_report 

from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import PassiveAggressiveClassifier, LogisticRegression

from sklearn.ensemble import (
    BaggingClassifier,
    StackingClassifier,
    AdaBoostClassifier, 
    ExtraTreesClassifier,
    RandomForestClassifier,
    RandomForestClassifier,
    GradientBoostingClassifier, 
    HistGradientBoostingClassifier
)
from xgboost import XGBClassifier

from pycaret.classification import ClassificationExperiment

# %% [markdown]
# # 2. Load Data

# %%
data = pd.read_csv('../Dataset/diabetes.csv').dropna().drop_duplicates()
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %% [markdown]
# # 3. Initial Analysis

# %% [markdown]
# ### 3.1. Metadata

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 60.0 KB

# %%
data.describe(include='all').transpose()
# Out:
#                           count        mean         std        min        25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000000   1.000000
# Glucose                   768.0  120.894531   31.972618   0.000000  99.000000
# BloodPressure             768.0   69.105469   19.355807   0.000000  62.000000
# SkinThickness             768.0   20.536458   15.952218   0.000000   0.000000
# Insulin                   768.0   79.799479  115.244002   0.000000   0.000000
# BMI                       768.0   32.000000    7.882812   0.000000  27.296875
# DiabetesPedigreeFunction  768.0    0.471924    0.331299   0.078003   0.243774
# Age                       768.0   33.240885   11.760232  21.000000  24.000000
# Outcome                   768.0    0.348958    0.476951   0.000000   0.000000
#
#                                  50%         75%         max
# Pregnancies                 3.000000    6.000000   17.000000
# Glucose                   117.000000  140.250000  199.000000
# BloodPressure              72.000000   80.000000  122.000000
# SkinThickness              23.000000   32.000000   99.000000
# Insulin                    30.500000  127.250000  846.000000
# BMI                        32.000000   36.593750   67.125000
# DiabetesPedigreeFunction    0.372559    0.626221    2.419922
# Age                        29.000000   41.000000   81.000000
# Outcome                     0.000000    1.000000    1.000000

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
no_of_columns = data.shape[0]
percentage_of_missing_data = data.isnull().sum()/no_of_columns
print(percentage_of_missing_data)
# Out:
# Pregnancies                 0.0
# Glucose                     0.0
# BloodPressure               0.0
# SkinThickness               0.0
# Insulin                     0.0
# BMI                         0.0
# DiabetesPedigreeFunction    0.0
# Age                         0.0
# Outcome                     0.0
# dtype: float64

# %%
print(f'Number of duplicates data : {data.duplicated().sum()}')
# Out:
# Number of duplicates data : 0

# %%
data.nunique()
# Out:
# Pregnancies                  17
# Glucose                     136
# BloodPressure                47
# SkinThickness                51
# Insulin                     186
# BMI                         248
# DiabetesPedigreeFunction    517
# Age                          52
# Outcome                       2
# dtype: int64

# %% [markdown]
# ### 3.2. Columns Processing

# %%
def downcasting_dtypes(data):
    downcast_int_col = data.select_dtypes(include='int').columns.tolist()
    for col in downcast_int_col:
        data[col] = data[col].astype('int16')

    downcast_float_col = data.select_dtypes(include='float').columns.tolist()
    for col in downcast_float_col:
        data[col] = data[col].astype('float16')

downcasting_dtypes(data)

# %%
numerical_columns = [column_name for column_name in data.columns if data[column_name].dtype != 'object']
categorical_columns = [column_name for column_name in data.columns if data[column_name].dtype == 'object']

print(f'Numerical Columns   : {numerical_columns}')
print(f'Categorical Columns : {categorical_columns}')
# Out:
# Numerical Columns   : ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']
# Categorical Columns : []

# %%
def change_columns_to_numerical(data):
    LE = LabelEncoder()

    for column in categorical_columns:
        data[column] = LE.fit_transform(data[column])
        data[column] = data[column].astype('int8')
        # data[column] = pd.to_numeric(data[column], errors='coerce')
        print(f'{column} : {LE.classes_}') 

change_columns_to_numerical(data)

# %% [markdown]
# ### 3.3. EDA

# %%
num_cols = 3
num_rows = math.ceil(len(numerical_columns) / num_cols)

fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 5))

for i, column in enumerate(numerical_columns):
    row = i // num_cols
    col = i % num_cols
    sns.kdeplot(data = data, x = column, ax=axes[row, col]) \
        .set_title("Distribusi nilai kolom " + column)
    

for i in range(len(numerical_columns), num_rows * num_cols):
    row = i // num_cols
    col = i % num_cols
    axes[row, col].axis('off')

plt.tight_layout()
plt.show()

# %%
num_cols = 4
num_rows = math.ceil(len(numerical_columns) / num_cols)

fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 10))

for i, column in enumerate(numerical_columns):
    row = i // num_cols
    col = i % num_cols
    sns.kdeplot(data=data, x=column, hue="Outcome", 
                fill=True, alpha=.2, palette="YlOrRd", 
                common_norm=False, ax=axes[row, col],
                warn_singular=False)\
        .set_title(column)

for i in range(len(numerical_columns), num_rows * num_cols):
    row = i // num_cols
    col = i % num_cols
    axes[row, col].axis('off')

plt.tight_layout()
plt.show()

# %%
# plt.figure(figsize=(20, 10))

# plt.scatter(data.age[data.target==1],
#             data.thalach[data.target==1],
#             c="salmon")

# plt.scatter(data.age[data.target==0],
#             data.thalach[data.target==0],
#             c="lightblue")

# plt.title("Heart Disease in function of Age and Max Heart Rate")
# plt.xlabel("Age")
# plt.ylabel("Max Heart Rate")
# plt.legend(["Disease", "No Disease"])

# %%
sns.pairplot(data, hue='Outcome')

# %%
plt.subplots(figsize = (20,2))
ax = sns.countplot(data = data, y = 'Outcome', palette='YlOrBr')
ax.bar_label(ax.containers[0])
plt.show()

# %%
num_cols = 3
num_rows = math.ceil(len(numerical_columns) / num_cols)

fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 5))
for i, column in enumerate(numerical_columns):
    row = i // num_cols
    col = i % num_cols
    sns.boxplot(x=data[column], ax=axes[row, col], palette="Oranges").set_title(column)
    
for i in range(len(numerical_columns), num_rows * num_cols):
    row = i // num_cols
    col = i % num_cols
    axes[row, col].axis('off')

plt.tight_layout()
plt.show()

# %%
# Q1 = data['text_len'].quantile(0.25)
# Q3 = data['text_len'].quantile(1.)

# print(Q1)
# print(Q3)

# data = data[(data['text_len'] > Q1) & (data['text_len'] < Q3)]

# fig, axes = plt.subplots(figsize=(25, 2))
# sns.boxplot(x = data['text_len'], palette="Oranges")

# sns.stripplot(x=data['text_len'], data=data,
#               size=4, color=".3", linewidth=0, palette="crest", hue=data['text_len'])

# %% [markdown]
# ### 3.4. Data Correlation

# %%
corr_data = data[numerical_columns].corr().round(2)

mask = np.zeros_like(corr_data)
mask[np.triu_indices_from(mask)] = True

plt.figure(figsize=(25, 10))
# sns.heatmap(corr_data, annot=True, mask=mask, cmap='RdBu')
sns.heatmap(corr_data, annot=True, cmap='RdBu')
plt.title("Correlation Matrix", size=20)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# # 4. Data Preprocessing

# %% [markdown]
# ### 4.1. Features Selections

# %%
### Pearson Correlation
def cor_selector(X, y,num_feats):
    cor_list = []
    feature_name = X.columns.tolist()
    # calculate the correlation with y for each feature
    for i in X.columns.tolist():
        cor = np.corrcoef(X[i], y)[0, 1]
        cor_list.append(cor)
    # replace NaN with 0
    cor_list = [0 if np.isnan(i) else i for i in cor_list]
    # feature name
    cor_feature = X.iloc[:,np.argsort(np.abs(cor_list))[-num_feats:]].columns.tolist()
    # feature selection? 0 for not select, 1 for select
    cor_support = [True if i in cor_feature else False for i in feature_name]
    print(str(len(cor_feature)), 'selected features')
    print(cor_feature)
    return cor_feature

### Chi-Squared
def chi_squared_elimination(X, Y,num_feats):
    X_norm = MinMaxScaler().fit_transform(X)
    chi_selector = SelectKBest(chi2, k=num_feats)
    chi_selector.fit(X_norm, Y)
    chi_support = chi_selector.get_support()
    chi_feature = X.loc[:,chi_support].columns.tolist()
    print(str(len(chi_feature)), 'selected features')
    print(chi_feature)
    return chi_feature

### Recursive Feature Elimination
def recursive_elimination(X, Y,num_feats):
    X_norm = MinMaxScaler().fit_transform(X)
    rfe_selector = RFE(estimator=LogisticRegression(), n_features_to_select=num_feats, step=10, verbose=5)
    rfe_selector.fit(X_norm, Y)
    rfe_support = rfe_selector.get_support()
    rfe_feature = X.loc[:,rfe_support].columns.tolist()
    print(str(len(rfe_feature)), 'selected features')
    print(rfe_feature)
    return rfe_feature

### Lasso: SelectFromModel
def lasso_elimination(X, Y, num_feats):
    X_norm = MinMaxScaler().fit_transform(X)
    embeded_lr_selector = SelectFromModel(LogisticRegression(penalty="l2"), max_features=num_feats)
    embeded_lr_selector.fit(X_norm, Y)
    embeded_lr_support = embeded_lr_selector.get_support()
    embeded_lr_feature = X.loc[:,embeded_lr_support].columns.tolist()
    print(str(len(embeded_lr_feature)), 'selected features')
    print(embeded_lr_feature)
    return embeded_lr_feature

### LightGBM: SelectFromModel
def LGBMC_elimination(X, Y, num_feats):
    lgbc=LGBMClassifier(n_estimators=500, learning_rate=0.05, num_leaves=32, colsample_bytree=0.2,
                reg_alpha=3, reg_lambda=1, min_split_gain=0.01, min_child_weight=40)

    embeded_lgb_selector = SelectFromModel(lgbc, max_features=num_feats)
    embeded_lgb_selector.fit(X, Y)
    embeded_lgb_support = embeded_lgb_selector.get_support()
    embeded_lgb_feature = X.loc[:,embeded_lgb_support].columns.tolist()
    print(str(len(embeded_lgb_feature)), 'selected features')
    print(embeded_lgb_feature)
    return embeded_lgb_feature

### Tree-based: SelectFromModel
def RFC_elimination (X, Y, num_feats):
    embeded_rf_selector = SelectFromModel(RandomForestClassifier(n_estimators=100), max_features=num_feats)
    embeded_rf_selector.fit(X, Y)

    embeded_rf_support = embeded_rf_selector.get_support()
    embeded_rf_feature = X.loc[:,embeded_rf_support].columns.tolist()
    print(str(len(embeded_rf_feature)), 'selected features')
    print(embeded_rf_feature)
    return embeded_rf_feature

# %%
X = data.drop(columns=['Potability'])
Y = data['Potability']

num_feats = 10

selected_feature = cor_selector(X, Y,num_feats)
# selected_feature = chi_squared_elimination(X, Y,num_feats)
# selected_feature = recursive_elimination(X, Y,num_feats)
# selected_feature = lasso_elimination(X, Y, num_feats)
# selected_feature = LGBMC_elimination(X, Y, num_feats)
# selected_feature = RFC_elimination(X, Y, num_feats)

X = data[selected_feature]
Y = data['Credit_Score']


print(Counter(Y))
undersample = RandomUnderSampler()
X, Y = undersample.fit_resample(X, Y)
print(Counter(Y))

Y = to_categorical(Y)

scaler = MinMaxScaler(feature_range=(0,1))
X = scaler.fit_transform(X)

X_train, X_val, y_train, y_val = train_test_split(X, Y, train_size=0.9, random_state = 42)
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, train_size=0.78, random_state = 42)

print(X_train.shape)
print(X_test.shape)
print(X_val.shape)
# Out:
# 10 selected features
# ['Monthly_Balance', 'Num_Bank_Accounts', 'Credit_History_Age', 'Num_Credit_Card', 'Num_of_Loan', 'Delay_from_due_date', 'Outstanding_Debt', 'Interest_Rate', 'Num_Credit_Inquiries', 'Credit_Mix']
# Counter({0: 53174, 2: 28998, 1: 17828})
# Counter({0: 17828, 1: 17828, 2: 17828})
# (37545, 10)
# (10590, 10)
# (5349, 10)

# %% [markdown]
# # 5 Neural Network Algoritms

# %%
X = data.drop(columns=['Outcome']).values
Y = data['Outcome']

print(Counter(Y))
# sampling = RandomUnderSampler()
sampling = SMOTE()
X, Y = sampling.fit_resample(X, Y)
print(Counter(Y))

Y = pd.get_dummies(Y).values

# scaler = MinMaxScaler(feature_range=(0,1))
scaler = PowerTransformer(method='yeo-johnson', standardize=True)
X = scaler.fit_transform(X)

X_train, X_val, y_train, y_val = train_test_split(X, Y, train_size=0.9, random_state = 42)
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, train_size=0.78, random_state = 42)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
print(X_val.shape, y_val.shape)

label = y_train.shape[1]
# Out:
# Counter({0: 500, 1: 268})
# Counter({1: 500, 0: 500})
# (702, 8) (702, 2)
# (198, 8) (198, 2)
# (100, 8) (100, 2)

# %%
def DNN_Model():
    model = Sequential()
    model.add(Dense(4096, activation='relu', kernel_regularizer=keras.regularizers.l2(l=0.001), input_shape=(X_train.shape[1],)))
    model.add(Dense(1024, activation='relu', kernel_regularizer=keras.regularizers.l2(l=0.001)))
    model.add(Dense(256, activation='relu', kernel_regularizer=keras.regularizers.l2(l=0.001)))
    model.add(Dense(label, activation='softmax'))
    
    return model

def CNN_Model():
    model = Sequential()

    model.add(Conv1D(128, 3, kernel_regularizer=keras.regularizers.l2(l=0.001), input_shape=(X_train.shape[1], 1)))
    model.add(BatchNormalization())
    # model.add(LeakyReLU(0.2))
    model.add(ReLU())
    # model.add(Dropout(0.8))
    model.add(MaxPooling1D())

    # model.add(Conv1D(64, 3, kernel_regularizer=keras.regularizers.l2(l=0.001)))
    # model.add(BatchNormalization())
    # # model.add(LeakyReLU(0.2))
    # model.add(ReLU())
    # model.add(Dropout(0.5))
    # model.add(MaxPooling1D())

    model.add(Conv1D(64, 3, kernel_regularizer=keras.regularizers.l2(l=0.001)))
    model.add(BatchNormalization())
    # model.add(LeakyReLU(0.2))
    model.add(ReLU())
    # model.add(Dropout(0.5))
    model.add(MaxPooling1D())

    # model.add(Conv1D(16, 3, kernel_regularizer=keras.regularizers.l2(l=0.001)))
    # model.add(BatchNormalization())
    # # model.add(LeakyReLU(0.2))
    # model.add(ReLU())
    # # model.add(Dropout(0.5))
    # model.add(MaxPooling1D())

    model.add(Flatten())
    # model.add(Dense(4098, activation='relu'))
    model.add(Dense(128, activation='relu'))
    # model.add(Dropout(0.5))
    model.add(Dense(128, activation='relu'))
    # model.add(Dropout(0.5))
    model.add(Dense(label, activation='softmax'))
    return model

def LSTM_Model():
    model = Sequential()
    model.add((LSTM(256, return_sequences=True, input_shape=(X_train.shape[1], 1))))
    model.add((LSTM(256)))
    # model.add(Dense(32, activation='swish'))
    # model.add(Dropout(0.2))
    # model.add(Dropout(0.5))
    # model.add(Dense(16, activation='relu'))
    model.add(Dense(label, activation='sigmoid'))
    return model

def GRU_Model():
    model = Sequential()
    model.add(GRU(256, activation ='tanh', recurrent_activation ='sigmoid', recurrent_dropout = 0, unroll=False, use_bias=True, reset_after=True, return_sequences=True, input_shape = (X_train.shape[1],1)))
    model.add(GRU(256, activation ='tanh', recurrent_activation ='sigmoid', recurrent_dropout = 0, unroll=False, use_bias=True, reset_after=True))
    model.add(Dense(label, activation='softmax'))
    return model
    

model = DNN_Model()
# model = CNN_Model()
# model = LSTM_Model()
# model = GRU_Model()

model.summary()

# opt = RMSprop(learning_rate = 0.001)
# opt = SGD(learning_rate = 0.001)
opt = Adam(learning_rate = 0.000_001)

model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
# model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_32 (Dense)            (None, 4096)              36864
#
#  dense_33 (Dense)            (None, 1024)              4195328
#
#  dense_34 (Dense)            (None, 256)               262400
#
#  dense_35 (Dense)            (None, 2)                 514
#
# =================================================================
# Total params: 4,495,106
# Trainable params: 4,495,106
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epoch = 1000
batch_size = 32

history = model.fit(X_train, y_train, verbose = 2,
                    batch_size = batch_size, epochs = num_epoch, 
                    validation_data = (X_test, y_test))
# Out:
# Epoch 1/1000
# 22/22 - 1s - loss: 2.7515 - accuracy: 0.6211 - val_loss: 2.7478 - val_accuracy: 0.7071 - 823ms/epoch - 37ms/step
# Epoch 2/1000
# 22/22 - 0s - loss: 2.7450 - accuracy: 0.6937 - val_loss: 2.7413 - val_accuracy: 0.7475 - 117ms/epoch - 5ms/step
# Epoch 3/1000
# 22/22 - 0s - loss: 2.7386 - accuracy: 0.7194 - val_loss: 2.7351 - val_accuracy: 0.7475 - 113ms/epoch - 5ms/step
# Epoch 4/1000
# 22/22 - 0s - loss: 2.7323 - accuracy: 0.7251 - val_loss: 2.7288 - val_accuracy: 0.7525 - 112ms/epoch - 5ms/step
# Epoch 5/1000
# 22/22 - 0s - loss: 2.7262 - accuracy: 0.7365 - val_loss: 2.7228 - val_accuracy: 0.7778 - 117ms/epoch - 5ms/step
# Epoch 6/1000
# 22/22 - 0s - loss: 2.7201 - accuracy: 0.7393 - val_loss: 2.7169 - val_accuracy: 0.7727 - 114ms/epoch - 5ms/step
# Epoch 7/1000
# 22/22 - 0s - loss: 2.7140 - accuracy: 0.7407 - val_loss: 2.7109 - val_accuracy: 0.7778 - 112ms/epoch - 5ms/step
# Epoch 8/1000
# 22/22 - 0s - loss: 2.7081 - accuracy: 0.7450 - val_loss: 2.7049 - val_accuracy: 0.7778 - 112ms/epoch - 5ms/step
# Epoch 9/1000
# 22/22 - 0s - loss: 2.7022 - accuracy: 0.7479 - val_loss: 2.6989 - val_accuracy: 0.7778 - 115ms/epoch - 5ms/step
# Epoch 10/1000
# 22/22 - 0s - loss: 2.6962 - accuracy: 0.7450 - val_loss: 2.6931 - val_accuracy: 0.7879 - 115ms/epoch - 5ms/step
# Epoch 11/1000
# 22/22 - 0s - loss: 2.6904 - accuracy: 0.7464 - val_loss: 2.6871 - val_accuracy: 0.7778 - 114ms/epoch - 5ms/step
# Epoch 12/1000
# 22/22 - 0s - loss: 2.6846 - accuracy: 0.7493 - val_loss: 2.6814 - val_accuracy: 0.7879 - 113ms/epoch - 5ms/step
# Epoch 13/1000
# 22/22 - 0s - loss: 2.6788 - accuracy: 0.7464 - val_loss: 2.6756 - val_accuracy: 0.7929 - 116ms/epoch - 5ms/step
# Epoch 14/1000
# 22/22 - 0s - loss: 2.6732 - accuracy: 0.7479 - val_loss: 2.6697 - val_accuracy: 0.7929 - 151ms/epoch - 7ms/step
# Epoch 15/1000
# 22/22 - 0s - loss: 2.6675 - accuracy: 0.7464 - val_loss: 2.6640 - val_accuracy: 0.8030 - 113ms/epoch - 5ms/step
# Epoch 16/1000
# 22/22 - 0s - loss: 2.6619 - accuracy: 0.7507 - val_loss: 2.6582 - val_accuracy: 0.8030 - 115ms/epoch - 5ms/step
# Epoch 17/1000
# 22/22 - 0s - loss: 2.6565 - accuracy: 0.7493 - val_loss: 2.6525 - val_accuracy: 0.8030 - 111ms/epoch - 5ms/step
# Epoch 18/1000
# 22/22 - 0s - loss: 2.6511 - accuracy: 0.7493 - val_loss: 2.6465 - val_accuracy: 0.7980 - 115ms/epoch - 5ms/step
# Epoch 19/1000
# 22/22 - 0s - loss: 2.6457 - accuracy: 0.7493 - val_loss: 2.6412 - val_accuracy: 0.8030 - 112ms/epoch - 5ms/step
# Epoch 20/1000
# 22/22 - 0s - loss: 2.6404 - accuracy: 0.7493 - val_loss: 2.6358 - val_accuracy: 0.7980 - 112ms/epoch - 5ms/step
# Epoch 21/1000
# 22/22 - 0s - loss: 2.6352 - accuracy: 0.7464 - val_loss: 2.6305 - val_accuracy: 0.7980 - 114ms/epoch - 5ms/step
# Epoch 22/1000
# 22/22 - 0s - loss: 2.6300 - accuracy: 0.7521 - val_loss: 2.6249 - val_accuracy: 0.7980 - 113ms/epoch - 5ms/step
# Epoch 23/1000
# 22/22 - 0s - loss: 2.6249 - accuracy: 0.7507 - val_loss: 2.6197 - val_accuracy: 0.7980 - 111ms/epoch - 5ms/step
# Epoch 24/1000
# 22/22 - 0s - loss: 2.6199 - accuracy: 0.7521 - val_loss: 2.6143 - val_accuracy: 0.7980 - 114ms/epoch - 5ms/step
# Epoch 25/1000
# 22/22 - 0s - loss: 2.6148 - accuracy: 0.7521 - val_loss: 2.6093 - val_accuracy: 0.7980 - 113ms/epoch - 5ms/step
# Epoch 26/1000
# 22/22 - 0s - loss: 2.6100 - accuracy: 0.7521 - val_loss: 2.6042 - val_accuracy: 0.7980 - 113ms/epoch - 5ms/step
# Epoch 27/1000
# 22/22 - 0s - loss: 2.6051 - accuracy: 0.7521 - val_loss: 2.5992 - val_accuracy: 0.7980 - 112ms/epoch - 5ms/step
# Epoch 28/1000
# 22/22 - 0s - loss: 2.6005 - accuracy: 0.7507 - val_loss: 2.5941 - val_accuracy: 0.7929 - 111ms/epoch - 5ms/step
# Epoch 29/1000
# 22/22 - 0s - loss: 2.5958 - accuracy: 0.7521 - val_loss: 2.5893 - val_accuracy: 0.7929 - 110ms/epoch - 5ms/step
# Epoch 30/1000
# 22/22 - 0s - loss: 2.5913 - accuracy: 0.7536 - val_loss: 2.5844 - val_accuracy: 0.7980 - 112ms/epoch - 5ms/step
# Epoch 31/1000
# 22/22 - 0s - loss: 2.5867 - accuracy: 0.7521 - val_loss: 2.5800 - val_accuracy: 0.7929 - 111ms/epoch - 5ms/step
# Epoch 32/1000
# 22/22 - 0s - loss: 2.5823 - accuracy: 0.7550 - val_loss: 2.5752 - val_accuracy: 0.7929 - 112ms/epoch - 5ms/step
# Epoch 33/1000
# 22/22 - 0s - loss: 2.5779 - accuracy: 0.7550 - val_loss: 2.5708 - val_accuracy: 0.7929 - 109ms/epoch - 5ms/step
# Epoch 34/1000
# 22/22 - 0s - loss: 2.5737 - accuracy: 0.7578 - val_loss: 2.5664 - val_accuracy: 0.7879 - 113ms/epoch - 5ms/step
# Epoch 35/1000
# 22/22 - 0s - loss: 2.5695 - accuracy: 0.7550 - val_loss: 2.5619 - val_accuracy: 0.7879 - 114ms/epoch - 5ms/step
# Epoch 36/1000
# 22/22 - 0s - loss: 2.5654 - accuracy: 0.7578 - val_loss: 2.5575 - val_accuracy: 0.7879 - 113ms/epoch - 5ms/step
# Epoch 37/1000
# 22/22 - 0s - loss: 2.5614 - accuracy: 0.7593 - val_loss: 2.5531 - val_accuracy: 0.7879 - 113ms/epoch - 5ms/step
# Epoch 38/1000
# 22/22 - 0s - loss: 2.5574 - accuracy: 0.7578 - val_loss: 2.5490 - val_accuracy: 0.7879 - 112ms/epoch - 5ms/step
# Epoch 39/1000
# 22/22 - 0s - loss: 2.5536 - accuracy: 0.7564 - val_loss: 2.5447 - val_accuracy: 0.7879 - 112ms/epoch - 5ms/step
# Epoch 40/1000
# 22/22 - 0s - loss: 2.5497 - accuracy: 0.7593 - val_loss: 2.5407 - val_accuracy: 0.7929 - 111ms/epoch - 5ms/step
# Epoch 41/1000
# 22/22 - 0s - loss: 2.5460 - accuracy: 0.7593 - val_loss: 2.5367 - val_accuracy: 0.7929 - 110ms/epoch - 5ms/step
# Epoch 42/1000
# 22/22 - 0s - loss: 2.5422 - accuracy: 0.7593 - val_loss: 2.5329 - val_accuracy: 0.7929 - 110ms/epoch - 5ms/step
# Epoch 43/1000
# 22/22 - 0s - loss: 2.5386 - accuracy: 0.7593 - val_loss: 2.5292 - val_accuracy: 0.7929 - 111ms/epoch - 5ms/step
# Epoch 44/1000
# 22/22 - 0s - loss: 2.5351 - accuracy: 0.7578 - val_loss: 2.5253 - val_accuracy: 0.7980 - 114ms/epoch - 5ms/step
# Epoch 45/1000
# 22/22 - 0s - loss: 2.5316 - accuracy: 0.7578 - val_loss: 2.5215 - val_accuracy: 0.7980 - 111ms/epoch - 5ms/step
# Epoch 46/1000
# 22/22 - 0s - loss: 2.5281 - accuracy: 0.7578 - val_loss: 2.5179 - val_accuracy: 0.7980 - 109ms/epoch - 5ms/step
# Epoch 47/1000
# 22/22 - 0s - loss: 2.5247 - accuracy: 0.7593 - val_loss: 2.5140 - val_accuracy: 0.7980 - 112ms/epoch - 5ms/step
# Epoch 48/1000
# 22/22 - 0s - loss: 2.5213 - accuracy: 0.7593 - val_loss: 2.5106 - val_accuracy: 0.7980 - 111ms/epoch - 5ms/step
# Epoch 49/1000
# 22/22 - 0s - loss: 2.5180 - accuracy: 0.7607 - val_loss: 2.5071 - val_accuracy: 0.7980 - 111ms/epoch - 5ms/step
# Epoch 50/1000
# 22/22 - 0s - loss: 2.5148 - accuracy: 0.7607 - val_loss: 2.5036 - val_accuracy: 0.7980 - 112ms/epoch - 5ms/step
# Epoch 51/1000
# 22/22 - 0s - loss: 2.5116 - accuracy: 0.7621 - val_loss: 2.5002 - val_accuracy: 0.7929 - 110ms/epoch - 5ms/step
# Epoch 52/1000
# 22/22 - 0s - loss: 2.5084 - accuracy: 0.7650 - val_loss: 2.4968 - val_accuracy: 0.7929 - 111ms/epoch - 5ms/step
# Epoch 53/1000
# 22/22 - 0s - loss: 2.5053 - accuracy: 0.7621 - val_loss: 2.4936 - val_accuracy: 0.7929 - 147ms/epoch - 7ms/step
# Epoch 54/1000
# 22/22 - 0s - loss: 2.5023 - accuracy: 0.7664 - val_loss: 2.4901 - val_accuracy: 0.7929 - 109ms/epoch - 5ms/step
# Epoch 55/1000
# 22/22 - 0s - loss: 2.4992 - accuracy: 0.7650 - val_loss: 2.4872 - val_accuracy: 0.7929 - 111ms/epoch - 5ms/step
# Epoch 56/1000
# 22/22 - 0s - loss: 2.4963 - accuracy: 0.7664 - val_loss: 2.4841 - val_accuracy: 0.7929 - 113ms/epoch - 5ms/step
# Epoch 57/1000
# 22/22 - 0s - loss: 2.4934 - accuracy: 0.7650 - val_loss: 2.4809 - val_accuracy: 0.7929 - 113ms/epoch - 5ms/step
# Epoch 58/1000
# 22/22 - 0s - loss: 2.4904 - accuracy: 0.7650 - val_loss: 2.4779 - val_accuracy: 0.7929 - 112ms/epoch - 5ms/step
# Epoch 59/1000
# 22/22 - 0s - loss: 2.4877 - accuracy: 0.7635 - val_loss: 2.4749 - val_accuracy: 0.7929 - 110ms/epoch - 5ms/step
# Epoch 60/1000
# 22/22 - 0s - loss: 2.4849 - accuracy: 0.7664 - val_loss: 2.4721 - val_accuracy: 0.7929 - 112ms/epoch - 5ms/step
# Epoch 61/1000
# 22/22 - 0s - loss: 2.4821 - accuracy: 0.7664 - val_loss: 2.4693 - val_accuracy: 0.8030 - 111ms/epoch - 5ms/step
# Epoch 62/1000
# 22/22 - 0s - loss: 2.4794 - accuracy: 0.7650 - val_loss: 2.4664 - val_accuracy: 0.7980 - 112ms/epoch - 5ms/step
# Epoch 63/1000
# 22/22 - 0s - loss: 2.4767 - accuracy: 0.7635 - val_loss: 2.4636 - val_accuracy: 0.7929 - 112ms/epoch - 5ms/step
# Epoch 64/1000
# 22/22 - 0s - loss: 2.4741 - accuracy: 0.7650 - val_loss: 2.4608 - val_accuracy: 0.7980 - 115ms/epoch - 5ms/step
# Epoch 65/1000
# 22/22 - 0s - loss: 2.4716 - accuracy: 0.7650 - val_loss: 2.4580 - val_accuracy: 0.7980 - 111ms/epoch - 5ms/step
# Epoch 66/1000
# 22/22 - 0s - loss: 2.4689 - accuracy: 0.7664 - val_loss: 2.4555 - val_accuracy: 0.7929 - 110ms/epoch - 5ms/step
# Epoch 67/1000
# 22/22 - 0s - loss: 2.4664 - accuracy: 0.7678 - val_loss: 2.4528 - val_accuracy: 0.7980 - 111ms/epoch - 5ms/step
# Epoch 68/1000
# 22/22 - 0s - loss: 2.4639 - accuracy: 0.7664 - val_loss: 2.4502 - val_accuracy: 0.7929 - 112ms/epoch - 5ms/step
# Epoch 69/1000
# 22/22 - 0s - loss: 2.4614 - accuracy: 0.7664 - val_loss: 2.4476 - val_accuracy: 0.7929 - 110ms/epoch - 5ms/step
# Epoch 70/1000
# 22/22 - 0s - loss: 2.4590 - accuracy: 0.7678 - val_loss: 2.4451 - val_accuracy: 0.7929 - 120ms/epoch - 5ms/step
# Epoch 71/1000
# 22/22 - 0s - loss: 2.4565 - accuracy: 0.7678 - val_loss: 2.4427 - val_accuracy: 0.7879 - 113ms/epoch - 5ms/step
# Epoch 72/1000
# 22/22 - 0s - loss: 2.4542 - accuracy: 0.7664 - val_loss: 2.4402 - val_accuracy: 0.7778 - 109ms/epoch - 5ms/step
# Epoch 73/1000
# 22/22 - 0s - loss: 2.4519 - accuracy: 0.7678 - val_loss: 2.4380 - val_accuracy: 0.7778 - 111ms/epoch - 5ms/step
# Epoch 74/1000
# 22/22 - 0s - loss: 2.4495 - accuracy: 0.7664 - val_loss: 2.4355 - val_accuracy: 0.7727 - 112ms/epoch - 5ms/step
# Epoch 75/1000
# 22/22 - 0s - loss: 2.4472 - accuracy: 0.7664 - val_loss: 2.4330 - val_accuracy: 0.7778 - 112ms/epoch - 5ms/step
# Epoch 76/1000
# 22/22 - 0s - loss: 2.4449 - accuracy: 0.7678 - val_loss: 2.4307 - val_accuracy: 0.7727 - 112ms/epoch - 5ms/step
# Epoch 77/1000
# 22/22 - 0s - loss: 2.4427 - accuracy: 0.7678 - val_loss: 2.4285 - val_accuracy: 0.7727 - 112ms/epoch - 5ms/step
# Epoch 78/1000
# 22/22 - 0s - loss: 2.4404 - accuracy: 0.7678 - val_loss: 2.4262 - val_accuracy: 0.7727 - 111ms/epoch - 5ms/step
# Epoch 79/1000
# 22/22 - 0s - loss: 2.4383 - accuracy: 0.7678 - val_loss: 2.4238 - val_accuracy: 0.7727 - 112ms/epoch - 5ms/step
# Epoch 80/1000
# 22/22 - 0s - loss: 2.4361 - accuracy: 0.7678 - val_loss: 2.4218 - val_accuracy: 0.7727 - 122ms/epoch - 6ms/step
# Epoch 81/1000
# 22/22 - 0s - loss: 2.4338 - accuracy: 0.7678 - val_loss: 2.4196 - val_accuracy: 0.7727 - 113ms/epoch - 5ms/step
# Epoch 82/1000
# 22/22 - 0s - loss: 2.4317 - accuracy: 0.7678 - val_loss: 2.4174 - val_accuracy: 0.7727 - 112ms/epoch - 5ms/step
# Epoch 83/1000
# 22/22 - 0s - loss: 2.4295 - accuracy: 0.7707 - val_loss: 2.4151 - val_accuracy: 0.7727 - 109ms/epoch - 5ms/step
# Epoch 84/1000
# 22/22 - 0s - loss: 2.4274 - accuracy: 0.7707 - val_loss: 2.4130 - val_accuracy: 0.7727 - 116ms/epoch - 5ms/step
# Epoch 85/1000
# 22/22 - 0s - loss: 2.4253 - accuracy: 0.7707 - val_loss: 2.4109 - val_accuracy: 0.7727 - 113ms/epoch - 5ms/step
# Epoch 86/1000
# 22/22 - 0s - loss: 2.4232 - accuracy: 0.7692 - val_loss: 2.4090 - val_accuracy: 0.7727 - 110ms/epoch - 5ms/step
# Epoch 87/1000
# 22/22 - 0s - loss: 2.4212 - accuracy: 0.7692 - val_loss: 2.4071 - val_accuracy: 0.7778 - 113ms/epoch - 5ms/step
# Epoch 88/1000
# 22/22 - 0s - loss: 2.4191 - accuracy: 0.7692 - val_loss: 2.4049 - val_accuracy: 0.7778 - 150ms/epoch - 7ms/step
# Epoch 89/1000
# 22/22 - 0s - loss: 2.4172 - accuracy: 0.7692 - val_loss: 2.4026 - val_accuracy: 0.7778 - 121ms/epoch - 5ms/step
# Epoch 90/1000
# 22/22 - 0s - loss: 2.4151 - accuracy: 0.7692 - val_loss: 2.4008 - val_accuracy: 0.7778 - 111ms/epoch - 5ms/step
# Epoch 91/1000
# 22/22 - 0s - loss: 2.4131 - accuracy: 0.7692 - val_loss: 2.3989 - val_accuracy: 0.7778 - 110ms/epoch - 5ms/step
# Epoch 92/1000
# 22/22 - 0s - loss: 2.4111 - accuracy: 0.7692 - val_loss: 2.3970 - val_accuracy: 0.7778 - 111ms/epoch - 5ms/step
# Epoch 93/1000
# 22/22 - 0s - loss: 2.4092 - accuracy: 0.7721 - val_loss: 2.3951 - val_accuracy: 0.7778 - 113ms/epoch - 5ms/step
# Epoch 94/1000
# 22/22 - 0s - loss: 2.4071 - accuracy: 0.7721 - val_loss: 2.3931 - val_accuracy: 0.7778 - 109ms/epoch - 5ms/step
# Epoch 95/1000
# 22/22 - 0s - loss: 2.4052 - accuracy: 0.7735 - val_loss: 2.3911 - val_accuracy: 0.7778 - 115ms/epoch - 5ms/step
# Epoch 96/1000
# 22/22 - 0s - loss: 2.4033 - accuracy: 0.7735 - val_loss: 2.3893 - val_accuracy: 0.7778 - 113ms/epoch - 5ms/step
# Epoch 97/1000
# 22/22 - 0s - loss: 2.4015 - accuracy: 0.7735 - val_loss: 2.3872 - val_accuracy: 0.7828 - 113ms/epoch - 5ms/step
# Epoch 98/1000
# 22/22 - 0s - loss: 2.3994 - accuracy: 0.7721 - val_loss: 2.3856 - val_accuracy: 0.7778 - 115ms/epoch - 5ms/step
# Epoch 99/1000
# 22/22 - 0s - loss: 2.3976 - accuracy: 0.7749 - val_loss: 2.3838 - val_accuracy: 0.7828 - 112ms/epoch - 5ms/step
# Epoch 100/1000
# 22/22 - 0s - loss: 2.3957 - accuracy: 0.7735 - val_loss: 2.3818 - val_accuracy: 0.7879 - 113ms/epoch - 5ms/step
# Epoch 101/1000
# 22/22 - 0s - loss: 2.3938 - accuracy: 0.7764 - val_loss: 2.3801 - val_accuracy: 0.7828 - 113ms/epoch - 5ms/step
# Epoch 102/1000
# 22/22 - 0s - loss: 2.3919 - accuracy: 0.7778 - val_loss: 2.3783 - val_accuracy: 0.7828 - 113ms/epoch - 5ms/step
# Epoch 103/1000
# 22/22 - 0s - loss: 2.3901 - accuracy: 0.7778 - val_loss: 2.3763 - val_accuracy: 0.7879 - 115ms/epoch - 5ms/step
# Epoch 104/1000
# 22/22 - 0s - loss: 2.3884 - accuracy: 0.7792 - val_loss: 2.3749 - val_accuracy: 0.7828 - 111ms/epoch - 5ms/step
# Epoch 105/1000
# 22/22 - 0s - loss: 2.3864 - accuracy: 0.7821 - val_loss: 2.3728 - val_accuracy: 0.7879 - 113ms/epoch - 5ms/step
# Epoch 106/1000
# 22/22 - 0s - loss: 2.3846 - accuracy: 0.7806 - val_loss: 2.3711 - val_accuracy: 0.7828 - 111ms/epoch - 5ms/step
# Epoch 107/1000
# 22/22 - 0s - loss: 2.3827 - accuracy: 0.7821 - val_loss: 2.3694 - val_accuracy: 0.7828 - 113ms/epoch - 5ms/step
# Epoch 108/1000
# 22/22 - 0s - loss: 2.3809 - accuracy: 0.7821 - val_loss: 2.3676 - val_accuracy: 0.7828 - 112ms/epoch - 5ms/step
# Epoch 109/1000
# 22/22 - 0s - loss: 2.3791 - accuracy: 0.7821 - val_loss: 2.3661 - val_accuracy: 0.7828 - 111ms/epoch - 5ms/step
# Epoch 110/1000
# 22/22 - 0s - loss: 2.3773 - accuracy: 0.7821 - val_loss: 2.3642 - val_accuracy: 0.7828 - 112ms/epoch - 5ms/step
# Epoch 111/1000
# 22/22 - 0s - loss: 2.3755 - accuracy: 0.7849 - val_loss: 2.3623 - val_accuracy: 0.7879 - 111ms/epoch - 5ms/step
# Epoch 112/1000
# 22/22 - 0s - loss: 2.3737 - accuracy: 0.7835 - val_loss: 2.3605 - val_accuracy: 0.7879 - 111ms/epoch - 5ms/step
# Epoch 113/1000
# 22/22 - 0s - loss: 2.3719 - accuracy: 0.7849 - val_loss: 2.3590 - val_accuracy: 0.7828 - 111ms/epoch - 5ms/step
# Epoch 114/1000
# 22/22 - 0s - loss: 2.3702 - accuracy: 0.7849 - val_loss: 2.3574 - val_accuracy: 0.7828 - 111ms/epoch - 5ms/step
# Epoch 115/1000
# 22/22 - 0s - loss: 2.3684 - accuracy: 0.7849 - val_loss: 2.3558 - val_accuracy: 0.7828 - 113ms/epoch - 5ms/step
# Epoch 116/1000
# 22/22 - 0s - loss: 2.3667 - accuracy: 0.7849 - val_loss: 2.3538 - val_accuracy: 0.7879 - 110ms/epoch - 5ms/step
# Epoch 117/1000
# 22/22 - 0s - loss: 2.3649 - accuracy: 0.7849 - val_loss: 2.3522 - val_accuracy: 0.7879 - 110ms/epoch - 5ms/step
# Epoch 118/1000
# 22/22 - 0s - loss: 2.3632 - accuracy: 0.7849 - val_loss: 2.3509 - val_accuracy: 0.7879 - 115ms/epoch - 5ms/step
# Epoch 119/1000
# 22/22 - 0s - loss: 2.3615 - accuracy: 0.7849 - val_loss: 2.3489 - val_accuracy: 0.7879 - 112ms/epoch - 5ms/step
# Epoch 120/1000
# 22/22 - 0s - loss: 2.3597 - accuracy: 0.7863 - val_loss: 2.3473 - val_accuracy: 0.7879 - 110ms/epoch - 5ms/step
# Epoch 121/1000
# 22/22 - 0s - loss: 2.3579 - accuracy: 0.7849 - val_loss: 2.3458 - val_accuracy: 0.7929 - 110ms/epoch - 5ms/step
# Epoch 122/1000
# 22/22 - 0s - loss: 2.3562 - accuracy: 0.7863 - val_loss: 2.3441 - val_accuracy: 0.7929 - 110ms/epoch - 5ms/step
# Epoch 123/1000
# 22/22 - 0s - loss: 2.3545 - accuracy: 0.7877 - val_loss: 2.3425 - val_accuracy: 0.7929 - 112ms/epoch - 5ms/step
# Epoch 124/1000
# 22/22 - 0s - loss: 2.3528 - accuracy: 0.7877 - val_loss: 2.3408 - val_accuracy: 0.7929 - 150ms/epoch - 7ms/step
# Epoch 125/1000
# 22/22 - 0s - loss: 2.3512 - accuracy: 0.7877 - val_loss: 2.3390 - val_accuracy: 0.7929 - 110ms/epoch - 5ms/step
# Epoch 126/1000
# 22/22 - 0s - loss: 2.3494 - accuracy: 0.7892 - val_loss: 2.3377 - val_accuracy: 0.7879 - 111ms/epoch - 5ms/step
# Epoch 127/1000
# 22/22 - 0s - loss: 2.3477 - accuracy: 0.7892 - val_loss: 2.3361 - val_accuracy: 0.7828 - 108ms/epoch - 5ms/step
# Epoch 128/1000
# 22/22 - 0s - loss: 2.3460 - accuracy: 0.7892 - val_loss: 2.3346 - val_accuracy: 0.7828 - 110ms/epoch - 5ms/step
# Epoch 129/1000
# 22/22 - 0s - loss: 2.3443 - accuracy: 0.7906 - val_loss: 2.3330 - val_accuracy: 0.7879 - 111ms/epoch - 5ms/step
# Epoch 130/1000
# 22/22 - 0s - loss: 2.3427 - accuracy: 0.7906 - val_loss: 2.3314 - val_accuracy: 0.7929 - 110ms/epoch - 5ms/step
# Epoch 131/1000
# 22/22 - 0s - loss: 2.3410 - accuracy: 0.7906 - val_loss: 2.3298 - val_accuracy: 0.7879 - 113ms/epoch - 5ms/step
# Epoch 132/1000
# 22/22 - 0s - loss: 2.3393 - accuracy: 0.7920 - val_loss: 2.3281 - val_accuracy: 0.7879 - 115ms/epoch - 5ms/step
# Epoch 133/1000
# 22/22 - 0s - loss: 2.3377 - accuracy: 0.7920 - val_loss: 2.3265 - val_accuracy: 0.7879 - 111ms/epoch - 5ms/step
# Epoch 134/1000
# 22/22 - 0s - loss: 2.3360 - accuracy: 0.7920 - val_loss: 2.3251 - val_accuracy: 0.7879 - 113ms/epoch - 5ms/step
# Epoch 135/1000
# 22/22 - 0s - loss: 2.3344 - accuracy: 0.7920 - val_loss: 2.3237 - val_accuracy: 0.7879 - 111ms/epoch - 5ms/step
# Epoch 136/1000
# 22/22 - 0s - loss: 2.3327 - accuracy: 0.7920 - val_loss: 2.3220 - val_accuracy: 0.7879 - 113ms/epoch - 5ms/step
# Epoch 137/1000
# 22/22 - 0s - loss: 2.3312 - accuracy: 0.7920 - val_loss: 2.3202 - val_accuracy: 0.7929 - 111ms/epoch - 5ms/step
# Epoch 138/1000
# 22/22 - 0s - loss: 2.3295 - accuracy: 0.7934 - val_loss: 2.3188 - val_accuracy: 0.7879 - 114ms/epoch - 5ms/step
# Epoch 139/1000
# 22/22 - 0s - loss: 2.3278 - accuracy: 0.7934 - val_loss: 2.3174 - val_accuracy: 0.7879 - 114ms/epoch - 5ms/step
# Epoch 140/1000
# 22/22 - 0s - loss: 2.3262 - accuracy: 0.7934 - val_loss: 2.3158 - val_accuracy: 0.7879 - 111ms/epoch - 5ms/step
# Epoch 141/1000
# 22/22 - 0s - loss: 2.3246 - accuracy: 0.7934 - val_loss: 2.3143 - val_accuracy: 0.7879 - 112ms/epoch - 5ms/step
# Epoch 142/1000
# 22/22 - 0s - loss: 2.3230 - accuracy: 0.7934 - val_loss: 2.3130 - val_accuracy: 0.7879 - 112ms/epoch - 5ms/step
# Epoch 143/1000
# 22/22 - 0s - loss: 2.3213 - accuracy: 0.7934 - val_loss: 2.3113 - val_accuracy: 0.7879 - 110ms/epoch - 5ms/step
# Epoch 144/1000
# 22/22 - 0s - loss: 2.3196 - accuracy: 0.7934 - val_loss: 2.3098 - val_accuracy: 0.7879 - 111ms/epoch - 5ms/step
# Epoch 145/1000
# 22/22 - 0s - loss: 2.3180 - accuracy: 0.7920 - val_loss: 2.3083 - val_accuracy: 0.7879 - 110ms/epoch - 5ms/step
# Epoch 146/1000
# 22/22 - 0s - loss: 2.3164 - accuracy: 0.7920 - val_loss: 2.3069 - val_accuracy: 0.7879 - 114ms/epoch - 5ms/step
# Epoch 147/1000
# 22/22 - 0s - loss: 2.3149 - accuracy: 0.7934 - val_loss: 2.3051 - val_accuracy: 0.7879 - 108ms/epoch - 5ms/step
# Epoch 148/1000
# 22/22 - 0s - loss: 2.3132 - accuracy: 0.7934 - val_loss: 2.3038 - val_accuracy: 0.7879 - 115ms/epoch - 5ms/step
# Epoch 149/1000
# 22/22 - 0s - loss: 2.3116 - accuracy: 0.7920 - val_loss: 2.3023 - val_accuracy: 0.7879 - 113ms/epoch - 5ms/step
# Epoch 150/1000
# 22/22 - 0s - loss: 2.3100 - accuracy: 0.7920 - val_loss: 2.3008 - val_accuracy: 0.7879 - 110ms/epoch - 5ms/step
# Epoch 151/1000
# 22/22 - 0s - loss: 2.3085 - accuracy: 0.7934 - val_loss: 2.2992 - val_accuracy: 0.7879 - 111ms/epoch - 5ms/step
# Epoch 152/1000
# 22/22 - 0s - loss: 2.3068 - accuracy: 0.7934 - val_loss: 2.2978 - val_accuracy: 0.7879 - 112ms/epoch - 5ms/step
# Epoch 153/1000
# 22/22 - 0s - loss: 2.3052 - accuracy: 0.7920 - val_loss: 2.2964 - val_accuracy: 0.7879 - 108ms/epoch - 5ms/step
# Epoch 154/1000
# 22/22 - 0s - loss: 2.3037 - accuracy: 0.7934 - val_loss: 2.2950 - val_accuracy: 0.7879 - 112ms/epoch - 5ms/step
# Epoch 155/1000
# 22/22 - 0s - loss: 2.3021 - accuracy: 0.7920 - val_loss: 2.2934 - val_accuracy: 0.7879 - 112ms/epoch - 5ms/step
# Epoch 156/1000
# 22/22 - 0s - loss: 2.3005 - accuracy: 0.7949 - val_loss: 2.2919 - val_accuracy: 0.7879 - 113ms/epoch - 5ms/step
# Epoch 157/1000
# 22/22 - 0s - loss: 2.2990 - accuracy: 0.7949 - val_loss: 2.2904 - val_accuracy: 0.7879 - 157ms/epoch - 7ms/step
# Epoch 158/1000
# 22/22 - 0s - loss: 2.2974 - accuracy: 0.7934 - val_loss: 2.2891 - val_accuracy: 0.7879 - 110ms/epoch - 5ms/step
# Epoch 159/1000
# 22/22 - 0s - loss: 2.2958 - accuracy: 0.7934 - val_loss: 2.2875 - val_accuracy: 0.7879 - 108ms/epoch - 5ms/step
# Epoch 160/1000
# 22/22 - 0s - loss: 2.2943 - accuracy: 0.7934 - val_loss: 2.2863 - val_accuracy: 0.7879 - 108ms/epoch - 5ms/step
# Epoch 161/1000
# 22/22 - 0s - loss: 2.2927 - accuracy: 0.7934 - val_loss: 2.2845 - val_accuracy: 0.7879 - 113ms/epoch - 5ms/step
# Epoch 162/1000
# 22/22 - 0s - loss: 2.2911 - accuracy: 0.7920 - val_loss: 2.2832 - val_accuracy: 0.7879 - 112ms/epoch - 5ms/step
# Epoch 163/1000
# 22/22 - 0s - loss: 2.2896 - accuracy: 0.7934 - val_loss: 2.2817 - val_accuracy: 0.7879 - 124ms/epoch - 6ms/step
# Epoch 164/1000
# 22/22 - 0s - loss: 2.2880 - accuracy: 0.7934 - val_loss: 2.2802 - val_accuracy: 0.7879 - 115ms/epoch - 5ms/step
# Epoch 165/1000
# 22/22 - 0s - loss: 2.2865 - accuracy: 0.7934 - val_loss: 2.2787 - val_accuracy: 0.7879 - 115ms/epoch - 5ms/step
# Epoch 166/1000
# 22/22 - 0s - loss: 2.2849 - accuracy: 0.7934 - val_loss: 2.2773 - val_accuracy: 0.7879 - 119ms/epoch - 5ms/step
# Epoch 167/1000
# 22/22 - 0s - loss: 2.2834 - accuracy: 0.7934 - val_loss: 2.2760 - val_accuracy: 0.7879 - 113ms/epoch - 5ms/step
# Epoch 168/1000
# 22/22 - 0s - loss: 2.2818 - accuracy: 0.7934 - val_loss: 2.2745 - val_accuracy: 0.7879 - 110ms/epoch - 5ms/step
# Epoch 169/1000
# 22/22 - 0s - loss: 2.2804 - accuracy: 0.7920 - val_loss: 2.2731 - val_accuracy: 0.7879 - 113ms/epoch - 5ms/step
# Epoch 170/1000
# 22/22 - 0s - loss: 2.2787 - accuracy: 0.7920 - val_loss: 2.2716 - val_accuracy: 0.7879 - 117ms/epoch - 5ms/step
# Epoch 171/1000
# 22/22 - 0s - loss: 2.2773 - accuracy: 0.7920 - val_loss: 2.2703 - val_accuracy: 0.7879 - 111ms/epoch - 5ms/step
# Epoch 172/1000
# 22/22 - 0s - loss: 2.2757 - accuracy: 0.7920 - val_loss: 2.2690 - val_accuracy: 0.7879 - 113ms/epoch - 5ms/step
# Epoch 173/1000
# 22/22 - 0s - loss: 2.2742 - accuracy: 0.7906 - val_loss: 2.2673 - val_accuracy: 0.7879 - 110ms/epoch - 5ms/step
# Epoch 174/1000
# 22/22 - 0s - loss: 2.2727 - accuracy: 0.7906 - val_loss: 2.2660 - val_accuracy: 0.7879 - 114ms/epoch - 5ms/step
# Epoch 175/1000
# 22/22 - 0s - loss: 2.2711 - accuracy: 0.7920 - val_loss: 2.2645 - val_accuracy: 0.7879 - 115ms/epoch - 5ms/step
# Epoch 176/1000
# 22/22 - 0s - loss: 2.2696 - accuracy: 0.7920 - val_loss: 2.2630 - val_accuracy: 0.7879 - 113ms/epoch - 5ms/step
# Epoch 177/1000
# 22/22 - 0s - loss: 2.2681 - accuracy: 0.7906 - val_loss: 2.2619 - val_accuracy: 0.7879 - 111ms/epoch - 5ms/step
# Epoch 178/1000
# 22/22 - 0s - loss: 2.2666 - accuracy: 0.7906 - val_loss: 2.2604 - val_accuracy: 0.7879 - 111ms/epoch - 5ms/step
# Epoch 179/1000
# 22/22 - 0s - loss: 2.2651 - accuracy: 0.7920 - val_loss: 2.2590 - val_accuracy: 0.7879 - 108ms/epoch - 5ms/step
# Epoch 180/1000
# 22/22 - 0s - loss: 2.2635 - accuracy: 0.7920 - val_loss: 2.2576 - val_accuracy: 0.7879 - 114ms/epoch - 5ms/step
# Epoch 181/1000
# 22/22 - 0s - loss: 2.2620 - accuracy: 0.7906 - val_loss: 2.2561 - val_accuracy: 0.7879 - 111ms/epoch - 5ms/step
# Epoch 182/1000
# 22/22 - 0s - loss: 2.2605 - accuracy: 0.7920 - val_loss: 2.2548 - val_accuracy: 0.7879 - 113ms/epoch - 5ms/step
# Epoch 183/1000
# 22/22 - 0s - loss: 2.2591 - accuracy: 0.7920 - val_loss: 2.2533 - val_accuracy: 0.7879 - 114ms/epoch - 5ms/step
# Epoch 184/1000
# 22/22 - 0s - loss: 2.2575 - accuracy: 0.7920 - val_loss: 2.2519 - val_accuracy: 0.7879 - 115ms/epoch - 5ms/step
# Epoch 185/1000
# 22/22 - 0s - loss: 2.2561 - accuracy: 0.7906 - val_loss: 2.2506 - val_accuracy: 0.7879 - 110ms/epoch - 5ms/step
# Epoch 186/1000
# 22/22 - 0s - loss: 2.2545 - accuracy: 0.7906 - val_loss: 2.2494 - val_accuracy: 0.7879 - 114ms/epoch - 5ms/step
# Epoch 187/1000
# 22/22 - 0s - loss: 2.2530 - accuracy: 0.7920 - val_loss: 2.2478 - val_accuracy: 0.7879 - 110ms/epoch - 5ms/step
# Epoch 188/1000
# 22/22 - 0s - loss: 2.2515 - accuracy: 0.7920 - val_loss: 2.2464 - val_accuracy: 0.7879 - 109ms/epoch - 5ms/step
# Epoch 189/1000
# 22/22 - 0s - loss: 2.2500 - accuracy: 0.7920 - val_loss: 2.2452 - val_accuracy: 0.7879 - 114ms/epoch - 5ms/step
# Epoch 190/1000
# 22/22 - 0s - loss: 2.2485 - accuracy: 0.7920 - val_loss: 2.2437 - val_accuracy: 0.7929 - 150ms/epoch - 7ms/step
# Epoch 191/1000
# 22/22 - 0s - loss: 2.2470 - accuracy: 0.7920 - val_loss: 2.2424 - val_accuracy: 0.7929 - 111ms/epoch - 5ms/step
# Epoch 192/1000
# 22/22 - 0s - loss: 2.2456 - accuracy: 0.7934 - val_loss: 2.2410 - val_accuracy: 0.7929 - 113ms/epoch - 5ms/step
# Epoch 193/1000
# 22/22 - 0s - loss: 2.2440 - accuracy: 0.7934 - val_loss: 2.2396 - val_accuracy: 0.7929 - 109ms/epoch - 5ms/step
# Epoch 194/1000
# 22/22 - 0s - loss: 2.2426 - accuracy: 0.7949 - val_loss: 2.2381 - val_accuracy: 0.7929 - 108ms/epoch - 5ms/step
# Epoch 195/1000
# 22/22 - 0s - loss: 2.2411 - accuracy: 0.7920 - val_loss: 2.2368 - val_accuracy: 0.7929 - 113ms/epoch - 5ms/step
# Epoch 196/1000
# 22/22 - 0s - loss: 2.2396 - accuracy: 0.7920 - val_loss: 2.2355 - val_accuracy: 0.7929 - 116ms/epoch - 5ms/step
# Epoch 197/1000
# 22/22 - 0s - loss: 2.2382 - accuracy: 0.7920 - val_loss: 2.2339 - val_accuracy: 0.7929 - 112ms/epoch - 5ms/step
# Epoch 198/1000
# 22/22 - 0s - loss: 2.2368 - accuracy: 0.7920 - val_loss: 2.2328 - val_accuracy: 0.7929 - 112ms/epoch - 5ms/step
# Epoch 199/1000
# 22/22 - 0s - loss: 2.2353 - accuracy: 0.7934 - val_loss: 2.2313 - val_accuracy: 0.7929 - 113ms/epoch - 5ms/step
# Epoch 200/1000
# 22/22 - 0s - loss: 2.2338 - accuracy: 0.7949 - val_loss: 2.2301 - val_accuracy: 0.7929 - 115ms/epoch - 5ms/step
# Epoch 201/1000
# 22/22 - 0s - loss: 2.2323 - accuracy: 0.7920 - val_loss: 2.2287 - val_accuracy: 0.7929 - 113ms/epoch - 5ms/step
# Epoch 202/1000
# 22/22 - 0s - loss: 2.2308 - accuracy: 0.7934 - val_loss: 2.2273 - val_accuracy: 0.7929 - 113ms/epoch - 5ms/step
# Epoch 203/1000
# 22/22 - 0s - loss: 2.2294 - accuracy: 0.7949 - val_loss: 2.2258 - val_accuracy: 0.7929 - 112ms/epoch - 5ms/step
# Epoch 204/1000
# 22/22 - 0s - loss: 2.2279 - accuracy: 0.7934 - val_loss: 2.2247 - val_accuracy: 0.7929 - 120ms/epoch - 5ms/step
# Epoch 205/1000
# 22/22 - 0s - loss: 2.2264 - accuracy: 0.7934 - val_loss: 2.2232 - val_accuracy: 0.7929 - 113ms/epoch - 5ms/step
# Epoch 206/1000
# 22/22 - 0s - loss: 2.2250 - accuracy: 0.7949 - val_loss: 2.2219 - val_accuracy: 0.7929 - 112ms/epoch - 5ms/step
# Epoch 207/1000
# 22/22 - 0s - loss: 2.2235 - accuracy: 0.7949 - val_loss: 2.2205 - val_accuracy: 0.7929 - 111ms/epoch - 5ms/step
# Epoch 208/1000
# 22/22 - 0s - loss: 2.2221 - accuracy: 0.7949 - val_loss: 2.2191 - val_accuracy: 0.7929 - 112ms/epoch - 5ms/step
# Epoch 209/1000
# 22/22 - 0s - loss: 2.2206 - accuracy: 0.7949 - val_loss: 2.2179 - val_accuracy: 0.7879 - 111ms/epoch - 5ms/step
# Epoch 210/1000
# 22/22 - 0s - loss: 2.2192 - accuracy: 0.7949 - val_loss: 2.2164 - val_accuracy: 0.7879 - 115ms/epoch - 5ms/step
# Epoch 211/1000
# 22/22 - 0s - loss: 2.2178 - accuracy: 0.7949 - val_loss: 2.2152 - val_accuracy: 0.7879 - 111ms/epoch - 5ms/step
# Epoch 212/1000
# 22/22 - 0s - loss: 2.2163 - accuracy: 0.7963 - val_loss: 2.2138 - val_accuracy: 0.7879 - 116ms/epoch - 5ms/step
# Epoch 213/1000
# 22/22 - 0s - loss: 2.2149 - accuracy: 0.7949 - val_loss: 2.2125 - val_accuracy: 0.7879 - 112ms/epoch - 5ms/step
# Epoch 214/1000
# 22/22 - 0s - loss: 2.2134 - accuracy: 0.7963 - val_loss: 2.2111 - val_accuracy: 0.7879 - 112ms/epoch - 5ms/step
# Epoch 215/1000
# 22/22 - 0s - loss: 2.2120 - accuracy: 0.7977 - val_loss: 2.2099 - val_accuracy: 0.7879 - 113ms/epoch - 5ms/step
# Epoch 216/1000
# 22/22 - 0s - loss: 2.2106 - accuracy: 0.7977 - val_loss: 2.2085 - val_accuracy: 0.7879 - 113ms/epoch - 5ms/step
# Epoch 217/1000
# 22/22 - 0s - loss: 2.2091 - accuracy: 0.7991 - val_loss: 2.2073 - val_accuracy: 0.7879 - 112ms/epoch - 5ms/step
# Epoch 218/1000
# 22/22 - 0s - loss: 2.2076 - accuracy: 0.8006 - val_loss: 2.2059 - val_accuracy: 0.7879 - 110ms/epoch - 5ms/step
# Epoch 219/1000
# 22/22 - 0s - loss: 2.2062 - accuracy: 0.7991 - val_loss: 2.2046 - val_accuracy: 0.7879 - 114ms/epoch - 5ms/step
# Epoch 220/1000
# 22/22 - 0s - loss: 2.2048 - accuracy: 0.8006 - val_loss: 2.2033 - val_accuracy: 0.7879 - 153ms/epoch - 7ms/step
# Epoch 221/1000
# 22/22 - 0s - loss: 2.2033 - accuracy: 0.8006 - val_loss: 2.2020 - val_accuracy: 0.7879 - 112ms/epoch - 5ms/step
# Epoch 222/1000
# 22/22 - 0s - loss: 2.2020 - accuracy: 0.7991 - val_loss: 2.2007 - val_accuracy: 0.7879 - 111ms/epoch - 5ms/step
# Epoch 223/1000
# 22/22 - 0s - loss: 2.2005 - accuracy: 0.7991 - val_loss: 2.1994 - val_accuracy: 0.7879 - 111ms/epoch - 5ms/step
# Epoch 224/1000
# 22/22 - 0s - loss: 2.1992 - accuracy: 0.8006 - val_loss: 2.1981 - val_accuracy: 0.7879 - 109ms/epoch - 5ms/step
# Epoch 225/1000
# 22/22 - 0s - loss: 2.1977 - accuracy: 0.8020 - val_loss: 2.1967 - val_accuracy: 0.7879 - 112ms/epoch - 5ms/step
# Epoch 226/1000
# 22/22 - 0s - loss: 2.1963 - accuracy: 0.8006 - val_loss: 2.1954 - val_accuracy: 0.7879 - 118ms/epoch - 5ms/step
# Epoch 227/1000
# 22/22 - 0s - loss: 2.1949 - accuracy: 0.8006 - val_loss: 2.1940 - val_accuracy: 0.7879 - 111ms/epoch - 5ms/step
# Epoch 228/1000
# 22/22 - 0s - loss: 2.1935 - accuracy: 0.8006 - val_loss: 2.1927 - val_accuracy: 0.7879 - 113ms/epoch - 5ms/step
# Epoch 229/1000
# 22/22 - 0s - loss: 2.1920 - accuracy: 0.8020 - val_loss: 2.1916 - val_accuracy: 0.7879 - 111ms/epoch - 5ms/step
# Epoch 230/1000
# 22/22 - 0s - loss: 2.1906 - accuracy: 0.8020 - val_loss: 2.1903 - val_accuracy: 0.7879 - 111ms/epoch - 5ms/step
# Epoch 231/1000
# 22/22 - 0s - loss: 2.1892 - accuracy: 0.8020 - val_loss: 2.1890 - val_accuracy: 0.7879 - 111ms/epoch - 5ms/step
# Epoch 232/1000
# 22/22 - 0s - loss: 2.1879 - accuracy: 0.8034 - val_loss: 2.1876 - val_accuracy: 0.7879 - 111ms/epoch - 5ms/step
# Epoch 233/1000
# 22/22 - 0s - loss: 2.1865 - accuracy: 0.8034 - val_loss: 2.1862 - val_accuracy: 0.7879 - 112ms/epoch - 5ms/step
# Epoch 234/1000
# 22/22 - 0s - loss: 2.1850 - accuracy: 0.8020 - val_loss: 2.1851 - val_accuracy: 0.7879 - 112ms/epoch - 5ms/step
# Epoch 235/1000
# 22/22 - 0s - loss: 2.1836 - accuracy: 0.8034 - val_loss: 2.1838 - val_accuracy: 0.7879 - 115ms/epoch - 5ms/step
# Epoch 236/1000
# 22/22 - 0s - loss: 2.1823 - accuracy: 0.8048 - val_loss: 2.1823 - val_accuracy: 0.7879 - 112ms/epoch - 5ms/step
# Epoch 237/1000
# 22/22 - 0s - loss: 2.1809 - accuracy: 0.8063 - val_loss: 2.1812 - val_accuracy: 0.7879 - 117ms/epoch - 5ms/step
# Epoch 238/1000
# 22/22 - 0s - loss: 2.1796 - accuracy: 0.8048 - val_loss: 2.1802 - val_accuracy: 0.7879 - 110ms/epoch - 5ms/step
# Epoch 239/1000
# 22/22 - 0s - loss: 2.1781 - accuracy: 0.8063 - val_loss: 2.1785 - val_accuracy: 0.7879 - 112ms/epoch - 5ms/step
# Epoch 240/1000
# 22/22 - 0s - loss: 2.1767 - accuracy: 0.8048 - val_loss: 2.1773 - val_accuracy: 0.7879 - 111ms/epoch - 5ms/step
# Epoch 241/1000
# 22/22 - 0s - loss: 2.1753 - accuracy: 0.8048 - val_loss: 2.1758 - val_accuracy: 0.7879 - 114ms/epoch - 5ms/step
# Epoch 242/1000
# 22/22 - 0s - loss: 2.1739 - accuracy: 0.8063 - val_loss: 2.1747 - val_accuracy: 0.7879 - 111ms/epoch - 5ms/step
# Epoch 243/1000
# 22/22 - 0s - loss: 2.1725 - accuracy: 0.8063 - val_loss: 2.1735 - val_accuracy: 0.7879 - 114ms/epoch - 5ms/step
# Epoch 244/1000
# 22/22 - 0s - loss: 2.1711 - accuracy: 0.8077 - val_loss: 2.1721 - val_accuracy: 0.7879 - 109ms/epoch - 5ms/step
# Epoch 245/1000
# 22/22 - 0s - loss: 2.1698 - accuracy: 0.8077 - val_loss: 2.1710 - val_accuracy: 0.7879 - 113ms/epoch - 5ms/step
# Epoch 246/1000
# 22/22 - 0s - loss: 2.1684 - accuracy: 0.8077 - val_loss: 2.1697 - val_accuracy: 0.7879 - 113ms/epoch - 5ms/step
# Epoch 247/1000
# 22/22 - 0s - loss: 2.1670 - accuracy: 0.8077 - val_loss: 2.1685 - val_accuracy: 0.7879 - 109ms/epoch - 5ms/step
# Epoch 248/1000
# 22/22 - 0s - loss: 2.1656 - accuracy: 0.8077 - val_loss: 2.1671 - val_accuracy: 0.7879 - 110ms/epoch - 5ms/step
# Epoch 249/1000
# 22/22 - 0s - loss: 2.1643 - accuracy: 0.8077 - val_loss: 2.1659 - val_accuracy: 0.7879 - 111ms/epoch - 5ms/step
# Epoch 250/1000
# 22/22 - 0s - loss: 2.1629 - accuracy: 0.8077 - val_loss: 2.1645 - val_accuracy: 0.7879 - 148ms/epoch - 7ms/step
# Epoch 251/1000
# 22/22 - 0s - loss: 2.1615 - accuracy: 0.8063 - val_loss: 2.1633 - val_accuracy: 0.7879 - 111ms/epoch - 5ms/step
# Epoch 252/1000
# 22/22 - 0s - loss: 2.1601 - accuracy: 0.8077 - val_loss: 2.1621 - val_accuracy: 0.7879 - 110ms/epoch - 5ms/step
# Epoch 253/1000
# 22/22 - 0s - loss: 2.1588 - accuracy: 0.8077 - val_loss: 2.1608 - val_accuracy: 0.7879 - 109ms/epoch - 5ms/step
# Epoch 254/1000
# 22/22 - 0s - loss: 2.1574 - accuracy: 0.8077 - val_loss: 2.1595 - val_accuracy: 0.7879 - 110ms/epoch - 5ms/step
# Epoch 255/1000
# 22/22 - 0s - loss: 2.1561 - accuracy: 0.8077 - val_loss: 2.1583 - val_accuracy: 0.7879 - 111ms/epoch - 5ms/step
# Epoch 256/1000
# 22/22 - 0s - loss: 2.1547 - accuracy: 0.8077 - val_loss: 2.1570 - val_accuracy: 0.7879 - 113ms/epoch - 5ms/step
# Epoch 257/1000
# 22/22 - 0s - loss: 2.1534 - accuracy: 0.8077 - val_loss: 2.1558 - val_accuracy: 0.7879 - 111ms/epoch - 5ms/step
# Epoch 258/1000
# 22/22 - 0s - loss: 2.1520 - accuracy: 0.8063 - val_loss: 2.1546 - val_accuracy: 0.7879 - 112ms/epoch - 5ms/step
# Epoch 259/1000
# 22/22 - 0s - loss: 2.1506 - accuracy: 0.8063 - val_loss: 2.1533 - val_accuracy: 0.7879 - 110ms/epoch - 5ms/step
# Epoch 260/1000
# 22/22 - 0s - loss: 2.1493 - accuracy: 0.8077 - val_loss: 2.1521 - val_accuracy: 0.7879 - 111ms/epoch - 5ms/step
# Epoch 261/1000
# 22/22 - 0s - loss: 2.1479 - accuracy: 0.8063 - val_loss: 2.1508 - val_accuracy: 0.7879 - 110ms/epoch - 5ms/step
# Epoch 262/1000
# 22/22 - 0s - loss: 2.1466 - accuracy: 0.8077 - val_loss: 2.1497 - val_accuracy: 0.7879 - 115ms/epoch - 5ms/step
# Epoch 263/1000
# 22/22 - 0s - loss: 2.1452 - accuracy: 0.8063 - val_loss: 2.1484 - val_accuracy: 0.7879 - 110ms/epoch - 5ms/step
# Epoch 264/1000
# 22/22 - 0s - loss: 2.1439 - accuracy: 0.8063 - val_loss: 2.1471 - val_accuracy: 0.7879 - 113ms/epoch - 5ms/step
# Epoch 265/1000
# 22/22 - 0s - loss: 2.1425 - accuracy: 0.8063 - val_loss: 2.1458 - val_accuracy: 0.7879 - 115ms/epoch - 5ms/step
# Epoch 266/1000
# 22/22 - 0s - loss: 2.1412 - accuracy: 0.8077 - val_loss: 2.1445 - val_accuracy: 0.7879 - 112ms/epoch - 5ms/step
# Epoch 267/1000
# 22/22 - 0s - loss: 2.1399 - accuracy: 0.8077 - val_loss: 2.1432 - val_accuracy: 0.7929 - 117ms/epoch - 5ms/step
# Epoch 268/1000
# 22/22 - 0s - loss: 2.1385 - accuracy: 0.8077 - val_loss: 2.1422 - val_accuracy: 0.7879 - 111ms/epoch - 5ms/step
# Epoch 269/1000
# 22/22 - 0s - loss: 2.1371 - accuracy: 0.8091 - val_loss: 2.1408 - val_accuracy: 0.7929 - 111ms/epoch - 5ms/step
# Epoch 270/1000
# 22/22 - 0s - loss: 2.1358 - accuracy: 0.8091 - val_loss: 2.1395 - val_accuracy: 0.7879 - 112ms/epoch - 5ms/step
# Epoch 271/1000
# 22/22 - 0s - loss: 2.1345 - accuracy: 0.8105 - val_loss: 2.1384 - val_accuracy: 0.7879 - 112ms/epoch - 5ms/step
# Epoch 272/1000
# 22/22 - 0s - loss: 2.1332 - accuracy: 0.8091 - val_loss: 2.1371 - val_accuracy: 0.7879 - 113ms/epoch - 5ms/step
# Epoch 273/1000
# 22/22 - 0s - loss: 2.1318 - accuracy: 0.8091 - val_loss: 2.1360 - val_accuracy: 0.7879 - 114ms/epoch - 5ms/step
# Epoch 274/1000
# 22/22 - 0s - loss: 2.1305 - accuracy: 0.8091 - val_loss: 2.1347 - val_accuracy: 0.7879 - 115ms/epoch - 5ms/step
# Epoch 275/1000
# 22/22 - 0s - loss: 2.1291 - accuracy: 0.8105 - val_loss: 2.1335 - val_accuracy: 0.7879 - 120ms/epoch - 5ms/step
# Epoch 276/1000
# 22/22 - 0s - loss: 2.1278 - accuracy: 0.8105 - val_loss: 2.1324 - val_accuracy: 0.7879 - 114ms/epoch - 5ms/step
# Epoch 277/1000
# 22/22 - 0s - loss: 2.1264 - accuracy: 0.8105 - val_loss: 2.1310 - val_accuracy: 0.7879 - 110ms/epoch - 5ms/step
# Epoch 278/1000
# 22/22 - 0s - loss: 2.1251 - accuracy: 0.8105 - val_loss: 2.1298 - val_accuracy: 0.7879 - 149ms/epoch - 7ms/step
# Epoch 279/1000
# 22/22 - 0s - loss: 2.1238 - accuracy: 0.8105 - val_loss: 2.1285 - val_accuracy: 0.7929 - 112ms/epoch - 5ms/step
# Epoch 280/1000
# 22/22 - 0s - loss: 2.1226 - accuracy: 0.8105 - val_loss: 2.1274 - val_accuracy: 0.7879 - 111ms/epoch - 5ms/step
# Epoch 281/1000
# 22/22 - 0s - loss: 2.1212 - accuracy: 0.8105 - val_loss: 2.1261 - val_accuracy: 0.7929 - 110ms/epoch - 5ms/step
# Epoch 282/1000
# 22/22 - 0s - loss: 2.1198 - accuracy: 0.8105 - val_loss: 2.1249 - val_accuracy: 0.7879 - 109ms/epoch - 5ms/step
# Epoch 283/1000
# 22/22 - 0s - loss: 2.1185 - accuracy: 0.8105 - val_loss: 2.1237 - val_accuracy: 0.7929 - 113ms/epoch - 5ms/step
# Epoch 284/1000
# 22/22 - 0s - loss: 2.1173 - accuracy: 0.8105 - val_loss: 2.1225 - val_accuracy: 0.7879 - 112ms/epoch - 5ms/step
# Epoch 285/1000
# 22/22 - 0s - loss: 2.1159 - accuracy: 0.8105 - val_loss: 2.1212 - val_accuracy: 0.7929 - 111ms/epoch - 5ms/step
# Epoch 286/1000
# 22/22 - 0s - loss: 2.1146 - accuracy: 0.8105 - val_loss: 2.1199 - val_accuracy: 0.7929 - 115ms/epoch - 5ms/step
# Epoch 287/1000
# 22/22 - 0s - loss: 2.1133 - accuracy: 0.8105 - val_loss: 2.1186 - val_accuracy: 0.7929 - 114ms/epoch - 5ms/step
# Epoch 288/1000
# 22/22 - 0s - loss: 2.1120 - accuracy: 0.8105 - val_loss: 2.1177 - val_accuracy: 0.7929 - 112ms/epoch - 5ms/step
# Epoch 289/1000
# 22/22 - 0s - loss: 2.1107 - accuracy: 0.8105 - val_loss: 2.1163 - val_accuracy: 0.7929 - 112ms/epoch - 5ms/step
# Epoch 290/1000
# 22/22 - 0s - loss: 2.1094 - accuracy: 0.8105 - val_loss: 2.1153 - val_accuracy: 0.7929 - 114ms/epoch - 5ms/step
# Epoch 291/1000
# 22/22 - 0s - loss: 2.1081 - accuracy: 0.8105 - val_loss: 2.1142 - val_accuracy: 0.7929 - 112ms/epoch - 5ms/step
# Epoch 292/1000
# 22/22 - 0s - loss: 2.1068 - accuracy: 0.8120 - val_loss: 2.1128 - val_accuracy: 0.7929 - 110ms/epoch - 5ms/step
# Epoch 293/1000
# 22/22 - 0s - loss: 2.1055 - accuracy: 0.8120 - val_loss: 2.1116 - val_accuracy: 0.7929 - 113ms/epoch - 5ms/step
# Epoch 294/1000
# 22/22 - 0s - loss: 2.1042 - accuracy: 0.8120 - val_loss: 2.1105 - val_accuracy: 0.7929 - 115ms/epoch - 5ms/step
# Epoch 295/1000
# 22/22 - 0s - loss: 2.1029 - accuracy: 0.8105 - val_loss: 2.1091 - val_accuracy: 0.7929 - 109ms/epoch - 5ms/step
# Epoch 296/1000
# 22/22 - 0s - loss: 2.1016 - accuracy: 0.8120 - val_loss: 2.1081 - val_accuracy: 0.7929 - 111ms/epoch - 5ms/step
# Epoch 297/1000
# 22/22 - 0s - loss: 2.1003 - accuracy: 0.8120 - val_loss: 2.1069 - val_accuracy: 0.7929 - 109ms/epoch - 5ms/step
# Epoch 298/1000
# 22/22 - 0s - loss: 2.0990 - accuracy: 0.8120 - val_loss: 2.1056 - val_accuracy: 0.7929 - 111ms/epoch - 5ms/step
# Epoch 299/1000
# 22/22 - 0s - loss: 2.0977 - accuracy: 0.8120 - val_loss: 2.1042 - val_accuracy: 0.7929 - 111ms/epoch - 5ms/step
# Epoch 300/1000
# 22/22 - 0s - loss: 2.0965 - accuracy: 0.8105 - val_loss: 2.1031 - val_accuracy: 0.7929 - 111ms/epoch - 5ms/step
# Epoch 301/1000
# 22/22 - 0s - loss: 2.0952 - accuracy: 0.8105 - val_loss: 2.1021 - val_accuracy: 0.7929 - 112ms/epoch - 5ms/step
# Epoch 302/1000
# 22/22 - 0s - loss: 2.0939 - accuracy: 0.8120 - val_loss: 2.1010 - val_accuracy: 0.7929 - 111ms/epoch - 5ms/step
# Epoch 303/1000
# 22/22 - 0s - loss: 2.0928 - accuracy: 0.8134 - val_loss: 2.0999 - val_accuracy: 0.7879 - 112ms/epoch - 5ms/step
# Epoch 304/1000
# 22/22 - 0s - loss: 2.0914 - accuracy: 0.8120 - val_loss: 2.0986 - val_accuracy: 0.7929 - 112ms/epoch - 5ms/step
# Epoch 305/1000
# 22/22 - 0s - loss: 2.0900 - accuracy: 0.8105 - val_loss: 2.0971 - val_accuracy: 0.7929 - 111ms/epoch - 5ms/step
# Epoch 306/1000
# 22/22 - 0s - loss: 2.0888 - accuracy: 0.8105 - val_loss: 2.0961 - val_accuracy: 0.7929 - 110ms/epoch - 5ms/step
# Epoch 307/1000
# 22/22 - 0s - loss: 2.0875 - accuracy: 0.8091 - val_loss: 2.0949 - val_accuracy: 0.7929 - 114ms/epoch - 5ms/step
# Epoch 308/1000
# 22/22 - 0s - loss: 2.0862 - accuracy: 0.8105 - val_loss: 2.0937 - val_accuracy: 0.7929 - 110ms/epoch - 5ms/step
# Epoch 309/1000
# 22/22 - 0s - loss: 2.0850 - accuracy: 0.8105 - val_loss: 2.0927 - val_accuracy: 0.7929 - 145ms/epoch - 7ms/step
# Epoch 310/1000
# 22/22 - 0s - loss: 2.0837 - accuracy: 0.8105 - val_loss: 2.0914 - val_accuracy: 0.7929 - 112ms/epoch - 5ms/step
# Epoch 311/1000
# 22/22 - 0s - loss: 2.0825 - accuracy: 0.8105 - val_loss: 2.0904 - val_accuracy: 0.7929 - 111ms/epoch - 5ms/step
# Epoch 312/1000
# 22/22 - 0s - loss: 2.0812 - accuracy: 0.8105 - val_loss: 2.0890 - val_accuracy: 0.7929 - 114ms/epoch - 5ms/step
# Epoch 313/1000
# 22/22 - 0s - loss: 2.0799 - accuracy: 0.8105 - val_loss: 2.0879 - val_accuracy: 0.7929 - 113ms/epoch - 5ms/step
# Epoch 314/1000
# 22/22 - 0s - loss: 2.0787 - accuracy: 0.8105 - val_loss: 2.0869 - val_accuracy: 0.7929 - 113ms/epoch - 5ms/step
# Epoch 315/1000
# 22/22 - 0s - loss: 2.0774 - accuracy: 0.8105 - val_loss: 2.0856 - val_accuracy: 0.7980 - 111ms/epoch - 5ms/step
# Epoch 316/1000
# 22/22 - 0s - loss: 2.0762 - accuracy: 0.8105 - val_loss: 2.0842 - val_accuracy: 0.7980 - 112ms/epoch - 5ms/step
# Epoch 317/1000
# 22/22 - 0s - loss: 2.0748 - accuracy: 0.8105 - val_loss: 2.0833 - val_accuracy: 0.7980 - 110ms/epoch - 5ms/step
# Epoch 318/1000
# 22/22 - 0s - loss: 2.0736 - accuracy: 0.8105 - val_loss: 2.0822 - val_accuracy: 0.7980 - 109ms/epoch - 5ms/step
# Epoch 319/1000
# 22/22 - 0s - loss: 2.0723 - accuracy: 0.8105 - val_loss: 2.0810 - val_accuracy: 0.7980 - 116ms/epoch - 5ms/step
# Epoch 320/1000
# 22/22 - 0s - loss: 2.0711 - accuracy: 0.8091 - val_loss: 2.0798 - val_accuracy: 0.7980 - 110ms/epoch - 5ms/step
# Epoch 321/1000
# 22/22 - 0s - loss: 2.0698 - accuracy: 0.8091 - val_loss: 2.0786 - val_accuracy: 0.7980 - 112ms/epoch - 5ms/step
# Epoch 322/1000
# 22/22 - 0s - loss: 2.0686 - accuracy: 0.8091 - val_loss: 2.0775 - val_accuracy: 0.7980 - 114ms/epoch - 5ms/step
# Epoch 323/1000
# 22/22 - 0s - loss: 2.0674 - accuracy: 0.8091 - val_loss: 2.0764 - val_accuracy: 0.7980 - 112ms/epoch - 5ms/step
# Epoch 324/1000
# 22/22 - 0s - loss: 2.0661 - accuracy: 0.8091 - val_loss: 2.0751 - val_accuracy: 0.7980 - 111ms/epoch - 5ms/step
# Epoch 325/1000
# 22/22 - 0s - loss: 2.0648 - accuracy: 0.8105 - val_loss: 2.0741 - val_accuracy: 0.7980 - 112ms/epoch - 5ms/step
# Epoch 326/1000
# 22/22 - 0s - loss: 2.0637 - accuracy: 0.8091 - val_loss: 2.0728 - val_accuracy: 0.7980 - 110ms/epoch - 5ms/step
# Epoch 327/1000
# 22/22 - 0s - loss: 2.0624 - accuracy: 0.8134 - val_loss: 2.0719 - val_accuracy: 0.7980 - 113ms/epoch - 5ms/step
# Epoch 328/1000
# 22/22 - 0s - loss: 2.0612 - accuracy: 0.8134 - val_loss: 2.0708 - val_accuracy: 0.7980 - 109ms/epoch - 5ms/step
# Epoch 329/1000
# 22/22 - 0s - loss: 2.0599 - accuracy: 0.8105 - val_loss: 2.0694 - val_accuracy: 0.7980 - 109ms/epoch - 5ms/step
# Epoch 330/1000
# 22/22 - 0s - loss: 2.0587 - accuracy: 0.8091 - val_loss: 2.0684 - val_accuracy: 0.7980 - 110ms/epoch - 5ms/step
# Epoch 331/1000
# 22/22 - 0s - loss: 2.0574 - accuracy: 0.8105 - val_loss: 2.0670 - val_accuracy: 0.7980 - 109ms/epoch - 5ms/step
# Epoch 332/1000
# 22/22 - 0s - loss: 2.0562 - accuracy: 0.8105 - val_loss: 2.0660 - val_accuracy: 0.7980 - 109ms/epoch - 5ms/step
# Epoch 333/1000
# 22/22 - 0s - loss: 2.0550 - accuracy: 0.8105 - val_loss: 2.0648 - val_accuracy: 0.7980 - 110ms/epoch - 5ms/step
# Epoch 334/1000
# 22/22 - 0s - loss: 2.0537 - accuracy: 0.8105 - val_loss: 2.0639 - val_accuracy: 0.7980 - 110ms/epoch - 5ms/step
# Epoch 335/1000
# 22/22 - 0s - loss: 2.0525 - accuracy: 0.8105 - val_loss: 2.0626 - val_accuracy: 0.7980 - 110ms/epoch - 5ms/step
# Epoch 336/1000
# 22/22 - 0s - loss: 2.0513 - accuracy: 0.8105 - val_loss: 2.0616 - val_accuracy: 0.7980 - 111ms/epoch - 5ms/step
# Epoch 337/1000
# 22/22 - 0s - loss: 2.0500 - accuracy: 0.8105 - val_loss: 2.0604 - val_accuracy: 0.7980 - 147ms/epoch - 7ms/step
# Epoch 338/1000
# 22/22 - 0s - loss: 2.0488 - accuracy: 0.8105 - val_loss: 2.0592 - val_accuracy: 0.7980 - 111ms/epoch - 5ms/step
# Epoch 339/1000
# 22/22 - 0s - loss: 2.0476 - accuracy: 0.8105 - val_loss: 2.0582 - val_accuracy: 0.7980 - 112ms/epoch - 5ms/step
# Epoch 340/1000
# 22/22 - 0s - loss: 2.0463 - accuracy: 0.8120 - val_loss: 2.0570 - val_accuracy: 0.7980 - 112ms/epoch - 5ms/step
# Epoch 341/1000
# 22/22 - 0s - loss: 2.0452 - accuracy: 0.8091 - val_loss: 2.0559 - val_accuracy: 0.7980 - 114ms/epoch - 5ms/step
# Epoch 342/1000
# 22/22 - 0s - loss: 2.0439 - accuracy: 0.8105 - val_loss: 2.0547 - val_accuracy: 0.7929 - 112ms/epoch - 5ms/step
# Epoch 343/1000
# 22/22 - 0s - loss: 2.0427 - accuracy: 0.8091 - val_loss: 2.0535 - val_accuracy: 0.7980 - 111ms/epoch - 5ms/step
# Epoch 344/1000
# 22/22 - 0s - loss: 2.0415 - accuracy: 0.8120 - val_loss: 2.0526 - val_accuracy: 0.7980 - 110ms/epoch - 5ms/step
# Epoch 345/1000
# 22/22 - 0s - loss: 2.0403 - accuracy: 0.8120 - val_loss: 2.0513 - val_accuracy: 0.7929 - 110ms/epoch - 5ms/step
# Epoch 346/1000
# 22/22 - 0s - loss: 2.0391 - accuracy: 0.8134 - val_loss: 2.0503 - val_accuracy: 0.7980 - 110ms/epoch - 5ms/step
# Epoch 347/1000
# 22/22 - 0s - loss: 2.0378 - accuracy: 0.8105 - val_loss: 2.0492 - val_accuracy: 0.7980 - 112ms/epoch - 5ms/step
# Epoch 348/1000
# 22/22 - 0s - loss: 2.0367 - accuracy: 0.8105 - val_loss: 2.0480 - val_accuracy: 0.7980 - 110ms/epoch - 5ms/step
# Epoch 349/1000
# 22/22 - 0s - loss: 2.0354 - accuracy: 0.8105 - val_loss: 2.0469 - val_accuracy: 0.7929 - 111ms/epoch - 5ms/step
# Epoch 350/1000
# 22/22 - 0s - loss: 2.0342 - accuracy: 0.8105 - val_loss: 2.0458 - val_accuracy: 0.7929 - 112ms/epoch - 5ms/step
# Epoch 351/1000
# 22/22 - 0s - loss: 2.0330 - accuracy: 0.8105 - val_loss: 2.0447 - val_accuracy: 0.7929 - 109ms/epoch - 5ms/step
# Epoch 352/1000
# 22/22 - 0s - loss: 2.0319 - accuracy: 0.8105 - val_loss: 2.0433 - val_accuracy: 0.7929 - 110ms/epoch - 5ms/step
# Epoch 353/1000
# 22/22 - 0s - loss: 2.0306 - accuracy: 0.8105 - val_loss: 2.0423 - val_accuracy: 0.7929 - 111ms/epoch - 5ms/step
# Epoch 354/1000
# 22/22 - 0s - loss: 2.0294 - accuracy: 0.8105 - val_loss: 2.0414 - val_accuracy: 0.7929 - 111ms/epoch - 5ms/step
# Epoch 355/1000
# 22/22 - 0s - loss: 2.0282 - accuracy: 0.8105 - val_loss: 2.0402 - val_accuracy: 0.7929 - 110ms/epoch - 5ms/step
# Epoch 356/1000
# 22/22 - 0s - loss: 2.0270 - accuracy: 0.8105 - val_loss: 2.0393 - val_accuracy: 0.7929 - 110ms/epoch - 5ms/step
# Epoch 357/1000
# 22/22 - 0s - loss: 2.0258 - accuracy: 0.8105 - val_loss: 2.0380 - val_accuracy: 0.7929 - 113ms/epoch - 5ms/step
# Epoch 358/1000
# 22/22 - 0s - loss: 2.0246 - accuracy: 0.8105 - val_loss: 2.0369 - val_accuracy: 0.7929 - 111ms/epoch - 5ms/step
# Epoch 359/1000
# 22/22 - 0s - loss: 2.0234 - accuracy: 0.8105 - val_loss: 2.0358 - val_accuracy: 0.7929 - 139ms/epoch - 6ms/step
# Epoch 360/1000
# 22/22 - 0s - loss: 2.0222 - accuracy: 0.8120 - val_loss: 2.0347 - val_accuracy: 0.7929 - 113ms/epoch - 5ms/step
# Epoch 361/1000
# 22/22 - 0s - loss: 2.0210 - accuracy: 0.8105 - val_loss: 2.0335 - val_accuracy: 0.7929 - 111ms/epoch - 5ms/step
# Epoch 362/1000
# 22/22 - 0s - loss: 2.0198 - accuracy: 0.8120 - val_loss: 2.0325 - val_accuracy: 0.7929 - 110ms/epoch - 5ms/step
# Epoch 363/1000
# 22/22 - 0s - loss: 2.0187 - accuracy: 0.8120 - val_loss: 2.0314 - val_accuracy: 0.7929 - 118ms/epoch - 5ms/step
# Epoch 364/1000
# 22/22 - 0s - loss: 2.0174 - accuracy: 0.8134 - val_loss: 2.0304 - val_accuracy: 0.7929 - 113ms/epoch - 5ms/step
# Epoch 365/1000
# 22/22 - 0s - loss: 2.0163 - accuracy: 0.8148 - val_loss: 2.0289 - val_accuracy: 0.7929 - 194ms/epoch - 9ms/step
# Epoch 366/1000
# 22/22 - 0s - loss: 2.0150 - accuracy: 0.8134 - val_loss: 2.0282 - val_accuracy: 0.7929 - 114ms/epoch - 5ms/step
# Epoch 367/1000
# 22/22 - 0s - loss: 2.0139 - accuracy: 0.8134 - val_loss: 2.0270 - val_accuracy: 0.7929 - 112ms/epoch - 5ms/step
# Epoch 368/1000
# 22/22 - 0s - loss: 2.0126 - accuracy: 0.8134 - val_loss: 2.0259 - val_accuracy: 0.7929 - 110ms/epoch - 5ms/step
# Epoch 369/1000
# 22/22 - 0s - loss: 2.0115 - accuracy: 0.8134 - val_loss: 2.0251 - val_accuracy: 0.7929 - 112ms/epoch - 5ms/step
# Epoch 370/1000
# 22/22 - 0s - loss: 2.0103 - accuracy: 0.8148 - val_loss: 2.0236 - val_accuracy: 0.7929 - 112ms/epoch - 5ms/step
# Epoch 371/1000
# 22/22 - 0s - loss: 2.0092 - accuracy: 0.8134 - val_loss: 2.0227 - val_accuracy: 0.7929 - 129ms/epoch - 6ms/step
# Epoch 372/1000
# 22/22 - 0s - loss: 2.0080 - accuracy: 0.8120 - val_loss: 2.0218 - val_accuracy: 0.7929 - 126ms/epoch - 6ms/step
# Epoch 373/1000
# 22/22 - 0s - loss: 2.0068 - accuracy: 0.8148 - val_loss: 2.0206 - val_accuracy: 0.7929 - 111ms/epoch - 5ms/step
# Epoch 374/1000
# 22/22 - 0s - loss: 2.0057 - accuracy: 0.8134 - val_loss: 2.0193 - val_accuracy: 0.7929 - 111ms/epoch - 5ms/step
# Epoch 375/1000
# 22/22 - 0s - loss: 2.0045 - accuracy: 0.8134 - val_loss: 2.0185 - val_accuracy: 0.7929 - 110ms/epoch - 5ms/step
# Epoch 376/1000
# 22/22 - 0s - loss: 2.0033 - accuracy: 0.8148 - val_loss: 2.0173 - val_accuracy: 0.7929 - 111ms/epoch - 5ms/step
# Epoch 377/1000
# 22/22 - 0s - loss: 2.0021 - accuracy: 0.8148 - val_loss: 2.0162 - val_accuracy: 0.7929 - 111ms/epoch - 5ms/step
# Epoch 378/1000
# 22/22 - 0s - loss: 2.0010 - accuracy: 0.8134 - val_loss: 2.0151 - val_accuracy: 0.7929 - 112ms/epoch - 5ms/step
# Epoch 379/1000
# ...
# 22/22 - 0s - loss: 1.5537 - accuracy: 0.8533 - val_loss: 1.6135 - val_accuracy: 0.8182 - 112ms/epoch - 5ms/step
# Epoch 876/1000
# 22/22 - 0s - loss: 1.5529 - accuracy: 0.8519 - val_loss: 1.6126 - val_accuracy: 0.8182 - 114ms/epoch - 5ms/step
# Epoch 877/1000
# 22/22 - 0s - loss: 1.5522 - accuracy: 0.8519 - val_loss: 1.6122 - val_accuracy: 0.8182 - 111ms/epoch - 5ms/step
# Epoch 878/1000
# 22/22 - 0s - loss: 1.5515 - accuracy: 0.8519 - val_loss: 1.6117 - val_accuracy: 0.8182 - 115ms/epoch - 5ms/step
# Epoch 879/1000
# 22/22 - 0s - loss: 1.5508 - accuracy: 0.8519 - val_loss: 1.6109 - val_accuracy: 0.8182 - 114ms/epoch - 5ms/step
# Epoch 880/1000
# 22/22 - 0s - loss: 1.5501 - accuracy: 0.8519 - val_loss: 1.6101 - val_accuracy: 0.8182 - 114ms/epoch - 5ms/step
# Epoch 881/1000
# 22/22 - 0s - loss: 1.5494 - accuracy: 0.8504 - val_loss: 1.6095 - val_accuracy: 0.8182 - 153ms/epoch - 7ms/step
# Epoch 882/1000
# 22/22 - 0s - loss: 1.5488 - accuracy: 0.8519 - val_loss: 1.6091 - val_accuracy: 0.8182 - 115ms/epoch - 5ms/step
# Epoch 883/1000
# 22/22 - 0s - loss: 1.5481 - accuracy: 0.8519 - val_loss: 1.6088 - val_accuracy: 0.8182 - 114ms/epoch - 5ms/step
# Epoch 884/1000
# 22/22 - 0s - loss: 1.5474 - accuracy: 0.8519 - val_loss: 1.6078 - val_accuracy: 0.8182 - 112ms/epoch - 5ms/step
# Epoch 885/1000
# 22/22 - 0s - loss: 1.5467 - accuracy: 0.8519 - val_loss: 1.6074 - val_accuracy: 0.8182 - 112ms/epoch - 5ms/step
# Epoch 886/1000
# 22/22 - 0s - loss: 1.5461 - accuracy: 0.8504 - val_loss: 1.6070 - val_accuracy: 0.8182 - 113ms/epoch - 5ms/step
# Epoch 887/1000
# 22/22 - 0s - loss: 1.5455 - accuracy: 0.8519 - val_loss: 1.6060 - val_accuracy: 0.8182 - 114ms/epoch - 5ms/step
# Epoch 888/1000
# 22/22 - 0s - loss: 1.5447 - accuracy: 0.8504 - val_loss: 1.6054 - val_accuracy: 0.8182 - 113ms/epoch - 5ms/step
# Epoch 889/1000
# 22/22 - 0s - loss: 1.5439 - accuracy: 0.8519 - val_loss: 1.6050 - val_accuracy: 0.8182 - 117ms/epoch - 5ms/step
# Epoch 890/1000
# 22/22 - 0s - loss: 1.5433 - accuracy: 0.8519 - val_loss: 1.6047 - val_accuracy: 0.8182 - 122ms/epoch - 6ms/step
# Epoch 891/1000
# 22/22 - 0s - loss: 1.5427 - accuracy: 0.8519 - val_loss: 1.6036 - val_accuracy: 0.8182 - 121ms/epoch - 5ms/step
# Epoch 892/1000
# 22/22 - 0s - loss: 1.5421 - accuracy: 0.8504 - val_loss: 1.6034 - val_accuracy: 0.8182 - 114ms/epoch - 5ms/step
# Epoch 893/1000
# 22/22 - 0s - loss: 1.5413 - accuracy: 0.8519 - val_loss: 1.6027 - val_accuracy: 0.8182 - 115ms/epoch - 5ms/step
# Epoch 894/1000
# 22/22 - 0s - loss: 1.5407 - accuracy: 0.8533 - val_loss: 1.6022 - val_accuracy: 0.8182 - 110ms/epoch - 5ms/step
# Epoch 895/1000
# 22/22 - 0s - loss: 1.5399 - accuracy: 0.8533 - val_loss: 1.6016 - val_accuracy: 0.8182 - 114ms/epoch - 5ms/step
# Epoch 896/1000
# 22/22 - 0s - loss: 1.5392 - accuracy: 0.8533 - val_loss: 1.6008 - val_accuracy: 0.8182 - 112ms/epoch - 5ms/step
# Epoch 897/1000
# 22/22 - 0s - loss: 1.5385 - accuracy: 0.8519 - val_loss: 1.6000 - val_accuracy: 0.8182 - 117ms/epoch - 5ms/step
# Epoch 898/1000
# 22/22 - 0s - loss: 1.5378 - accuracy: 0.8504 - val_loss: 1.5997 - val_accuracy: 0.8182 - 116ms/epoch - 5ms/step
# Epoch 899/1000
# 22/22 - 0s - loss: 1.5371 - accuracy: 0.8519 - val_loss: 1.5992 - val_accuracy: 0.8182 - 115ms/epoch - 5ms/step
# Epoch 900/1000
# 22/22 - 0s - loss: 1.5364 - accuracy: 0.8533 - val_loss: 1.5986 - val_accuracy: 0.8182 - 113ms/epoch - 5ms/step
# Epoch 901/1000
# 22/22 - 0s - loss: 1.5360 - accuracy: 0.8519 - val_loss: 1.5980 - val_accuracy: 0.8182 - 116ms/epoch - 5ms/step
# Epoch 902/1000
# 22/22 - 0s - loss: 1.5352 - accuracy: 0.8519 - val_loss: 1.5974 - val_accuracy: 0.8182 - 149ms/epoch - 7ms/step
# Epoch 903/1000
# 22/22 - 0s - loss: 1.5345 - accuracy: 0.8533 - val_loss: 1.5968 - val_accuracy: 0.8182 - 110ms/epoch - 5ms/step
# Epoch 904/1000
# 22/22 - 0s - loss: 1.5338 - accuracy: 0.8533 - val_loss: 1.5963 - val_accuracy: 0.8182 - 111ms/epoch - 5ms/step
# Epoch 905/1000
# 22/22 - 0s - loss: 1.5332 - accuracy: 0.8504 - val_loss: 1.5955 - val_accuracy: 0.8182 - 115ms/epoch - 5ms/step
# Epoch 906/1000
# 22/22 - 0s - loss: 1.5324 - accuracy: 0.8533 - val_loss: 1.5953 - val_accuracy: 0.8182 - 113ms/epoch - 5ms/step
# Epoch 907/1000
# 22/22 - 0s - loss: 1.5317 - accuracy: 0.8519 - val_loss: 1.5945 - val_accuracy: 0.8182 - 112ms/epoch - 5ms/step
# Epoch 908/1000
# 22/22 - 0s - loss: 1.5311 - accuracy: 0.8519 - val_loss: 1.5942 - val_accuracy: 0.8182 - 115ms/epoch - 5ms/step
# Epoch 909/1000
# 22/22 - 0s - loss: 1.5304 - accuracy: 0.8504 - val_loss: 1.5933 - val_accuracy: 0.8182 - 119ms/epoch - 5ms/step
# Epoch 910/1000
# 22/22 - 0s - loss: 1.5298 - accuracy: 0.8519 - val_loss: 1.5925 - val_accuracy: 0.8182 - 114ms/epoch - 5ms/step
# Epoch 911/1000
# 22/22 - 0s - loss: 1.5290 - accuracy: 0.8519 - val_loss: 1.5921 - val_accuracy: 0.8182 - 113ms/epoch - 5ms/step
# Epoch 912/1000
# 22/22 - 0s - loss: 1.5284 - accuracy: 0.8519 - val_loss: 1.5916 - val_accuracy: 0.8182 - 113ms/epoch - 5ms/step
# Epoch 913/1000
# 22/22 - 0s - loss: 1.5277 - accuracy: 0.8519 - val_loss: 1.5910 - val_accuracy: 0.8182 - 112ms/epoch - 5ms/step
# Epoch 914/1000
# 22/22 - 0s - loss: 1.5273 - accuracy: 0.8533 - val_loss: 1.5908 - val_accuracy: 0.8182 - 114ms/epoch - 5ms/step
# Epoch 915/1000
# 22/22 - 0s - loss: 1.5264 - accuracy: 0.8519 - val_loss: 1.5896 - val_accuracy: 0.8182 - 113ms/epoch - 5ms/step
# Epoch 916/1000
# 22/22 - 0s - loss: 1.5258 - accuracy: 0.8533 - val_loss: 1.5895 - val_accuracy: 0.8182 - 111ms/epoch - 5ms/step
# Epoch 917/1000
# 22/22 - 0s - loss: 1.5251 - accuracy: 0.8519 - val_loss: 1.5887 - val_accuracy: 0.8182 - 112ms/epoch - 5ms/step
# Epoch 918/1000
# 22/22 - 0s - loss: 1.5244 - accuracy: 0.8519 - val_loss: 1.5880 - val_accuracy: 0.8182 - 117ms/epoch - 5ms/step
# Epoch 919/1000
# 22/22 - 0s - loss: 1.5238 - accuracy: 0.8519 - val_loss: 1.5873 - val_accuracy: 0.8182 - 110ms/epoch - 5ms/step
# Epoch 920/1000
# 22/22 - 0s - loss: 1.5231 - accuracy: 0.8519 - val_loss: 1.5869 - val_accuracy: 0.8182 - 111ms/epoch - 5ms/step
# Epoch 921/1000
# 22/22 - 0s - loss: 1.5225 - accuracy: 0.8519 - val_loss: 1.5865 - val_accuracy: 0.8182 - 111ms/epoch - 5ms/step
# Epoch 922/1000
# 22/22 - 0s - loss: 1.5219 - accuracy: 0.8504 - val_loss: 1.5857 - val_accuracy: 0.8182 - 116ms/epoch - 5ms/step
# Epoch 923/1000
# 22/22 - 0s - loss: 1.5211 - accuracy: 0.8519 - val_loss: 1.5854 - val_accuracy: 0.8182 - 151ms/epoch - 7ms/step
# Epoch 924/1000
# 22/22 - 0s - loss: 1.5204 - accuracy: 0.8533 - val_loss: 1.5849 - val_accuracy: 0.8182 - 117ms/epoch - 5ms/step
# Epoch 925/1000
# 22/22 - 0s - loss: 1.5198 - accuracy: 0.8519 - val_loss: 1.5841 - val_accuracy: 0.8182 - 111ms/epoch - 5ms/step
# Epoch 926/1000
# 22/22 - 0s - loss: 1.5191 - accuracy: 0.8533 - val_loss: 1.5839 - val_accuracy: 0.8182 - 114ms/epoch - 5ms/step
# Epoch 927/1000
# 22/22 - 0s - loss: 1.5185 - accuracy: 0.8519 - val_loss: 1.5829 - val_accuracy: 0.8182 - 120ms/epoch - 5ms/step
# Epoch 928/1000
# 22/22 - 0s - loss: 1.5178 - accuracy: 0.8533 - val_loss: 1.5824 - val_accuracy: 0.8182 - 115ms/epoch - 5ms/step
# Epoch 929/1000
# 22/22 - 0s - loss: 1.5171 - accuracy: 0.8533 - val_loss: 1.5818 - val_accuracy: 0.8182 - 116ms/epoch - 5ms/step
# Epoch 930/1000
# 22/22 - 0s - loss: 1.5165 - accuracy: 0.8561 - val_loss: 1.5813 - val_accuracy: 0.8182 - 114ms/epoch - 5ms/step
# Epoch 931/1000
# 22/22 - 0s - loss: 1.5158 - accuracy: 0.8561 - val_loss: 1.5808 - val_accuracy: 0.8182 - 114ms/epoch - 5ms/step
# Epoch 932/1000
# 22/22 - 0s - loss: 1.5152 - accuracy: 0.8547 - val_loss: 1.5802 - val_accuracy: 0.8182 - 114ms/epoch - 5ms/step
# Epoch 933/1000
# 22/22 - 0s - loss: 1.5145 - accuracy: 0.8561 - val_loss: 1.5798 - val_accuracy: 0.8182 - 113ms/epoch - 5ms/step
# Epoch 934/1000
# 22/22 - 0s - loss: 1.5139 - accuracy: 0.8533 - val_loss: 1.5789 - val_accuracy: 0.8182 - 110ms/epoch - 5ms/step
# Epoch 935/1000
# 22/22 - 0s - loss: 1.5132 - accuracy: 0.8533 - val_loss: 1.5786 - val_accuracy: 0.8182 - 119ms/epoch - 5ms/step
# Epoch 936/1000
# 22/22 - 0s - loss: 1.5126 - accuracy: 0.8561 - val_loss: 1.5780 - val_accuracy: 0.8182 - 113ms/epoch - 5ms/step
# Epoch 937/1000
# 22/22 - 0s - loss: 1.5119 - accuracy: 0.8561 - val_loss: 1.5774 - val_accuracy: 0.8182 - 115ms/epoch - 5ms/step
# Epoch 938/1000
# 22/22 - 0s - loss: 1.5112 - accuracy: 0.8561 - val_loss: 1.5768 - val_accuracy: 0.8182 - 115ms/epoch - 5ms/step
# Epoch 939/1000
# 22/22 - 0s - loss: 1.5105 - accuracy: 0.8561 - val_loss: 1.5762 - val_accuracy: 0.8182 - 114ms/epoch - 5ms/step
# Epoch 940/1000
# 22/22 - 0s - loss: 1.5100 - accuracy: 0.8575 - val_loss: 1.5760 - val_accuracy: 0.8182 - 115ms/epoch - 5ms/step
# Epoch 941/1000
# 22/22 - 0s - loss: 1.5094 - accuracy: 0.8575 - val_loss: 1.5751 - val_accuracy: 0.8182 - 112ms/epoch - 5ms/step
# Epoch 942/1000
# 22/22 - 0s - loss: 1.5086 - accuracy: 0.8575 - val_loss: 1.5747 - val_accuracy: 0.8182 - 114ms/epoch - 5ms/step
# Epoch 943/1000
# 22/22 - 0s - loss: 1.5079 - accuracy: 0.8575 - val_loss: 1.5741 - val_accuracy: 0.8182 - 156ms/epoch - 7ms/step
# Epoch 944/1000
# 22/22 - 0s - loss: 1.5074 - accuracy: 0.8561 - val_loss: 1.5733 - val_accuracy: 0.8182 - 115ms/epoch - 5ms/step
# Epoch 945/1000
# 22/22 - 0s - loss: 1.5067 - accuracy: 0.8561 - val_loss: 1.5726 - val_accuracy: 0.8182 - 112ms/epoch - 5ms/step
# Epoch 946/1000
# 22/22 - 0s - loss: 1.5060 - accuracy: 0.8575 - val_loss: 1.5723 - val_accuracy: 0.8182 - 116ms/epoch - 5ms/step
# Epoch 947/1000
# 22/22 - 0s - loss: 1.5054 - accuracy: 0.8575 - val_loss: 1.5716 - val_accuracy: 0.8182 - 111ms/epoch - 5ms/step
# Epoch 948/1000
# 22/22 - 0s - loss: 1.5047 - accuracy: 0.8575 - val_loss: 1.5715 - val_accuracy: 0.8182 - 118ms/epoch - 5ms/step
# Epoch 949/1000
# 22/22 - 0s - loss: 1.5041 - accuracy: 0.8575 - val_loss: 1.5708 - val_accuracy: 0.8182 - 112ms/epoch - 5ms/step
# Epoch 950/1000
# 22/22 - 0s - loss: 1.5034 - accuracy: 0.8575 - val_loss: 1.5703 - val_accuracy: 0.8182 - 110ms/epoch - 5ms/step
# Epoch 951/1000
# 22/22 - 0s - loss: 1.5029 - accuracy: 0.8575 - val_loss: 1.5694 - val_accuracy: 0.8182 - 116ms/epoch - 5ms/step
# Epoch 952/1000
# 22/22 - 0s - loss: 1.5021 - accuracy: 0.8590 - val_loss: 1.5689 - val_accuracy: 0.8182 - 115ms/epoch - 5ms/step
# Epoch 953/1000
# 22/22 - 0s - loss: 1.5015 - accuracy: 0.8575 - val_loss: 1.5687 - val_accuracy: 0.8182 - 112ms/epoch - 5ms/step
# Epoch 954/1000
# 22/22 - 0s - loss: 1.5009 - accuracy: 0.8575 - val_loss: 1.5676 - val_accuracy: 0.8182 - 111ms/epoch - 5ms/step
# Epoch 955/1000
# 22/22 - 0s - loss: 1.5002 - accuracy: 0.8575 - val_loss: 1.5673 - val_accuracy: 0.8182 - 115ms/epoch - 5ms/step
# Epoch 956/1000
# 22/22 - 0s - loss: 1.4996 - accuracy: 0.8575 - val_loss: 1.5668 - val_accuracy: 0.8182 - 114ms/epoch - 5ms/step
# Epoch 957/1000
# 22/22 - 0s - loss: 1.4989 - accuracy: 0.8575 - val_loss: 1.5661 - val_accuracy: 0.8182 - 112ms/epoch - 5ms/step
# Epoch 958/1000
# 22/22 - 0s - loss: 1.4982 - accuracy: 0.8590 - val_loss: 1.5656 - val_accuracy: 0.8182 - 114ms/epoch - 5ms/step
# Epoch 959/1000
# 22/22 - 0s - loss: 1.4976 - accuracy: 0.8575 - val_loss: 1.5650 - val_accuracy: 0.8182 - 118ms/epoch - 5ms/step
# Epoch 960/1000
# 22/22 - 0s - loss: 1.4970 - accuracy: 0.8575 - val_loss: 1.5646 - val_accuracy: 0.8232 - 113ms/epoch - 5ms/step
# Epoch 961/1000
# 22/22 - 0s - loss: 1.4964 - accuracy: 0.8590 - val_loss: 1.5641 - val_accuracy: 0.8182 - 116ms/epoch - 5ms/step
# Epoch 962/1000
# 22/22 - 0s - loss: 1.4957 - accuracy: 0.8575 - val_loss: 1.5635 - val_accuracy: 0.8182 - 115ms/epoch - 5ms/step
# Epoch 963/1000
# 22/22 - 0s - loss: 1.4951 - accuracy: 0.8575 - val_loss: 1.5631 - val_accuracy: 0.8232 - 148ms/epoch - 7ms/step
# Epoch 964/1000
# 22/22 - 0s - loss: 1.4944 - accuracy: 0.8575 - val_loss: 1.5624 - val_accuracy: 0.8182 - 115ms/epoch - 5ms/step
# Epoch 965/1000
# 22/22 - 0s - loss: 1.4939 - accuracy: 0.8590 - val_loss: 1.5621 - val_accuracy: 0.8182 - 112ms/epoch - 5ms/step
# Epoch 966/1000
# 22/22 - 0s - loss: 1.4932 - accuracy: 0.8575 - val_loss: 1.5612 - val_accuracy: 0.8232 - 108ms/epoch - 5ms/step
# Epoch 967/1000
# 22/22 - 0s - loss: 1.4925 - accuracy: 0.8575 - val_loss: 1.5608 - val_accuracy: 0.8182 - 117ms/epoch - 5ms/step
# Epoch 968/1000
# 22/22 - 0s - loss: 1.4919 - accuracy: 0.8575 - val_loss: 1.5603 - val_accuracy: 0.8232 - 112ms/epoch - 5ms/step
# Epoch 969/1000
# 22/22 - 0s - loss: 1.4913 - accuracy: 0.8575 - val_loss: 1.5597 - val_accuracy: 0.8182 - 108ms/epoch - 5ms/step
# Epoch 970/1000
# 22/22 - 0s - loss: 1.4907 - accuracy: 0.8575 - val_loss: 1.5593 - val_accuracy: 0.8182 - 112ms/epoch - 5ms/step
# Epoch 971/1000
# 22/22 - 0s - loss: 1.4901 - accuracy: 0.8575 - val_loss: 1.5584 - val_accuracy: 0.8232 - 113ms/epoch - 5ms/step
# Epoch 972/1000
# 22/22 - 0s - loss: 1.4894 - accuracy: 0.8575 - val_loss: 1.5583 - val_accuracy: 0.8232 - 113ms/epoch - 5ms/step
# Epoch 973/1000
# 22/22 - 0s - loss: 1.4888 - accuracy: 0.8590 - val_loss: 1.5574 - val_accuracy: 0.8232 - 113ms/epoch - 5ms/step
# Epoch 974/1000
# 22/22 - 0s - loss: 1.4882 - accuracy: 0.8575 - val_loss: 1.5572 - val_accuracy: 0.8182 - 114ms/epoch - 5ms/step
# Epoch 975/1000
# 22/22 - 0s - loss: 1.4876 - accuracy: 0.8590 - val_loss: 1.5563 - val_accuracy: 0.8232 - 118ms/epoch - 5ms/step
# Epoch 976/1000
# 22/22 - 0s - loss: 1.4869 - accuracy: 0.8575 - val_loss: 1.5560 - val_accuracy: 0.8232 - 113ms/epoch - 5ms/step
# Epoch 977/1000
# 22/22 - 0s - loss: 1.4863 - accuracy: 0.8590 - val_loss: 1.5558 - val_accuracy: 0.8232 - 111ms/epoch - 5ms/step
# Epoch 978/1000
# 22/22 - 0s - loss: 1.4856 - accuracy: 0.8590 - val_loss: 1.5549 - val_accuracy: 0.8232 - 115ms/epoch - 5ms/step
# Epoch 979/1000
# 22/22 - 0s - loss: 1.4849 - accuracy: 0.8575 - val_loss: 1.5542 - val_accuracy: 0.8232 - 113ms/epoch - 5ms/step
# Epoch 980/1000
# 22/22 - 0s - loss: 1.4844 - accuracy: 0.8590 - val_loss: 1.5537 - val_accuracy: 0.8283 - 117ms/epoch - 5ms/step
# Epoch 981/1000
# 22/22 - 0s - loss: 1.4837 - accuracy: 0.8590 - val_loss: 1.5533 - val_accuracy: 0.8283 - 146ms/epoch - 7ms/step
# Epoch 982/1000
# 22/22 - 0s - loss: 1.4831 - accuracy: 0.8590 - val_loss: 1.5526 - val_accuracy: 0.8232 - 114ms/epoch - 5ms/step
# Epoch 983/1000
# 22/22 - 0s - loss: 1.4825 - accuracy: 0.8590 - val_loss: 1.5522 - val_accuracy: 0.8283 - 117ms/epoch - 5ms/step
# Epoch 984/1000
# 22/22 - 0s - loss: 1.4820 - accuracy: 0.8575 - val_loss: 1.5518 - val_accuracy: 0.8232 - 112ms/epoch - 5ms/step
# Epoch 985/1000
# 22/22 - 0s - loss: 1.4813 - accuracy: 0.8590 - val_loss: 1.5513 - val_accuracy: 0.8283 - 114ms/epoch - 5ms/step
# Epoch 986/1000
# 22/22 - 0s - loss: 1.4807 - accuracy: 0.8604 - val_loss: 1.5507 - val_accuracy: 0.8232 - 110ms/epoch - 5ms/step
# Epoch 987/1000
# 22/22 - 0s - loss: 1.4800 - accuracy: 0.8590 - val_loss: 1.5502 - val_accuracy: 0.8232 - 113ms/epoch - 5ms/step
# Epoch 988/1000
# 22/22 - 0s - loss: 1.4794 - accuracy: 0.8618 - val_loss: 1.5495 - val_accuracy: 0.8283 - 110ms/epoch - 5ms/step
# Epoch 989/1000
# 22/22 - 0s - loss: 1.4788 - accuracy: 0.8604 - val_loss: 1.5491 - val_accuracy: 0.8232 - 114ms/epoch - 5ms/step
# Epoch 990/1000
# 22/22 - 0s - loss: 1.4781 - accuracy: 0.8604 - val_loss: 1.5486 - val_accuracy: 0.8232 - 111ms/epoch - 5ms/step
# Epoch 991/1000
# 22/22 - 0s - loss: 1.4779 - accuracy: 0.8618 - val_loss: 1.5477 - val_accuracy: 0.8283 - 111ms/epoch - 5ms/step
# Epoch 992/1000
# 22/22 - 0s - loss: 1.4769 - accuracy: 0.8590 - val_loss: 1.5477 - val_accuracy: 0.8283 - 120ms/epoch - 5ms/step
# Epoch 993/1000
# 22/22 - 0s - loss: 1.4763 - accuracy: 0.8604 - val_loss: 1.5471 - val_accuracy: 0.8283 - 111ms/epoch - 5ms/step
# Epoch 994/1000
# 22/22 - 0s - loss: 1.4757 - accuracy: 0.8590 - val_loss: 1.5465 - val_accuracy: 0.8232 - 114ms/epoch - 5ms/step
# Epoch 995/1000
# 22/22 - 0s - loss: 1.4751 - accuracy: 0.8590 - val_loss: 1.5459 - val_accuracy: 0.8283 - 115ms/epoch - 5ms/step
# Epoch 996/1000
# 22/22 - 0s - loss: 1.4744 - accuracy: 0.8618 - val_loss: 1.5454 - val_accuracy: 0.8283 - 113ms/epoch - 5ms/step
# Epoch 997/1000
# 22/22 - 0s - loss: 1.4738 - accuracy: 0.8604 - val_loss: 1.5447 - val_accuracy: 0.8283 - 111ms/epoch - 5ms/step
# Epoch 998/1000
# 22/22 - 0s - loss: 1.4733 - accuracy: 0.8590 - val_loss: 1.5442 - val_accuracy: 0.8283 - 114ms/epoch - 5ms/step
# Epoch 999/1000
# 22/22 - 0s - loss: 1.4726 - accuracy: 0.8604 - val_loss: 1.5438 - val_accuracy: 0.8283 - 153ms/epoch - 7ms/step
# Epoch 1000/1000
# 22/22 - 0s - loss: 1.4722 - accuracy: 0.8604 - val_loss: 1.5436 - val_accuracy: 0.8283 - 112ms/epoch - 5ms/step

# %%
fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(25, 4))
ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[0].set_title('Accuracy')
ax[0].set_xlabel('Accuracy')
ax[0].set_ylabel('Epoch')

ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[1].set_title('Loss')
ax[1].set_xlabel('Loss')
ax[1].set_ylabel('Epoch')

plt.legend(['Train', 'Test'])
plt.show()

# %%
from sklearn.metrics import classification_report
y_pred = np.rint(model.predict(X_val, verbose=0))

print(classification_report(y_val,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.71      0.76        52
#            1       0.72      0.81      0.76        48
#
#    micro avg       0.76      0.76      0.76       100
#    macro avg       0.76      0.76      0.76       100
# weighted avg       0.76      0.76      0.76       100
#  samples avg       0.76      0.76      0.76       100

# %%
labels = ['Not Diabetes', 'Diabetes']

y_pred = np.rint(model.predict(X_val, verbose=0).argmax(axis=1))
con_mat = confusion_matrix(y_val.argmax(axis=1),y_pred)

cm_percent = con_mat.astype('float') / con_mat.sum(axis=1)[:, np.newaxis]

sns.heatmap(cm_percent, annot=True, fmt='.2%', cmap='Blues', xticklabels=labels, yticklabels=labels)

plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # 6. Supervised Learning

# %%
X = data.drop(columns=['Outcome']).values
Y = data['Outcome']

print(Counter(Y))
# undersample = RandomUnderSampler()
undersample = SMOTE()
X, Y = undersample.fit_resample(X, Y)
print(Counter(Y))

Y = Y.values

# scaler = MinMaxScaler(feature_range=(0,1))
scaler = PowerTransformer(method='yeo-johnson', standardize=True)
X = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X, Y, train_size=0.9, random_state = 42)

print(X_train.shape)
print(X_test.shape)
# Out:
# Counter({0: 500, 1: 268})
# Counter({1: 500, 0: 500})
# (900, 8)
# (100, 8)

# %% [markdown]
# ### 6.2 Stacking Classifier

# %%
adaboost = AdaBoostClassifier(n_estimators=100, random_state=42)
bagging = BaggingClassifier(n_jobs=-1)
extraTrees = ExtraTreesClassifier(max_depth=100, n_jobs=-1, random_state=42)
gradient = GradientBoostingClassifier(max_depth=100, n_estimators=100, learning_rate=.01,  random_state=42)
randomForest = RandomForestClassifier(max_depth=100, random_state=42, n_jobs=-1)
histGradient = HistGradientBoostingClassifier()
XGB = XGBClassifier(n_jobs=-1)
knn = KNeighborsClassifier(n_jobs=-1)
decisionTree = DecisionTreeClassifier(random_state=42, max_depth=100)
pac = PassiveAggressiveClassifier(random_state=42)
linear = LogisticRegression(random_state=42)

model = StackingClassifier([
    ('bagging', bagging),
    ('adaboost', adaboost),
    ('extraTress', extraTrees),
    ('randomforest', randomForest),
    ('decisionTree', decisionTree),
    ('histGradient', histGradient),
    ('XGB', XGB),
    ('pac', pac),
    ('linear', linear),
    # ('gradient', gradient),
    # ('knn', knn),
], n_jobs=-1)

# %%
model.fit(X_train, y_train)
# Out:
# StackingClassifier(estimators=[('bagging', BaggingClassifier(n_jobs=-1)),
#                                ('adaboost',
#                                 AdaBoostClassifier(n_estimators=100,
#                                                    random_state=42)),
#                                ('extraTress',
#                                 ExtraTreesClassifier(max_depth=100, n_jobs=-1,
#                                                      random_state=42)),
#                                ('randomforest',
#                                 RandomForestClassifier(max_depth=100, n_jobs=-1,
#                                                        random_state=42)),
#                                ('decisionTree',
#                                 DecisionTreeClassifier(max_depth=100,
#                                                        r...
#                                               max_cat_threshold=None,
#                                               max_cat_to_onehot=None,
#                                               max_delta_step=None,
#                                               max_depth=None, max_leaves=None,
#                                               min_child_weight=None,
#                                               missing=nan,
#                                               monotone_constraints=None,
#                                               n_estimators=100, n_jobs=-1,
#                                               num_parallel_tree=None,
#                                               predictor=None, random_state=None, ...)),
#                                ('pac',
#                                 PassiveAggressiveClassifier(random_state=42)),
#                                ('linear', LogisticRegression(random_state=42))],
#                    n_jobs=-1)

# %%
print("Train Score : ",round((model.score(X_train, y_train)*100), 2),'%')
print("Test Score  : ",round((model.score(X_test, y_test)*100), 2),'%')
# Out:
# Train Score :  100.0 %
# Test Score  :  83.0 %

# %%
y_pred = model.predict(X_test)
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.87      0.83        47
#            1       0.88      0.79      0.83        53
#
#     accuracy                           0.83       100
#    macro avg       0.83      0.83      0.83       100
# weighted avg       0.83      0.83      0.83       100

# %%
labels = ['Not Diabetes', 'Diabetes']

y_pred = model.predict(X_test)
con_mat = confusion_matrix(y_test,y_pred)

cm_percent = con_mat.astype('float') / con_mat.sum(axis=1)[:, np.newaxis]

sns.heatmap(cm_percent, annot=True, fmt='.2%', cmap='Blues', xticklabels=labels, yticklabels=labels)

plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix - Fake News Detection')
plt.show()

# %% [markdown]
# ### 6.2. Pycaret

# %%
s = ClassificationExperiment()
s.setup(data, target = 'target', session_id = 123)
# Out:
# <style type="text/css">
# #T_4b62a_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4b62a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b62a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4b62a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b62a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4b62a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4b62a_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4b62a_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4b62a_row1_col1" class="data row1 col1" >target</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4b62a_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_4b62a_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4b62a_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_4b62a_row3_col1" class="data row3 col1" >(302, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4b62a_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_4b62a_row4_col1" class="data row4 col1" >(302, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4b62a_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_4b62a_row5_col1" class="data row5 col1" >(211, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4b62a_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_4b62a_row6_col1" class="data row6 col1" >(91, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4b62a_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_4b62a_row7_col1" class="data row7 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4b62a_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_4b62a_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4b62a_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_4b62a_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4b62a_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_4b62a_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4b62a_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_4b62a_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4b62a_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_4b62a_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_4b62a_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_4b62a_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_4b62a_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_4b62a_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_4b62a_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_4b62a_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_4b62a_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_4b62a_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_4b62a_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_4b62a_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_4b62a_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_4b62a_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_4b62a_row18_col1" class="data row18 col1" >de87</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = s.compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              21:18:11
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library

# %%
s.evaluate_model(best)

# %%
print(best)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=123, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
s.predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ea290">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea290_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ea290_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ea290_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_ea290_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_ea290_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_ea290_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_ea290_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_ea290_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea290_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ea290_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_ea290_row0_col1" class="data row0 col1" >0.8462</td>
#       <td id="T_ea290_row0_col2" class="data row0 col2" >0.9082</td>
#       <td id="T_ea290_row0_col3" class="data row0 col3" >0.9184</td>
#       <td id="T_ea290_row0_col4" class="data row0 col4" >0.8182</td>
#       <td id="T_ea290_row0_col5" class="data row0 col5" >0.8654</td>
#       <td id="T_ea290_row0_col6" class="data row0 col6" >0.6873</td>
#       <td id="T_ea290_row0_col7" class="data row0 col7" >0.6935</td>
#     </tr>
#   </tbody>
# </table>
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 300   68    1   0       144   193    1        1      141      0      3.4
# 276   58    1   0       146   218    0        1      105      0      2.0
# 84    42    0   0       102   265    0        0      122      0      0.6
# 141   43    1   0       115   303    0        1      181      0      1.2
# 226   62    1   1       120   281    0        0      103      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 153   66    0   2       146   278    0        0      152      0      0.0
# 11    48    0   2       130   275    0        1      139      0      0.2
# 81    45    1   1       128   308    0        0      170      0      0.0
# 162   41    1   1       120   157    0        1      182      0      0.0
# 214   56    1   0       125   249    1        0      144      1      1.2
#
#      slope  ca  thal  target  prediction_label  prediction_score
# 300      1   2     3       0                 0            0.9656
# 276      1   1     3       0                 0            0.9710
# 84       1   0     2       1                 1            0.6207
# 141      1   0     2       1                 1            0.6176
# 226      1   1     3       0                 0            0.9002
# ..     ...  ..   ...     ...               ...               ...
# 153      1   1     2       1                 1            0.9173
# 11       2   0     2       1                 1            0.9615
# 81       2   0     2       1                 1            0.8216
# 162      2   0     2       1                 1            0.9372
# 214      1   1     2       0                 0            0.8795
#
# [91 rows x 16 columns]

# %%
lgbm = s.create_model('xgboost')
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              18:02:50
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# <style type="text/css">
# #T_9c2dd_row10_col0, #T_9c2dd_row10_col1, #T_9c2dd_row10_col2, #T_9c2dd_row10_col3, #T_9c2dd_row10_col4, #T_9c2dd_row10_col5, #T_9c2dd_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_9c2dd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c2dd_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_9c2dd_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_9c2dd_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_9c2dd_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_9c2dd_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_9c2dd_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_9c2dd_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c2dd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9c2dd_row0_col0" class="data row0 col0" >0.7718</td>
#       <td id="T_9c2dd_row0_col1" class="data row0 col1" >0.8167</td>
#       <td id="T_9c2dd_row0_col2" class="data row0 col2" >0.7180</td>
#       <td id="T_9c2dd_row0_col3" class="data row0 col3" >0.7497</td>
#       <td id="T_9c2dd_row0_col4" class="data row0 col4" >0.7335</td>
#       <td id="T_9c2dd_row0_col5" class="data row0 col5" >0.5342</td>
#       <td id="T_9c2dd_row0_col6" class="data row0 col6" >0.5346</td>
#     </tr>
#     <tr>
#       <th id="T_9c2dd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9c2dd_row1_col0" class="data row1 col0" >0.7747</td>
#       <td id="T_9c2dd_row1_col1" class="data row1 col1" >0.8213</td>
#       <td id="T_9c2dd_row1_col2" class="data row1 col2" >0.7183</td>
#       <td id="T_9c2dd_row1_col3" class="data row1 col3" >0.7547</td>
#       <td id="T_9c2dd_row1_col4" class="data row1 col4" >0.7360</td>
#       <td id="T_9c2dd_row1_col5" class="data row1 col5" >0.5396</td>
#       <td id="T_9c2dd_row1_col6" class="data row1 col6" >0.5401</td>
#     </tr>
#     <tr>
#       <th id="T_9c2dd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9c2dd_row2_col0" class="data row2 col0" >0.7757</td>
#       <td id="T_9c2dd_row2_col1" class="data row2 col1" >0.8226</td>
#       <td id="T_9c2dd_row2_col2" class="data row2 col2" >0.7208</td>
#       <td id="T_9c2dd_row2_col3" class="data row2 col3" >0.7552</td>
#       <td id="T_9c2dd_row2_col4" class="data row2 col4" >0.7376</td>
#       <td id="T_9c2dd_row2_col5" class="data row2 col5" >0.5419</td>
#       <td id="T_9c2dd_row2_col6" class="data row2 col6" >0.5424</td>
#     </tr>
#     <tr>
#       <th id="T_9c2dd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9c2dd_row3_col0" class="data row3 col0" >0.7683</td>
#       <td id="T_9c2dd_row3_col1" class="data row3 col1" >0.8147</td>
#       <td id="T_9c2dd_row3_col2" class="data row3 col2" >0.7119</td>
#       <td id="T_9c2dd_row3_col3" class="data row3 col3" >0.7465</td>
#       <td id="T_9c2dd_row3_col4" class="data row3 col4" >0.7288</td>
#       <td id="T_9c2dd_row3_col5" class="data row3 col5" >0.5267</td>
#       <td id="T_9c2dd_row3_col6" class="data row3 col6" >0.5272</td>
#     </tr>
#     <tr>
#       <th id="T_9c2dd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9c2dd_row4_col0" class="data row4 col0" >0.7714</td>
#       <td id="T_9c2dd_row4_col1" class="data row4 col1" >0.8189</td>
#       <td id="T_9c2dd_row4_col2" class="data row4 col2" >0.7178</td>
#       <td id="T_9c2dd_row4_col3" class="data row4 col3" >0.7491</td>
#       <td id="T_9c2dd_row4_col4" class="data row4 col4" >0.7331</td>
#       <td id="T_9c2dd_row4_col5" class="data row4 col5" >0.5334</td>
#       <td id="T_9c2dd_row4_col6" class="data row4 col6" >0.5337</td>
#     </tr>
#     <tr>
#       <th id="T_9c2dd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9c2dd_row5_col0" class="data row5 col0" >0.7700</td>
#       <td id="T_9c2dd_row5_col1" class="data row5 col1" >0.8144</td>
#       <td id="T_9c2dd_row5_col2" class="data row5 col2" >0.7148</td>
#       <td id="T_9c2dd_row5_col3" class="data row5 col3" >0.7482</td>
#       <td id="T_9c2dd_row5_col4" class="data row5 col4" >0.7311</td>
#       <td id="T_9c2dd_row5_col5" class="data row5 col5" >0.5304</td>
#       <td id="T_9c2dd_row5_col6" class="data row5 col6" >0.5308</td>
#     </tr>
#     <tr>
#       <th id="T_9c2dd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9c2dd_row6_col0" class="data row6 col0" >0.7762</td>
#       <td id="T_9c2dd_row6_col1" class="data row6 col1" >0.8220</td>
#       <td id="T_9c2dd_row6_col2" class="data row6 col2" >0.7227</td>
#       <td id="T_9c2dd_row6_col3" class="data row6 col3" >0.7552</td>
#       <td id="T_9c2dd_row6_col4" class="data row6 col4" >0.7386</td>
#       <td id="T_9c2dd_row6_col5" class="data row6 col5" >0.5432</td>
#       <td id="T_9c2dd_row6_col6" class="data row6 col6" >0.5436</td>
#     </tr>
#     <tr>
#       <th id="T_9c2dd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9c2dd_row7_col0" class="data row7 col0" >0.7739</td>
#       <td id="T_9c2dd_row7_col1" class="data row7 col1" >0.8207</td>
#       <td id="T_9c2dd_row7_col2" class="data row7 col2" >0.7208</td>
#       <td id="T_9c2dd_row7_col3" class="data row7 col3" >0.7520</td>
#       <td id="T_9c2dd_row7_col4" class="data row7 col4" >0.7361</td>
#       <td id="T_9c2dd_row7_col5" class="data row7 col5" >0.5385</td>
#       <td id="T_9c2dd_row7_col6" class="data row7 col6" >0.5389</td>
#     </tr>
#     <tr>
#       <th id="T_9c2dd_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9c2dd_row8_col0" class="data row8 col0" >0.7744</td>
#       <td id="T_9c2dd_row8_col1" class="data row8 col1" >0.8216</td>
#       <td id="T_9c2dd_row8_col2" class="data row8 col2" >0.7189</td>
#       <td id="T_9c2dd_row8_col3" class="data row8 col3" >0.7538</td>
#       <td id="T_9c2dd_row8_col4" class="data row8 col4" >0.7360</td>
#       <td id="T_9c2dd_row8_col5" class="data row8 col5" >0.5392</td>
#       <td id="T_9c2dd_row8_col6" class="data row8 col6" >0.5397</td>
#     </tr>
#     <tr>
#       <th id="T_9c2dd_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9c2dd_row9_col0" class="data row9 col0" >0.7723</td>
#       <td id="T_9c2dd_row9_col1" class="data row9 col1" >0.8190</td>
#       <td id="T_9c2dd_row9_col2" class="data row9 col2" >0.7165</td>
#       <td id="T_9c2dd_row9_col3" class="data row9 col3" >0.7513</td>
#       <td id="T_9c2dd_row9_col4" class="data row9 col4" >0.7335</td>
#       <td id="T_9c2dd_row9_col5" class="data row9 col5" >0.5349</td>
#       <td id="T_9c2dd_row9_col6" class="data row9 col6" >0.5353</td>
#     </tr>
#     <tr>
#       <th id="T_9c2dd_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_9c2dd_row10_col0" class="data row10 col0" >0.7729</td>
#       <td id="T_9c2dd_row10_col1" class="data row10 col1" >0.8192</td>
#       <td id="T_9c2dd_row10_col2" class="data row10 col2" >0.7180</td>
#       <td id="T_9c2dd_row10_col3" class="data row10 col3" >0.7516</td>
#       <td id="T_9c2dd_row10_col4" class="data row10 col4" >0.7344</td>
#       <td id="T_9c2dd_row10_col5" class="data row10 col5" >0.5362</td>
#       <td id="T_9c2dd_row10_col6" class="data row10 col6" >0.5366</td>
#     </tr>
#     <tr>
#       <th id="T_9c2dd_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_9c2dd_row11_col0" class="data row11 col0" >0.0024</td>
#       <td id="T_9c2dd_row11_col1" class="data row11 col1" >0.0028</td>
#       <td id="T_9c2dd_row11_col2" class="data row11 col2" >0.0030</td>
#       <td id="T_9c2dd_row11_col3" class="data row11 col3" >0.0030</td>
#       <td id="T_9c2dd_row11_col4
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
X = data.drop(columns=['satisfaction']).values
Y = data['satisfaction']

# %%
scores = cross_val_score(lgbm, X_train, y_train, cv=20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 scores = cross_val_score(lgbm, X_train, y_train, cv=20)
#
# NameError: name 'X_train' is not defined

# %%
sns.lineplot(scores)
# Out:
# <Axes: >

# %%
preds = s.predict_model(lgbm)
preds
# Out:
# <style type="text/css">
# </style>
# <table id="T_40b2e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40b2e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_40b2e_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_40b2e_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_40b2e_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_40b2e_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_40b2e_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_40b2e_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_40b2e_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40b2e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_40b2e_row0_col0" class="data row0 col0" >Extreme Gradient Boosting</td>
#       <td id="T_40b2e_row0_col1" class="data row0 col1" >0.7745</td>
#       <td id="T_40b2e_row0_col2" class="data row0 col2" >0.8197</td>
#       <td id="T_40b2e_row0_col3" class="data row0 col3" >0.7199</td>
#       <td id="T_40b2e_row0_col4" class="data row0 col4" >0.7531</td>
#       <td id="T_40b2e_row0_col5" class="data row0 col5" >0.7362</td>
#       <td id="T_40b2e_row0_col6" class="data row0 col6" >0.5394</td>
#       <td id="T_40b2e_row0_col7" class="data row0 col7" >0.5399</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred = (abs(preds['satisfaction'] - preds['prediction_label'])).sum()

print(f'{pred} / {preds.shape[0]} : {round(pred/preds.shape[0]*100, 2)} % (False Predictions)')
# Out:
# 33248 / 147438 : 22.55 % (False Predictions)
